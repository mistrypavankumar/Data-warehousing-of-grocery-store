# %%
import sqlite3 as lite
import csv
from datetime import datetime, date, timedelta
from decimal import Decimal
import random

# %%
database_name = "store4"

'''
    If you are building the grocery database, 
        you should only touch
        ARGS, TABLE_DEFINITIONS, and params.

    If you get an error message, 
        set all three values in ARGS to True
        and then re-run the script.
'''


class ARGS:
    CREATE_PRODUCTS_TABLE = True
    POPULATE_FACTS_TABLE = True


class params:

    class group:
        customers_low = 1050
        customers_high = 1080
        weekend_increase = 50
        price_multiplier = 1.07
        maximum_items = 70
        restock_days = [1, 3, 5]
    
    class simulation:
        start_date = date(2024, 1, 1)
        end_date = date(2025, 6, 30)
 
    class debug:
        display_daily_commits = 30

    '''
        Initial Stock Counts in Cases
        Numbers are based on profiling in HW 3
        The max stock level is set to 2 for items for which I expect
            to sell less than 2 cases worth over three days.
    '''
    class MAX_STOCK_LEVELS:
        milk = 16
        cereal = 2
        baby_food = 2
        diapers = 2
        bread = 3
        peanut_butter = 5
        jelly_jam = 10
        other = 7

    '''
        The simulation probabilities that Breitzman
            told us to use from Week 2.
    '''
    class PROBS:
        MILK = 70
        MILK_CEREAL = 50
        NoMILK_CEREAL = 5
        BABYFOOD = 20
        BABYFOOD_DIAPERS = 80
        NoBABYFOOD_DIAPERS = 1
        BREAD = 50
        PEANUTBUTTER = 10
        PEANUTBUTTER_JELLYJAM = 90
        NoPEANUTBUTTER_JELLYJAM = 5
        
    
    '''
        I am assuming that all cases have 12 items.
        Allows me to give special treatment 
            to different product categories later.
    '''
    class CASE_COUNT:
        generic = 12


'''
    TABLE_DEFINITIONS is a dict as follows:
        Key - the name of the table in the database
        Value - the CREATE TABLE statement for the table
    I wrote a lot of unused table definitions that will be useful
        in a later HW.
'''
TABLE_DEFINITIONS = {
    'date' : \
            'CREATE TABLE date(' \
                    'DateKey INT, ' \
                    'PrettyDate TEXT, ' \
                    'DayNumberInMonth INT, ' \
                    'DayNumberInYear INT, ' \
                    'WeekNumberInYear INT, ' \
                    'MonthNum INT, ' \
                    'MonthTxt TEXT, ' \
                    'Quarter INT, ' \
                    'Year INT,' \
                    'FiscalYear INT, ' \
                    'isHoliday INT, ' \
                    'isWeekend INT, ' \
                    'Season TEXT' ')',

    'products': \
            'CREATE TABLE products(' \
                    'sku INT,' \
                    'product_name TEXT, ' \
                    'product_type TEXT, ' \
                    'manufacturer TEXT, ' \
                    'base_price REAL)',

    'store' : \
            'CREATE TABLE store(' \
                    'StoreKey INT, ' \
                    'StoreManager TEXT, ' \
                    'StoreStreetAddr TEXT, ' \
                    'StoreTown TEXT, ' \
                    'StoreZipCode TEXT, ' \
                    'StorePhoneNumber TEXT, ' \
                    'StoreState TEXT' ')',
    
    'sales_transactions': \
            'CREATE TABLE sales_transactions(' \
                    'date TEXT, ' \
                    'customer_number INT, ' \
                    'sku INT, ' \
                    'salesPrice REAL, ' \
                    'items_left INT, ' \
                    'cases_ordered INT)',

    'sales_customers': \
            'CREATE TABLE sales_customers(' \
                    'date VARCHAR(8), ' \
                    'customer_number INT, ' \
                    'num_items INT, ' \
                    'total FLOAT)',

    'sales_daily': \
            'CREATE TABLE sales_daily(' \
                    'date VARCHAR(8), ' \
                    'num_customers INT, ' \
                    'num_items INT, ' \
                    'total FLOAT)',

    'inventory_daily' : \
            'CREATE TABLE inventory_daily(' \
                    'DateKey INT, ' \
                    'ProductKey INT, ' \
                    'StoreKey INT, ' \
                    'NumAvailable INT, '
                    'CostToStoreItem FLOAT, ' \
                    'CostToStore FLOAT, ' \
                    'NumCasesPurchasedToDate INT)', 

    'inventory_quarterly' : \
            'CREATE TABLE inventory_quarterly(' \
                    'ProductKey INT, ' \
                    'StoreKey INT, ' \
                    'Quarter INT, ' \
                    'Year INT, ' \
                    'CasesPurchasedToDate INT, ' \
                    'CasesPurchasedThisQuarter INT, ' \
                    'CasesOnHand INT, ' \
                    'TotalCostToStoreThisQuarter FLOAT, ' \
                    'TotalSoldByStoreThisQuarter FLOAT, ' \
                    'TotalCostToStoreThisYTD FLOAT, ' \
                    'TotalSoldByStoreThisYTD FLOAT)'
}


'''
    It would be nice if the assert functions were not called
        when DEBUG.globals.run_assert is set to False so that
        the interpreter is not calling and then returning
        every single time the DEBUG functions are called
        but I would need to copy the condition checks in
        a bunch of places.
'''
class DEBUG:
    
    class globals:
        run_assert = False
        
    def assert_params(param, param_type):
        if not DEBUG.globals.run_assert:
            return
        
        assert isinstance(param, param_type), \
            "Error!" \
            f"Expected argument of {param_type}" "\n" \
            f"Got argument of {type(param)} instead." "\n" \
            f"This parameter's value is {param}" "\n"

    '''
        The caller is responsible for passing a meaningful
            message describing what their asserts intend to do. 
    '''
    def assert_expr(expr, msg):
        if not DEBUG.globals.run_assert:
            return
            
        assert isinstance(expr, bool), \
            'Error! Your expression did not actually ' '\n' \
            '\t' 'resolve to a boolean.' \
            'This is the message you passed to assert_expr(expr, msg)' '\n' \
            f'{msg}'
        
        assert expr, msg


'''
    This class provides one common point of interaction with my team's database.
    Everything that writes to the database uses this API.
'''
class db:
    
    class globals:
        con = None
        cur = None
        commit_pending = 0

    def connect():
        db.globals.con = lite.connect(f'{database_name}.db')
        db.globals.cur = db.globals.con.cursor()
        print('Database Successfully Connected To')

    def build_table(name):
        DEBUG.assert_params(name, str)
        DEBUG.assert_expr( \
            name in TABLE_DEFINITIONS.keys(), \
            'This assert checks that you are calling build_table(name) ' '\n' \
            '\t' 'with a valid table name.' '\n' \
            'This assert exists because the Python SQLite library ' '\n' \
            '\t' 'disallows placeholders for DROP TABLE statements.')
        
        db.execute_sql(f'DROP TABLE IF EXISTS {name}')
        db.execute_sql(TABLE_DEFINITIONS[name])
    
    def execute_sql(sql):
        DEBUG.assert_params(sql, str)
        
        db.globals.cur.execute(sql)

    def execute_sql_values(sql, values):
        DEBUG.assert_params(sql, str)
        DEBUG.assert_params(values, tuple)

        db.globals.cur.execute(sql, values)

    def commit():
        db.globals.con.commit()
        db.commit_pending = 0

    def close():
        db.globals.con.commit()
        db.globals.con.close()
        print('Database Connection Closed')


'''
    This API is for debugging purposes.
    In my testing, something was not playing nice with the
        existing database API when I tried to print because
        I was getting errors stating that the database connection is closed.
    These functions maintain their own connection and cursor.
'''
class db_debug():
    
    def execute_sql(sql):
        DEBUG.assert_params(sql, str)

        con = lite.connect(f'{database_name}.db')
        cur = con.cursor()
        
        results = cur.execute(sql).fetchall()
        for row in results:
            print(row)

        con.close()

    def execute_sql_values(sql, values):
        DEBUG.assert_params(values, tuple)

        con = lite.connect(f'{database_name}.db')
        cur = con.cursor()
        
        results = cur.execute(sql, values)
        for row in results:
            print(row)
        
        con.close()


'''
    This class is responsible for storing information
        about each individual product.
    Each product in memory is responsible for knowing
        how much of that product is in stock.
'''
class Product:

    class MAX_STOCK_LEVELS:
        milk = params.MAX_STOCK_LEVELS.milk
        cereal = params.MAX_STOCK_LEVELS.cereal
        baby_food = params.MAX_STOCK_LEVELS.baby_food
        diapers = params.MAX_STOCK_LEVELS.diapers
        bread = params.MAX_STOCK_LEVELS.bread
        peanut_butter = params.MAX_STOCK_LEVELS.peanut_butter
        jelly_jam = params.MAX_STOCK_LEVELS.jelly_jam
        other = params.MAX_STOCK_LEVELS.other


    def __init__(self, p_name, p_type, sku, price):
        DEBUG.assert_params(p_name, str)
        DEBUG.assert_params(p_type, str)
        DEBUG.assert_params(sku, int)
        DEBUG.assert_params(price, float)
        
        self.p_name = p_name
        self.p_type = p_type
        self.sku = sku
        self.price = price
        self.stock = 0
        self.total_cases_ordered = 0

    def __str__(self):
        return f'{self.p_name} - {self.p_type} - {self.sku} - {self.price}'

    def restock(self):
        match self.p_type:
            case 'Milk':
                max_limit = 12 * Product.MAX_STOCK_LEVELS.milk
            case 'Cereal':
                max_limit = 12 * Product.MAX_STOCK_LEVELS.cereal
            case 'Baby Food':
                max_limit = 12 * Product.MAX_STOCK_LEVELS.baby_food
            case 'Diapers':
                max_limit = 12 * Product.MAX_STOCK_LEVELS.diapers
            case 'Bread':
                max_limit = 12 * Product.MAX_STOCK_LEVELS.bread
            case 'Peanut Butter':
                max_limit = 12 * Product.MAX_STOCK_LEVELS.peanut_butter
            case 'Jelly/Jam':
                max_limit = 12 * Product.MAX_STOCK_LEVELS.jelly_jam
            case _:
                max_limit = 12 * Product.MAX_STOCK_LEVELS.other

        num_items_needed = max_limit - self.stock
        num_cases_needed = (num_items_needed + 11) // 12

        self.total_cases_ordered += num_cases_needed
        self.stock += 12*(num_cases_needed)


'''
    Products that a customer can select are represented by
        Inventory.products, which is a class-level dict
        of arrays whose definition should be inferred
        by Inventory.TYPE and Inventory.reset_lists().
'''
class Inventory:
    from enum import Enum
    
    products = {}

    class TYPE(Enum):
        OTHER = 'other'
        MILK = 'milk'
        CEREAL = 'cereal'
        BABY_FOOD = 'baby food'
        DIAPERS = 'diapers'
        BREAD = 'bread'
        PEANUT_BUTTER = 'peanut butter'
        JELLY_JAM = 'jelly jam'

    '''
        Jupyter makes lists persist in memory after I run each cell.
        I delete the existing lists in order to not have the same product appear multiple times.
    '''
    def reset_lists():
        Inventory.products = {}
        for p_type in Inventory.TYPE:
            Inventory.products[p_type.value] = []
    
    def select(p_type):
        DEBUG.assert_params(p_type, Inventory.TYPE)
        
        num_products_in_type = len(Inventory.products[p_type.value])
        product_index = random.randint(0, (num_products_in_type-1))
        last_index = \
            product_index - 1 if product_index != 0 \
            else (num_products_in_type-1)

        product = Inventory.products[p_type.value][product_index]

        '''
            If a product has 0 items in stock,
                loop through the product array until you find 
                something of the same type that is in stock.
            Relies on having shuffled the lists earlier.
        '''
        while(product.stock <= 0 and product_index != last_index):   
            product_index += 1
            product_index %= num_products_in_type
            product = Inventory.products[p_type.value][product_index]

        '''
            If everything in a product category is out of stock, 
                then return None and let the caller deal with it.
        '''
        if((product_index == last_index) and (product.stock <= 0)):
            return None
        
        product.stock -= 1
        return product

    '''
        Products are populated in memory 
            at the same time the product is populated in my dimension table.
            I found the dimension table helpful when doing some profiling.
    '''
    def create_products_table():
        
        if not ARGS.CREATE_PRODUCTS_TABLE:
            print("You don't want to create the Products table")
            return
            
        db.build_table('products')
        Inventory.reset_lists()
        db.commit()
    
        csv.register_dialect('piper', delimiter='|', quoting=csv.QUOTE_NONE)
        
        with open('Products1.txt', 'r') as csvfile:
            count = 0
            
            for row in csv.DictReader(csvfile, dialect='piper'):
                sku = int(row.get('SKU'))
                product_name = row.get('Product Name')
                product_type = row.get('itemType')
                manufacturer = row.get('Manufacturer')
                base_price = row.get('BasePrice')

                price = float(Decimal(base_price.strip('$')))
                price = round(price * params.group.price_multiplier, 2)

                current_product = Product(
                    p_name=product_name,
                    p_type=product_type,
                    sku=sku,
                    price=price
                )
                
                db.execute_sql_values( \
                        sql='insert into products values (?, ?, ?, ?, ?)',\
                        values=(sku, product_name, product_type, manufacturer, base_price))

                match product_type:
                    case 'Milk':
                        Inventory.products['milk'].append(current_product)
                    case 'Cereal':
                        Inventory.products['cereal'].append(current_product)
                    case 'Baby Food':
                        Inventory.products['baby food'].append(current_product)
                    case 'Diapers':
                        Inventory.products['diapers'].append(current_product)
                    case 'Bread':
                        Inventory.products['bread'].append(current_product)
                    case 'Peanut Butter':
                        Inventory.products['peanut butter'].append(current_product)
                    case 'Jelly/Jam':
                        Inventory.products['jelly jam'].append(current_product)
                    case _:
                        Inventory.products['other'].append(current_product)
                
                count += 1
                if count % 10000 == 0:
                    db.commit()
                    print(f"Committed {count} products")
                
            db.commit()
            print(f"Committed {count} products")
    
            '''
                We want the customer to randomly select another item of the same type 
                    if the item is out of stock.
                The select() method chooses the next index and this relies on having random products.
            '''
            for product_list in Inventory.products.values():
                random.shuffle(product_list)
            print('Products in memory successfully populated.')

    def restock_milk():
        for milk_product in Inventory.products['milk']:
            milk_product.restock()

    def restock_all():
        for product_list in Inventory.products.values():
            for product in product_list:
                product.restock()
        

'''
    Everything needed for the simulator to loop through
        a full calendar year.
'''
class simulate:

    '''
        These variables are not associated with any
            single day.
    '''
    class globals:
        num_days = 0
        start_date = params.simulation.start_date
        end_date = params.simulation.end_date

    class helpers:
        def random(prob):
            DEBUG.assert_expr( \
                ((0 < prob) and (prob < 100)), \
                'Asserts that probability is a valid percent')
            
            return random.randint(1, 100) <= prob

    class params:
        customers_low = params.group.customers_low
        customers_high = params.group.customers_high
        weekend_increase = params.group.weekend_increase
        maximum_items = params.group.maximum_items
        restock_days = params.group.restock_days
    
    class PROBS:
        MILK = params.PROBS.MILK
        MILK_CEREAL = params.PROBS.MILK_CEREAL
        NoMILK_CEREAL = params.PROBS.NoMILK_CEREAL
        BABYFOOD = params.PROBS.BABYFOOD
        BABYFOOD_DIAPERS = params.PROBS.BABYFOOD_DIAPERS
        NoBABYFOOD_DIAPERS = params.PROBS.NoBABYFOOD_DIAPERS
        BREAD = params.PROBS.BREAD
        PEANUTBUTTER = params.PROBS.PEANUTBUTTER
        PEANUTBUTTER_JELLYJAM = params.PROBS.PEANUTBUTTER_JELLYJAM
        NoPEANUTBUTTER_JELLYJAM = params.PROBS.NoPEANUTBUTTER_JELLYJAM
    
    class DEBUG:
        def print_log(day):
            if (simulate.globals.num_days % params.debug.display_daily_commits == 0) \
                or (day.current_date == simulate.globals.start_date) \
                or (day.current_date == simulate.globals.end_date):
                
                print(f'{datetime.now()} - ' \
                      f'{day.date_str} - ' \
                      f'{db.commit_pending} records created and committing')

    '''
        Holds accumulators so I can populate fact tables of higher grain.
    '''
    class Day:
        def __init__(self, current_date):
            DEBUG.assert_params(current_date, date)
            
            self.current_date = current_date
            self.date_str = current_date.strftime('%Y-%m-%d')
            self.num_items = 0
            self.num_customers = 0
            self.daily_total = 0

        def save(self):
            self.daily_total = round(self.daily_total, 2)
            
            db.commit_pending += 1
            try:
                db.execute_sql_values('INSERT INTO sales_daily VALUES (?, ?, ?, ?)', 
                    (self.date_str, self.num_items, self.num_customers, self.daily_total))
            except Exception as err:
                print("Error writing to sales_daily database table.", err)

                
    class Customer:
        def __init__(self, day):
            DEBUG.assert_params(day, simulate.Day)
            
            self.date = day.date_str
            self.customer_number = day.num_customers + 1
            self.num_items = 0
            self.max_items = random.randint(1, params.group.maximum_items)
            self.running_total = 0

        def save(self, day):
            DEBUG.assert_params(day, simulate.Day)
    
            self.running_total = round(self.running_total, 2)
            
            day.num_items += self.num_items
            day.num_customers += 1
            day.daily_total += self.running_total
            
            db.commit_pending += 1
            try:
                db.execute_sql_values('INSERT INTO sales_customers VALUES (?, ?, ?, ?)', 
                    (self.date, self.customer_number, self.num_items, self.running_total))
            except Exception as err:
                print("Error writing to sales_customers database table.", err)

    def build_tables():
        for table_name in TABLE_DEFINITIONS.keys():
            if table_name != 'products':
                db.build_table(table_name)
        db.commit()
            
    def run():
        if not ARGS.POPULATE_FACTS_TABLE:
            print("You don't want to populate the Facts table")
            return

        for table_name in TABLE_DEFINITIONS.keys():
            '''
                I discovered when I worked in Tableau that the simulate
                    nukes the product dimension table which is unwanted.
            '''
            if not (table_name == 'products'):
                db.build_table(table_name)
        db.commit()

        simulate.build_tables()
        
        current_date = simulate.globals.start_date
        while(current_date <= simulate.globals.end_date):
            simulate.simulate_one_day(current_date)
            current_date += timedelta(1)

    def simulate_one_day(current_date):
        DEBUG.assert_params(current_date, date)

        simulate.globals.num_days += 1
        if(current_date == simulate.globals.start_date):
            Inventory.restock_all()

        '''
            Milk is restocked all 7 days of the week.
            Everything else is restocked on Tuesday, Thursday, and Saturday.
        '''
        if(current_date.weekday() in simulate.params.restock_days):
            Inventory.restock_all()
        else:
            Inventory.restock_milk()
                        
        increase = 0
        if current_date.weekday() >= 5:
            increase = simulate.params.weekend_increase
    
        day = simulate.Day(current_date)
        daily_customers = random.randint(simulate.params.customers_low + increase, simulate.params.customers_high + increase)

        for customer_number in range(daily_customers):
            simulate.simulate_one_customer(day)

        day.save()
        simulate.DEBUG.print_log(day)
        db.commit()
                
    def simulate_one_customer(day):

        DEBUG.assert_params(day, simulate.Day)

        customer_data = simulate.Customer(day)
        
        if simulate.helpers.random(simulate.PROBS.MILK):
            product = Inventory.select(Inventory.TYPE.MILK)
            simulate.buy(customer_data, product)

            if (customer_data.num_items < customer_data.max_items) \
                and (simulate.helpers.random(simulate.PROBS.MILK_CEREAL)):
                
                product = Inventory.select(Inventory.TYPE.CEREAL)
                simulate.buy(customer_data, product)

        else:
            if (simulate.helpers.random(simulate.PROBS.NoMILK_CEREAL)):
                product = Inventory.select(Inventory.TYPE.CEREAL)
                simulate.buy(customer_data, product)

        
        if (customer_data.num_items >= customer_data.max_items):
            customer_data.save(day)
            return

            
        if (simulate.helpers.random(simulate.PROBS.BABYFOOD)):
            product = Inventory.select(Inventory.TYPE.BABY_FOOD)
            simulate.buy(customer_data, product)

            if (customer_data.num_items < customer_data.max_items) \
                and (simulate.helpers.random(simulate.PROBS.BABYFOOD_DIAPERS)):
                
                product = Inventory.select(Inventory.TYPE.DIAPERS)
                simulate.buy(customer_data, product)
                
        else:
            if (simulate.helpers.random(simulate.PROBS.NoBABYFOOD_DIAPERS)):
                product = Inventory.select(Inventory.TYPE.DIAPERS)
                simulate.buy(customer_data, product)


        if (customer_data.num_items >= customer_data.max_items):
            customer_data.save(day)
            return
            
        
        if (simulate.helpers.random(simulate.PROBS.BREAD)):
            product = Inventory.select(Inventory.TYPE.BREAD)
            simulate.buy(customer_data, product)

        
        if (customer_data.num_items >= customer_data.max_items):
            customer_data.save(day)
            return

        
        if (simulate.helpers.random(simulate.PROBS.PEANUTBUTTER)):
            product = Inventory.select(Inventory.TYPE.PEANUT_BUTTER)
            simulate.buy(customer_data, product)

            if (customer_data.num_items < customer_data.max_items) \
                and (simulate.helpers.random(simulate.PROBS.PEANUTBUTTER_JELLYJAM)):
            
                product = Inventory.select(Inventory.TYPE.JELLY_JAM)
                simulate.buy(customer_data, product)

        else:
            if (simulate.helpers.random(simulate.PROBS.NoPEANUTBUTTER_JELLYJAM)):
                product = Inventory.select(Inventory.TYPE.JELLY_JAM)
                simulate.buy(customer_data, product)


        if (customer_data.num_items >= customer_data.max_items):
            return

        
        while customer_data.num_items < customer_data.max_items:
            product = Inventory.select(Inventory.TYPE.OTHER)
            simulate.buy(customer_data, product)

        customer_data.save(day)

    def buy(customer, product):
        if product is None:
            '''
                In the rare case if 
                    a customer attempts to buy from a product category
                    where there is no stock, 
                    the current customer stops buying
                    and nothing is written.
            '''
            customer.max_items = customer.num_items
            return
        
        customer.num_items += 1
        customer.running_total += product.price
        db.commit_pending += 1
        try:
            db.execute_sql_values('insert into sales_transactions values (?, ?, ?, ?, ?, ?)',
                                        (customer.date,customer.customer_number,product.sku,product.price, product.stock, product.total_cases_ordered))

        except Exception as err:
            print("Error writing to sales_transactions database table", err)


def run():
    print(f'{datetime.now()} - Data Generation started.')
    start = datetime.now()
    
    db.connect()
    Inventory.create_products_table()
    simulate.run()
    db.close()

    end = datetime.now()
    print(f'{end} - Data generation ended.')

    print(f'The data generation took {end - start}')

run()
# Out:
# 2025-05-03 21:07:15.316692 - Data Generation started.
# Database Successfully Connected To
# Committed 2075 products
# Products in memory successfully populated.
# 2025-05-03 21:07:15.502861 - 2024-01-01 - 38286 records created and committing
# 2025-05-03 21:07:19.043369 - 2024-01-30 - 38517 records created and committing
# 2025-05-03 21:07:22.691422 - 2024-02-29 - 38719 records created and committing
# 2025-05-03 21:07:26.318872 - 2024-03-30 - 40520 records created and committing
# 2025-05-03 21:07:30.002365 - 2024-04-29 - 39750 records created and committing
# 2025-05-03 21:07:33.657661 - 2024-05-29 - 39147 records created and committing
# 2025-05-03 21:07:37.363537 - 2024-06-28 - 38896 records created and committing
# 2025-05-03 21:07:41.047082 - 2024-07-28 - 40878 records created and committing
# 2025-05-03 21:07:44.725171 - 2024-08-27 - 38693 records created and committing
# 2025-05-03 21:07:48.428798 - 2024-09-26 - 39111 records created and committing
# 2025-05-03 21:07:52.158078 - 2024-10-26 - 39596 records created and committing
# 2025-05-03 21:07:55.897263 - 2024-11-25 - 40822 records created and committing
# 2025-05-03 21:07:59.582815 - 2024-12-25 - 39041 records created and committing
# 2025-05-03 21:08:03.297473 - 2025-01-24 - 38340 records created and committing
# 2025-05-03 21:08:07.036988 - 2025-02-23 - 40919 records created and committing
# 2025-05-03 21:08:10.793141 - 2025-03-25 - 40003 records created and committing
# 2025-05-03 21:08:14.507315 - 2025-04-24 - 40139 records created and committing
# 2025-05-03 21:08:18.293055 - 2025-05-24 - 40695 records created and committing
# 2025-05-03 21:08:22.078085 - 2025-06-23 - 40043 records created and committing
# 2025-05-03 21:08:22.954650 - 2025-06-30 - 38950 records created and committing
# Database Connection Closed
# 2025-05-03 21:08:22.959819 - Data generation ended.
# The data generation took 0:01:07.642746

# %% [markdown]
# ## Testbed
# Inspect anything you want.

# %%
db_debug.execute_sql('SELECT * from products')
# Out:
# (42081001, 'Jambalaya Rice Mix', 'Rice/Rice Mix', 'Zatarains', '$2.49')
# (42082001, 'Jambalaya Rice Mix', 'Rice/Rice Mix', 'Zatarains', '$1.79')
# (42083001, 'Guacamole Regular', '', 'Yucatan', '$3.99')
# (42084001, 'Coffee Original Blend', 'Coffee/Creamer', 'Yuban', '$3.99')
# (42085001, 'GoGurt Variety Pack', 'Yogurt', 'Yoplait', '$2.99')
# (42086001, 'Italian Dressing', 'Salad Dressing', 'Wishbone', '$2.00')
# (42087001, 'Cheeseburger Heat & Serve Sliders', '', 'White Castle', '$11.59')
# (42088001, 'Choice Cuts Poultry', 'Pet Food', 'Whiskas', '$4.99')
# (42089001, 'Farmers Pick Concord Grape', '', 'Welchs', '$3.59')
# (42090001, 'Juice Red Grape', 'Juice', 'Welchs', '$4.79')
# (42091001, 'Cereal Whole Grain Biscuit', 'Cereal', 'Weetabix', '$6.99')
# (42092001, 'Shells & Cheese Microwave Cup', 'Mac & Cheese', 'Velveeta', '$1.00')
# (42093001, 'Shells & Cheese Original', 'Mac & Cheese', 'Velveeta', '$2.49')
# (42094001, 'Splash Berry Blend', 'Juice', 'V8', '$2.99')
# (42095001, 'Splash Mango Peach', 'Juice', 'V8', '$2.99')
# (42096001, 'V-Fusion Berry', 'Juice', 'V8', '$3.49')
# (42097001, 'V-Fusion Pomegranate Blueberry', 'Juice', 'V8', '$3.99')
# (42098001, 'V-Fusion Refreshers Peach Strawberry', 'Juice', 'V8', '$3.49')
# (42099001, 'Whole Grain Original Cereal', 'Cereal', 'Uncle Sam', '$2.50')
# (42100001, 'Iced Tea Lemon', '', 'Turkey Hill', '$2.99')
# (42101001, 'Orange Juice Some Pulp', 'Juice', 'Tropicana', '$7.29')
# (42102001, 'Trop50 Calcium', 'Juice', 'Tropicana', '$7.29')
# (42103001, 'Tri-State Almonds ', 'Nuts', 'Tri-State', '$1.54')
# (42104001, 'Tri-State Asparagus ', 'Fresh Vegetables', 'Tri-State', '$0.78')
# (42105001, 'Tri-State Baby Onion ', 'Fresh Vegetables', 'Tri-State', '$2.62')
# (42106001, 'Tri-State Beets ', 'Fresh Vegetables', 'Tri-State', '$3.42')
# (42107001, 'Tri-State Broccoli ', 'Fresh Vegetables', 'Tri-State', '$1.34')
# (42108001, 'Tri-State Canned Peanuts ', 'Nuts', 'Tri-State', '$0.85')
# (42109001, 'Tri-State Cantelope ', 'Fresh Fruit', 'Tri-State', '$2.57')
# (42110001, 'Tri-State Cauliflower ', 'Fresh Vegetables', 'Tri-State', '$0.81')
# (42111001, 'Tri-State Corn on the Cob ', 'Fresh Vegetables', 'Tri-State', '$2.80')
# (42112001, 'Tri-State Dried Mushrooms ', 'Fresh Vegetables', 'Tri-State', '$2.61')
# (42113001, 'Tri-State Elephant Garlic ', 'Fresh Vegetables', 'Tri-State', '$1.71')
# (42114001, 'Tri-State Fancy Plums ', 'Fresh Fruit', 'Tri-State', '$2.44')
# (42115001, 'Tri-State Firm Tofu ', 'Tofu', 'Tri-State', '$1.66')
# (42116001, 'Tri-State Fresh Lima Beans ', 'Fresh Vegetables', 'Tri-State', '$2.43')
# (42117001, 'Tri-State Fuji Apples ', 'Fresh Fruit', 'Tri-State', '$2.69')
# (42118001, 'Tri-State Garlic ', 'Fresh Vegetables', 'Tri-State', '$0.74')
# (42119001, 'Tri-State Golden Delcious Apples ', 'Fresh Fruit', 'Tri-State', '$1.96')
# (42120001, 'Tri-State Green Pepper ', 'Fresh Vegetables', 'Tri-State', '$3.64')
# (42121001, 'Tri-State Honey Dew ', 'Fresh Fruit', 'Tri-State', '$1.42')
# (42122001, 'Tri-State Lemons ', 'Fresh Fruit', 'Tri-State', '$1.77')
# (42123001, 'Tri-State Lettuce ', 'Fresh Vegetables', 'Tri-State', '$3.17')
# (42124001, 'Tri-State Limes ', 'Fresh Fruit', 'Tri-State', '$2.40')
# (42125001, 'Tri-State Macintosh Apples ', 'Fresh Fruit', 'Tri-State', '$1.82')
# (42126001, 'Tri-State Mandarin Oranges ', 'Fresh Fruit', 'Tri-State', '$2.95')
# (42127001, 'Tri-State Mixed Nuts ', 'Nuts', 'Tri-State', '$1.76')
# (42128001, 'Tri-State Mushrooms ', 'Fresh Vegetables', 'Tri-State', '$1.16')
# (42129001, 'Tri-State New Potatos ', 'Fresh Vegetables', 'Tri-State', '$0.67')
# (42130001, 'Tri-State Onions ', 'Fresh Vegetables', 'Tri-State', '$2.53')
# (42131001, 'Tri-State Oranges ', 'Fresh Fruit', 'Tri-State', '$3.19')
# (42132001, 'Tri-State Party Nuts ', 'Nuts', 'Tri-State', '$2.63')
# (42133001, 'Tri-State Peaches ', 'Fresh Fruit', 'Tri-State', '$2.56')
# (42134001, 'Tri-State Plums ', 'Fresh Fruit', 'Tri-State', '$2.86')
# (42135001, 'Tri-State Potatos ', 'Fresh Vegetables', 'Tri-State', '$1.96')
# (42136001, 'Tri-State Prepared Salad ', 'Fresh Vegetables', 'Tri-State', '$2.50')
# (42137001, 'Tri-State Red Delcious Apples ', 'Fresh Fruit', 'Tri-State', '$3.61')
# (42138001, 'Tri-State Red Pepper ', 'Fresh Vegetables', 'Tri-State', '$3.87')
# (42139001, 'Tri-State Shitake Mushrooms ', 'Fresh Vegetables', 'Tri-State', '$2.93')
# (42140001, 'Tri-State Squash ', 'Fresh Vegetables', 'Tri-State', '$1.55')
# (42141001, 'Tri-State Summer Squash ', 'Fresh Vegetables', 'Tri-State', '$0.55')
# (42142001, 'Tri-State Sweet Onion ', 'Fresh Vegetables', 'Tri-State', '$1.57')
# (42143001, 'Tri-State Sweet Peas ', 'Fresh Vegetables', 'Tri-State', '$3.58')
# (42144001, 'Tri-State Tangerines ', 'Fresh Fruit', 'Tri-State', '$0.62')
# (42145001, 'Tri-State Tomatos ', 'Fresh Vegetables', 'Tri-State', '$2.21')
# (42146001, 'Tri-State Walnuts ', 'Nuts', 'Tri-State', '$0.88')
# (42147001, 'Toucan Canned Mixed Fruit ', 'Canned Fruit', 'Toucan', '$1.40')
# (42148001, 'Toucan Canned Peaches ', 'Canned Fruit', 'Toucan', '$1.38')
# (42149001, 'Diapers Size 3', 'Diapers', 'Tippy Toes', '$7.99')
# (42150001, 'Diapers Size 3', 'Diapers', 'Tippy Toes', '$14.99')
# (42151001, 'Diapers Size 3', 'Diapers', 'Tippy Toes', '$16.99')
# (42152001, 'Diapers Size 4', 'Diapers', 'Tippy Toes', '$7.99')
# (42153001, 'Diapers Size 4', 'Diapers', 'Tippy Toes', '$14.99')
# (42154001, 'Diapers Size 5', 'Diapers', 'Tippy Toes', '$7.99')
# (42155001, 'Diapers Size 5', 'Diapers', 'Tippy Toes', '$16.99')
# (42156001, 'Tip Top Lox ', 'Fresh Fish', 'Tip Top', '$0.79')
# (42157001, 'Thresher Malted Milk Balls ', 'Chocolate Candy', 'Thresher', '$1.58')
# (42158001, 'Thresher Mint Chocolate Bar ', 'Chocolate Candy', 'Thresher', '$1.71')
# (42159001, 'Thresher Mints ', 'Hard Candy', 'Thresher', '$1.81')
# (42160001, 'Thresher Semi-Sweet Chocolate Bar ', 'Chocolate Candy', 'Thresher', '$1.87')
# (42161001, 'Thresher Spicy Mints ', 'Hard Candy', 'Thresher', '$3.65')
# (42162001, 'Thresher Tasty Candy Bar ', 'Chocolate Candy', 'Thresher', '$3.44')
# (42163001, 'Thresher White Chocolate Bar ', 'Chocolate Candy', 'Thresher', '$2.49')
# (42164001, 'Bagel Thins 100% Whole Wheat', 'Baked Goods Other than Bread', 'Thomas', '$2.50')
# (42165001, 'Bagel Thins Cinnamon Raisin', 'Baked Goods Other than Bread', 'Thomas', '$2.50')
# (42166001, 'Bagel Thins Everything', 'Baked Goods Other than Bread', 'Thomas', '$2.50')
# (42167001, 'Bagel Thins Plain', 'Baked Goods Other than Bread', 'Thomas', '$2.50')
# (42168001, 'Bagels 100% Whole Wheat Mini', 'Baked Goods Other than Bread', 'Thomas', '$3.00')
# (42169001, 'Bagels Blueberry', 'Baked Goods Other than Bread', 'Thomas', '$3.00')
# (42170001, 'Bagels Cinnamon Raisin', 'Baked Goods Other than Bread', 'Thomas', '$3.00')
# (42171001, 'Bagels Cinnamon Raisin Mini', 'Baked Goods Other than Bread', 'Thomas', '$3.00')
# (42172001, 'Bagels Everything', 'Baked Goods Other than Bread', 'Thomas', '$3.00')
# (42173001, 'Bagels Hearty Grains Whole Wheat', 'Baked Goods Other than Bread', 'Thomas', '$3.00')
# (42174001, 'Bagels Plain', 'Baked Goods Other than Bread', 'Thomas', '$3.00')
# (42175001, 'Bagels Plain Mini', 'Baked Goods Other than Bread', 'Thomas', '$3.00')
# (42176001, 'Bagels Plain Whole Grain', 'Baked Goods Other than Bread', 'Thomas', '$3.00')
# (42177001, 'English Muffins Double Fiber Honey Wheat', 'Baked Goods Other than Bread', 'Thomas', '$3.00')
# (42178001, 'English Muffins Hearty Grains 100% Whole Wheat', 'Baked Goods Other than Bread', 'Thomas', '$3.00')
# (42179001, 'English Muffins Multi Grain Light', 'Baked Goods Other than Bread', 'Thomas', '$3.00')
# (42180001, 'English Muffins Original', 'Baked Goods Other than Bread', 'Thomas', '$2.50')
# (42181001, 'English Muffins Original', 'Baked Goods Other than Bread', 'Thomas', '$5.49')
# (42182001, 'English Muffins Original Whole Grain With Omega 3', 'Baked Goods Other than Bread', 'Thomas', '$2.50')
# (42183001, 'English Muffins Raisin', 'Baked Goods Other than Bread', 'Thomas', '$2.50')
# (42184001, 'English Muffins Triple Health', 'Baked Goods Other than Bread', 'Thomas', '$3.00')
# (42185001, 'Tell Tale Almonds ', 'Nuts', 'Tell Tale', '$3.68')
# (42186001, 'Tell Tale Asparagus ', 'Fresh Vegetables', 'Tell Tale', '$3.64')
# (42187001, 'Tell Tale Baby Onion ', 'Fresh Vegetables', 'Tell Tale', '$2.66')
# (42188001, 'Tell Tale Beets ', 'Fresh Vegetables', 'Tell Tale', '$2.60')
# (42189001, 'Tell Tale Broccoli ', 'Fresh Vegetables', 'Tell Tale', '$1.81')
# (42190001, 'Tell Tale Canned Peanuts ', 'Nuts', 'Tell Tale', '$3.40')
# (42191001, 'Tell Tale Cantelope ', 'Fresh Fruit', 'Tell Tale', '$3.82')
# (42192001, 'Tell Tale Cauliflower ', 'Fresh Vegetables', 'Tell Tale', '$1.87')
# (42193001, 'Tell Tale Corn on the Cob ', 'Fresh Vegetables', 'Tell Tale', '$1.94')
# (42194001, 'Tell Tale Dried Mushrooms ', 'Fresh Vegetables', 'Tell Tale', '$1.45')
# (42195001, 'Tell Tale Elephant Garlic ', 'Fresh Vegetables', 'Tell Tale', '$2.64')
# (42196001, 'Tell Tale Fancy Plums ', 'Fresh Fruit', 'Tell Tale', '$0.68')
# (42197001, 'Tell Tale Firm Tofu ', 'Tofu', 'Tell Tale', '$1.67')
# (42198001, 'Tell Tale Fresh Lima Beans ', 'Fresh Vegetables', 'Tell Tale', '$3.17')
# (42199001, 'Tell Tale Fuji Apples ', 'Fresh Fruit', 'Tell Tale', '$3.63')
# (42200001, 'Tell Tale Garlic ', 'Fresh Vegetables', 'Tell Tale', '$1.17')
# (42201001, 'Tell Tale Golden Delcious Apples ', 'Fresh Fruit', 'Tell Tale', '$3.79')
# (42202001, 'Tell Tale Green Pepper ', 'Fresh Vegetables', 'Tell Tale', '$1.65')
# (42203001, 'Tell Tale Honey Dew ', 'Fresh Fruit', 'Tell Tale', '$2.80')
# (42204001, 'Tell Tale Lemons ', 'Fresh Fruit', 'Tell Tale', '$0.61')
# (42205001, 'Tell Tale Lettuce ', 'Fresh Vegetables', 'Tell Tale', '$1.77')
# (42206001, 'Tell Tale Limes ', 'Fresh Fruit', 'Tell Tale', '$1.84')
# (42207001, 'Tell Tale Macintosh Apples ', 'Fresh Fruit', 'Tell Tale', '$2.53')
# (42208001, 'Tell Tale Mandarin Oranges ', 'Fresh Fruit', 'Tell Tale', '$1.91')
# (42209001, 'Tell Tale Mixed Nuts ', 'Nuts', 'Tell Tale', '$1.85')
# (42210001, 'Tell Tale Mushrooms ', 'Fresh Vegetables', 'Tell Tale', '$2.96')
# (42211001, 'Tell Tale New Potatos ', 'Fresh Vegetables', 'Tell Tale', '$1.14')
# (42212001, 'Tell Tale Onions ', 'Fresh Vegetables', 'Tell Tale', '$2.41')
# (42213001, 'Tell Tale Oranges ', 'Fresh Fruit', 'Tell Tale', '$1.72')
# (42214001, 'Tell Tale Party Nuts ', 'Nuts', 'Tell Tale', '$2.85')
# (42215001, 'Tell Tale Peaches ', 'Fresh Fruit', 'Tell Tale', '$0.58')
# (42216001, 'Tell Tale Plums ', 'Fresh Fruit', 'Tell Tale', '$2.74')
# (42217001, 'Tell Tale Potatos ', 'Fresh Vegetables', 'Tell Tale', '$0.84')
# (42218001, 'Tell Tale Prepared Salad ', 'Fresh Vegetables', 'Tell Tale', '$2.59')
# (42219001, 'Tell Tale Red Delcious Apples ', 'Fresh Fruit', 'Tell Tale', '$1.90')
# (42220001, 'Tell Tale Red Pepper ', 'Fresh Vegetables', 'Tell Tale', '$1.93')
# (42221001, 'Tell Tale Shitake Mushrooms ', 'Fresh Vegetables', 'Tell Tale', '$3.51')
# (42222001, 'Tell Tale Squash ', 'Fresh Vegetables', 'Tell Tale', '$1.86')
# (42223001, 'Tell Tale Summer Squash ', 'Fresh Vegetables', 'Tell Tale', '$0.73')
# (42224001, 'Tell Tale Sweet Onion ', 'Fresh Vegetables', 'Tell Tale', '$1.36')
# (42225001, 'Tell Tale Sweet Peas ', 'Fresh Vegetables', 'Tell Tale', '$2.19')
# (42226001, 'Tell Tale Tangerines ', 'Fresh Fruit', 'Tell Tale', '$1.74')
# (42227001, 'Tell Tale Tomatos ', 'Fresh Vegetables', 'Tell Tale', '$2.55')
# (42228001, 'Tell Tale Walnuts ', 'Nuts', 'Tell Tale', '$1.63')
# (42229001, 'Cake Dreamies Creme Kakes', 'Baked Goods Other than Bread', 'Tastykake', '$3.00')
# (42230001, 'Cake Kandy Kake Peanut Butter', 'Baked Goods Other than Bread', 'Tastykake', '$3.00')
# (42231001, 'Cake Koffee Kake Cream Filled', 'Baked Goods Other than Bread', 'Tastykake', '$3.00')
# (42232001, 'Cupcakes Buttercream', 'Baked Goods Other than Bread', 'Tastykake', '$3.00')
# (42233001, 'Cupcakes Chocolate', 'Baked Goods Other than Bread', 'Tastykake', '$3.00')
# (42234001, 'Cupcakes Krimpet Butterscotch', 'Baked Goods Other than Bread', 'Tastykake', '$3.00')
# (42235001, 'Cupcakes Lemon', 'Baked Goods Other than Bread', 'Tastykake', '$3.00')
# (42236001, 'Pie Apple', 'Baked Goods Other than Bread', 'Tastykake', '$1.00')
# (42237001, 'Pie Cherry', 'Baked Goods Other than Bread', 'Tastykake', '$1.00')
# (42238001, 'Pie Chocolate Klair', 'Baked Goods Other than Bread', 'Tastykake', '$1.00')
# (42239001, 'Pie Lemon', 'Baked Goods Other than Bread', 'Tastykake', '$1.00')
# (42240001, 'Pie Peach', 'Baked Goods Other than Bread', 'Tastykake', '$1.00')
# (42241001, 'Hot Cocoa Mix Marshmallows', '', 'Swiss Miss', '$3.09')
# (42242001, 'Hot Cocoa Mix Milk Chocolate', 'Soda/Juice/Drinks', 'Swiss Miss', '$3.09')
# (42243001, 'Hot Cocoa Mix Milk Chocolate Canister', 'Soda/Juice/Drinks', 'Swiss Miss', '$7.69')
# (42244001, 'Hot Cocoa Mix Milk Chocolate No Sugar Added', 'Soda/Juice/Drinks', 'Swiss Miss', '$3.59')
# (42245001, 'Swell Canned Mixed Fruit ', 'Canned Fruit', 'Swell', '$2.34')
# (42246001, 'Swell Canned Peaches ', 'Canned Fruit', 'Swell', '$1.63')
# (42247001, 'Super Brown Sugar ', 'Sugar', 'Super', '$1.42')
# (42248001, 'Super Canola Oil ', 'Cooking Oil', 'Super', '$1.32')
# (42249001, 'Super Chunky Peanut Butter ', 'Peanut Butter', 'Super', '$0.99')
# (42250001, 'Super Corn Oil ', 'Cooking Oil', 'Super', '$1.81')
# (42251001, 'Super Creamy Peanut Butter ', 'Peanut Butter', 'Super', '$1.48')
# (42252001, 'Super Extra Chunky Peanut Butter ', 'Peanut Butter', 'Super', '$3.62')
# (42253001, 'Super Oregano ', 'Spices', 'Super', '$3.45')
# (42254001, 'Super Pepper ', 'Spices', 'Super', '$2.83')
# (42255001, 'Super Salt ', 'Spices', 'Super', '$2.94')
# (42256001, 'Super Sesame Oil ', 'Cooking Oil', 'Super', '$2.73')
# (42257001, 'Super Vegetable Oil ', 'Cooking Oil', 'Super', '$2.22')
# (42258001, 'Super White Sugar ', 'Sugar', 'Super', '$1.56')
# (42259001, 'Sunset Counter Cleaner ', 'Cleaners', 'Sunset', '$0.83')
# (42260001, 'Sunset Glass Cleaner ', 'Cleaners', 'Sunset', '$1.85')
# (42261001, 'Sunset Room Freshener ', 'Deodorizers', 'Sunset', '$2.44')
# (42262001, 'Sunset Toilet Bowl Cleaner ', 'Cleaners', 'Sunset', '$1.16')
# (42263001, 'Sunny Delight Original', '', 'Sunny Delight Drinks', '$2.99')
# (42264001, 'Orange Citrus Punch Smooth', '', 'Sunny D', '$2.19')
# (42265001, 'Orange Citrus Punch Tangy Original', '', 'Sunny D', '$3.89')
# (42266001, 'Bread Raisin', 'Bread', 'Sun-Maid', '$3.29')
# (42267001, 'Giant Bread', 'Bread', 'Sunbeam', '$1.69')
# (42268001, 'BBQ Sauce Original', '', 'Stubbs', '$3.99')
# (42269001, 'Bread Honey Wheat', 'Bread', 'Stroehmann', '$1.99')
# (42270001, 'Stuffing Mix Pork', '', 'Stove Top', '$2.09')
# (42271001, 'Lasagna With Meat And Sauce Pasta', 'Frozen Food', "Stouffer's", '$7.98')
# (42272001, 'Sandwich Steaks Thin Sliced', '', 'Steakumm', '$4.39')
# (42273001, 'Steady 200 MG Acetominifen ', 'Acetominifen', 'Steady', '$1.53')
# (42274001, 'Steady 200 MG Ibuprofen ', 'Ibuprofen', 'Steady', '$2.83')
# (42275001, 'Steady Buffered Aspirin ', 'Aspirin', 'Steady', '$1.42')
# (42276001, 'Steady Childrens Aspirin ', 'Aspirin', 'Steady', '$1.74')
# (42277001, 'Steady Mint Mouthwash ', 'Mouthwash', 'Steady', '$2.24')
# (42278001, 'Chunk Light Tuna Water (pouch)', '', 'Starkist', '$2.29')
# (42279001, 'Coffee Blonde Veranda', 'Coffee/Creamer', 'Starbucks', '$14.29')
# (42280001, 'Coffee Breakfast Blend', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42281001, 'Coffee Caffe Verona', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42282001, 'Coffee Caffe Verona Decaf', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42283001, 'Coffee Caramel', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42284001, 'Coffee Colombia', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42285001, 'Coffee Espresso', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42286001, 'Coffee French Roast', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42287001, 'Coffee French Roast', 'Coffee/Creamer', 'Starbucks', '$14.29')
# (42288001, 'Coffee Gold Coast Blend', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42289001, 'Coffee House Blend', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42290001, 'Coffee House Blend', 'Coffee/Creamer', 'Starbucks', '$14.29')
# (42291001, 'Coffee House Blend Decaf', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42292001, 'Coffee Italian', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42293001, 'Coffee Mocha', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42294001, 'Coffee Pike Place', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42295001, 'Coffee Sumatra', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42296001, 'Coffee Veranda Blend', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42297001, 'Coffee Willow Blend', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42298001, 'Coffee Willow Blend Decaf', 'Coffee/Creamer', 'Starbucks', '$7.99')
# (42299001, 'Hot Cocoa Mix Premium Double Chocolate', '', 'Starbucks', '$6.59')
# (42300001, 'Hot Cocoa Mix Salted Caramel', '', 'Starbucks', '$6.59')
# (42301001, 'Hot Cocoa Mix Vanilla Brulee', '', 'Starbucks', '$6.59')
# (42302001, 'Vinegar Balsamic', '', 'Star', '$2.99')
# (42303001, 'Sparkling Spring Water Pomegranate Berry', '', 'Sparkling ICE', '$1.19')
# (42304001, 'Soy Milk Vanilla', 'Soda/Juice/Drinks', 'Soy Dream', '$4.79')
# (42305001, 'Baby Lotion Original', '', 'Soft & Precious', '$2.99')
# (42306001, 'Hair Moist Creme', '', 'Soft & Precious', '$3.99')
# (42307001, 'Hair Moisturizer Detangling', '', 'Soft & Precious', '$3.99')
# (42308001, 'Tortilla Chips Original', '', 'Snyders Of Hanover', '$2.99')
# (42309001, 'Singles To Go Diet Green Tea', '', 'Snapple', '$0.99')
# (42310001, 'Singles To Go Diet Lemon', '', 'Snapple', '$0.99')
# (42311001, 'Jam Grape', 'Jelly/Jam', 'Smuckers', '$2.29')
# (42312001, 'Jam Strawberry', 'Jelly/Jam', 'Smuckers', '$3.09')
# (42313001, 'Jelly Grape', 'Jelly/Jam', 'Smuckers', '$2.29')
# (42314001, 'Squeeze Jelly Grape', 'Jelly/Jam', 'Smuckers', '$2.14')
# (42315001, 'Peanut Butter Crunchy', 'Peanut Butter', 'Skippy', '$3.99')
# (42316001, 'Peanut Butter Smooth', 'Peanut Butter', 'Skippy', '$3.99')
# (42317001, 'Pasta Sauce Tomato Basil', 'Gravy/Sauce', 'Simple Truth Organic', '$1.99')
# (42318001, 'Almond Milk Original', 'Soda/Juice/Drinks', 'Silk', '$3.69')
# (42319001, 'Soymilk Light Chocolate', 'Soda/Juice/Drinks', 'Silk', '$3.69')
# (42320001, 'Ship Shape Extra Lean Hamburger ', 'Hamburger', 'Ship Shape', '$2.97')
# (42321001, 'Ship Shape Seasoned Hamburger ', 'Hamburger', 'Ship Shape', '$1.75')
# (42322001, 'Shady Lake Rice Medly ', 'Rice', 'Shady Lake', '$0.70')
# (42323001, 'Shady Lake Thai Rice ', 'Rice', 'Shady Lake', '$2.81')
# (42324001, 'Coffee Level 3', 'Coffee/Creamer', 'Seattles Best', '$6.99')
# (42325001, 'Coffee Level 4', 'Coffee/Creamer', 'Seattles Best', '$6.99')
# (42326001, 'Coffee Level 5', 'Coffee/Creamer', 'Seattles Best', '$6.99')
# (42327001, 'All Purpose Cleaner Bleach 5-in-1', '', 'Scrubbing Bubbles', '$3.19')
# (42328001, 'Shower Automatic Refill Liquid Shower Cleaner', '', 'Scrubbing Bubbles', '$9.00')
# (42329001, 'Sponges Blue', '', 'Scotch-Brite', '$2.49')
# (42330001, 'English Muffins Original', '', 'Schmidt Old Tyme', '$1.49')
# (42331001, 'Bread Amazin Raisin', 'Bread', 'Schmidt', '$4.39')
# (42332001, 'Tastings Medium Asiago', '', 'Sargento', '$2.79')
# (42333001, 'Tastings Parmentino', '', 'Sargento', '$2.99')
# (42334001, 'Flatbread Angus Cheeseburgers', 'Bread', 'Sandwich Bros', '$2.99')
# (42335001, 'Flatbread Chicken Melts', 'Bread', 'Sandwich Bros', '$2.99')
# (42336001, 'Bran Flakes Cereal', 'Cereal', 'Safeway Kitchens', '$2.49')
# (42337001, 'Coffee 100% Colombian', 'Coffee/Creamer', 'Safeway Kitchens', '$3.29')
# (42338001, 'Coffee 100% Colombian', 'Coffee/Creamer', 'Safeway Kitchens', '$6.99')
# (42339001, 'Coffee Classic Decaf', 'Coffee/Creamer', 'Safeway Kitchens', '$3.79')
# (42340001, 'Coffee Classic Decaf', 'Coffee/Creamer', 'Safeway Kitchens', '$6.99')
# (42341001, 'Coffee Classic Regular', 'Coffee/Creamer', 'Safeway Kitchens', '$3.29')
# (42342001, 'Coffee Classic Regular', 'Coffee/Creamer', 'Safeway Kitchens', '$6.99')
# (42343001, 'Coffee French Roast', 'Coffee/Creamer', 'Safeway Kitchens', '$3.29')
# (42344001, 'Coffee French Roast', 'Coffee/Creamer', 'Safeway Kitchens', '$6.99')
# (42345001, 'Coffee Half The Caffeine', 'Coffee/Creamer', 'Safeway Kitchens', '$3.29')
# (42346001, 'Corn Flakes Cereal', 'Cereal', 'Safeway Kitchens', '$2.49')
# (42347001, 'Crispy Rice Cereal', 'Cereal', 'Safeway Kitchens', '$2.19')
# (42348001, 'Honey Nut Toasted Oats Cereal', 'Cereal', 'Safeway Kitchens', '$2.19')
# (42349001, 'Bread Raisin', 'Bread', 'Safeway', '$2.19')
# (42350001, 'Bread Texas Toast', 'Bread', 'Safeway', '$2.19')
# (42351001, 'Coffee Breakfast Blend', 'Coffee/Creamer', 'Safeway', '$5.99')
# (42352001, 'Coffee Buttery Caramel', 'Coffee/Creamer', 'Safeway', '$5.99')
# (42353001, 'Coffee Half Caf French', 'Coffee/Creamer', 'Safeway', '$5.99')
# (42354001, 'Juice Just Black Cherry', '', 'RW Knudsen', '$8.69')
# (42355001, '1.00% Milk', 'Milk', 'Rowan Dairy', '$3.69')
# (42356001, '1.00% Milk', 'Milk', 'Rowan Dairy', '$1.89')
# (42357001, '2.00% Milk', 'Milk', 'Rowan Dairy', '$3.69')
# (42358001, '2.00% Milk', 'Milk', 'Rowan Dairy', '$1.89')
# (42359001, 'Whole Milk Milk', 'Milk', 'Rowan Dairy', '$3.69')
# (42360001, 'Whole Milk Milk', 'Milk', 'Rowan Dairy', '$1.89')
# (42361001, 'Cola Soda', 'Soda', 'Rowan Brand', '$0.99')
# (42362001, 'Sugar White', '', 'Rowan', '$1.69')
# (42363001, 'Honey Wheat Rods Pretzels', 'Snacks', 'Rolled Gold', '$3.29')
# (42364001, 'Peanut Butter Cups King Size', 'Candy', 'Reeses', '$1.69')
# (42365001, 'Red Wing Counter Cleaner ', 'Cleaners', 'Red Wing', '$0.93')
# (42366001, 'Red Wing Glass Cleaner ', 'Cleaners', 'Red Wing', '$1.68')
# (42367001, 'Red Wing Room Freshener ', 'Deodorizers', 'Red Wing', '$2.95')
# (42368001, 'Red Wing Toilet Bowl Cleaner ', 'Cleaners', 'Red Wing', '$2.92')
# (42369001, 'Red Spade Beef Bologna ', 'Bologna', 'Red Spade', '$3.76')
# (42370001, 'Red Spade Chicken Hot Dogs ', 'Hot Dogs', 'Red Spade', '$2.95')
# (42371001, 'Red Spade Cole Slaw ', 'Deli Salads', 'Red Spade', '$0.97')
# (42372001, 'Red Spade Corned Beef ', 'Deli Meats', 'Red Spade', '$2.74')
# (42373001, 'Red Spade Foot-Long Hot Dogs ', 'Hot Dogs', 'Red Spade', '$3.56')
# (42374001, 'Red Spade Low Fat Bologna ', 'Bologna', 'Red Spade', '$3.44')
# (42375001, 'Red Spade Low Fat Cole Slaw ', 'Deli Salads', 'Red Spade', '$3.10')
# (42376001, 'Red Spade Pimento Loaf ', 'Bologna', 'Red Spade', '$1.61')
# (42377001, 'Red Spade Potato Salad ', 'Deli Salads', 'Red Spade', '$0.68')
# (42378001, 'Red Spade Roasted Chicken ', 'Fresh Chicken', 'Red Spade', '$2.76')
# (42379001, 'Red Spade Sliced Chicken ', 'Deli Meats', 'Red Spade', '$1.69')
# (42380001, 'Red Spade Sliced Ham ', 'Deli Meats', 'Red Spade', '$1.57')
# (42381001, 'Red Spade Sliced Turkey ', 'Deli Meats', 'Red Spade', '$2.33')
# (42382001, 'Red Spade Turkey Hot Dogs ', 'Hot Dogs', 'Red Spade', '$1.86')
# (42383001, 'Stone Wheat Thins Original', 'Snacks', 'Red Oval Farms', '$4.19')
# (42384001, 'Just Black Cherry Juice', '', 'R.W. Knudsen', '$3.35')
# (42385001, 'Quick Extra Lean Hamburger ', 'Hamburger', 'Quick', '$2.61')
# (42386001, 'Quick Seasoned Hamburger ', 'Hamburger', 'Quick', '$3.64')
# (42387001, 'Apple Nut Harvest Real Medley Bars', 'Snacks', 'Quaker', '$3.50')
# (42388001, 'Cherry Pistachio Real Medley Bars', 'Snacks', 'Quaker', '$3.50')
# (42389001, 'Granola Bars Chewy Chocolate Chip', 'Snacks', 'Quaker', '$2.50')
# (42390001, 'Life Cereal', 'Cereal', 'Quaker', '$2.50')
# (42391001, 'Life Cinnamon Cereal', 'Cereal', 'Quaker', '$2.50')
# (42392001, 'Ohs Honey Graham Cereal', 'Cereal', 'Quaker', '$2.99')
# (42393001, 'Peach Almond Real Medley Bars', 'Snacks', 'Quaker', '$3.50')
# (42394001, 'Yogurt Strawberry Chewy Granola Bars', 'Snacks', 'Quaker', '$2.50')
# (42395001, 'Sausage Pork', '', 'Purnell', '$3.29')
# (42396001, 'Lettuce Head', 'Produce', 'Produce', '$1.09')
# (42397001, 'Turnip Greens Vegetables', 'Produce', 'Produce', '$1.29')
# (42398001, 'Mocha Coffee', 'Coffee/Creamer', 'Private Selection', '$4.99')
# (42399001, 'Bacon Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42400001, 'BBQ Grab & Go', 'Snacks', 'Pringles', '$1.00')
# (42401001, 'BBQ Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42402001, 'Buffalo Ranch Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42403001, 'Cheddar & Sour Cream Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42404001, 'Cheddar Cheese Grab & Go', 'Snacks', 'Pringles', '$1.00')
# (42405001, 'Cheddar Cheese Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42406001, 'Cheese Burger Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42407001, 'Honey Butter Stix', 'Snacks', 'Pringles', '$3.19')
# (42408001, 'Honey Mustard Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42409001, 'Jalapeno Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42410001, 'Lightly Salted Cheddar Cheese Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42411001, 'Lightly Salted Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42412001, 'Loaded Baked Potato Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42413001, 'Loud Fiery Chili Lime Corn Crisps', 'Snacks', 'Pringles', '$1.67')
# (42414001, 'Loud Mighty Margherita Pizza Grain & Vegetable Crisps', 'Snacks', 'Pringles', '$1.67')
# (42415001, 'Loud Salsa Fiesta Corn Crisps', 'Snacks', 'Pringles', '$1.67')
# (42416001, 'Loud Spicy Queso Corn Crisps', 'Snacks', 'Pringles', '$1.67')
# (42417001, 'Loud Super Cheesy Italian Grain & Vegetable Crisps', 'Snacks', 'Pringles', '$1.67')
# (42418001, 'Memphis BBQ Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42419001, 'Mixed Flavors Snack Stacks', 'Snacks', 'Pringles', '$9.19')
# (42420001, 'Original Fat Free Potato Chips', 'Snacks', 'Pringles', '$2.98')
# (42421001, 'Original Grab & Go', 'Snacks', 'Pringles', '$1.00')
# (42422001, 'Original Potato Crisps', 'Snacks', 'Pringles', '$5.29')
# (42423001, 'Original Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42424001, 'Pizza Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42425001, 'Pizza Stix', 'Snacks', 'Pringles', '$3.19')
# (42426001, 'Ranch Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42427001, 'Reduced Fat Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42428001, 'Reduced Fat Sour Cream & Onion Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42429001, 'Salt & Vinegar Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42430001, 'Screamin Dill Pickle Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42431001, 'Sour Cream & Onion Grab & Go', 'Snacks', 'Pringles', '$1.00')
# (42432001, 'Sour Cream & Onion Potato Crisps', 'Snacks', 'Pringles', '$1.67')
# (42433001, 'Sour Cream & Onion Stacks', 'Snacks', 'Pringles', '$5.00')
# (42434001, 'Variety Pack Grab & Go', 'Snacks', 'Pringles', '$8.99')
# (42435001, 'Zero Fruit Punch', '', 'Powerade', '$0.89')
# (42436001, 'Zero Grape', '', 'Powerade', '$0.89')
# (42437001, 'Zero Mixed Berry', '', 'Powerade', '$0.89')
# (42438001, 'Zero Orange', '', 'Powerade', '$0.89')
# (42439001, 'Fruity Pebbles Cereal', 'Cereal', 'Post', '$3.28')
# (42440001, 'Great Grains Crunchy Pecan Cereal', 'Cereal', 'Post', '$4.39')
# (42441001, 'Great Grains Date Pecan Raisin Cereal', 'Cereal', 'Post', '$4.39')
# (42442001, 'Honey Bunches Of Oat Honey Roasted Cereal', 'Cereal', 'Post', '$2.99')
# (42443001, 'Honey Bunches Of Oats Almond Cereal', 'Cereal', 'Post', '$4.39')
# (42444001, 'Honey Bunches Of Oats Greek Honey Crunch Cereal', 'Cereal', 'Post', '$4.39')
# (42445001, 'Honey Bunches Of Oats Honet Roasted Cereal', 'Cereal', 'Post', '$4.39')
# (42446001, 'Honey Bunches Of Oats Honey Roasted Cereal', 'Cereal', 'Post', '$8.79')
# (42447001, 'Honey Bunches Of Oats Morning Energy Chocolate Almond Crunch Cereal', 'Cereal', 'Post', '$4.39')
# (42448001, 'Honey Bunches Of Oats Morning Energy Cinnamon Crunch Cereal', 'Cereal', 'Post', '$4.39')
# (42449001, 'Honey Bunches Of Oats Strawberry Cereal', 'Cereal', 'Post', '$4.39')
# (42450001, 'Honey Bunches Of Oats With Almonds Cereal', 'Cereal', 'Post', '$2.99')
# (42451001, 'Pleasant Beef Soup ', 'Soup', 'Pleasant', '$1.43')
# (42452001, 'Pleasant Canned Beets ', 'Canned Vegetables', 'Pleasant', '$0.72')
# (42453001, 'Pleasant Canned Peas ', 'Canned Vegetables', 'Pleasant', '$2.54')
# (42454001, 'Pleasant Canned String Beans ', 'Canned Vegetables', 'Pleasant', '$1.60')
# (42455001, 'Pleasant Canned Tomatos ', 'Canned Vegetables', 'Pleasant', '$3.50')
# (42456001, 'Pleasant Canned Tuna in Oil ', 'Tuna', 'Pleasant', '$1.37')
# (42457001, 'Pleasant Canned Tuna in Water ', 'Tuna', 'Pleasant', '$2.96')
# (42458001, 'Pleasant Canned Yams ', 'Canned Vegetables', 'Pleasant', '$3.97')
# (42459001, 'Pleasant Chicken Noodle Soup ', 'Soup', 'Pleasant', '$1.31')
# (42460001, 'Pleasant Chicken Ramen Soup ', 'Soup', 'Pleasant', '$2.82')
# (42461001, 'Pleasant Chicken Soup ', 'Soup', 'Pleasant', '$1.30')
# (42462001, 'Pleasant Creamed Corn ', 'Canned Vegetables', 'Pleasant', '$1.18')
# (42463001, 'Pleasant Noodle Soup ', 'Soup', 'Pleasant', '$2.48')
# (42464001, 'Pleasant Regular Ramen Soup ', 'Soup', 'Pleasant', '$3.31')
# (42465001, 'Pleasant Rice Soup ', 'Soup', 'Pleasant', '$0.90')
# (42466001, 'Pleasant Turkey Noodle Soup ', 'Soup', 'Pleasant', '$1.17')
# (42467001, 'Pleasant Vegetable Soup ', 'Soup', 'Pleasant', '$2.69')
# (42468001, 'Plato Brown Sugar ', 'Sugar', 'Plato', '$1.24')
# (42469001, 'Plato Canola Oil ', 'Cooking Oil', 'Plato', '$1.13')
# (42470001, 'Plato Chunky Peanut Butter ', 'Peanut Butter', 'Plato', '$2.45')
# (42471001, 'Plato Corn Oil ', 'Cooking Oil', 'Plato', '$0.77')
# (42472001, 'Plato Creamy Peanut Butter ', 'Peanut Butter', 'Plato', '$2.32')
# (42473001, 'Plato Extra Chunky Peanut Butter ', 'Peanut Butter', 'Plato', '$1.68')
# (42474001, 'Plato Oregano ', 'Spices', 'Plato', '$2.26')
# (42475001, 'Plato Pepper ', 'Spices', 'Plato', '$3.32')
# (42476001, 'Plato Salt ', 'Spices', 'Plato', '$1.47')
# (42477001, 'Plato Sesame Oil ', 'Cooking Oil', 'Plato', '$1.49')
# (42478001, 'Plato Vegetable Oil ', 'Cooking Oil', 'Plato', '$1.30')
# (42479001, 'Plato White Sugar ', 'Sugar', 'Plato', '$1.72')
# (42480001, 'Grands Biscuits Buttermilk', 'Other Dairy/Not Milk', 'Pillsbury', '$3.99')
# (42481001, 'Grands Biscuits Flaky Layers Buttermilk', 'Other Dairy/Not Milk', 'Pillsbury', '$1.99')
# (42482001, 'Grands Biscuits Southern Homestyle Buttermilk', 'Other Dairy/Not Milk', 'Pillsbury', '$1.59')
# (42483001, 'Grands Biscuits Southern Homestyle Buttermilk', 'Other Dairy/Not Milk', 'Pillsbury', '$1.99')
# (42484001, 'Grands Junior Biscuits Flaky Layers Buttermilk', 'Other Dairy/Not Milk', 'Pillsbury', '$1.29')
# (42485001, 'PigTail Beef TV Dinner ', 'TV Dinner', 'PigTail', '$2.14')
# (42486001, 'PigTail Chicken TV Dinner ', 'TV Dinner', 'PigTail', '$1.11')
# (42487001, 'PigTail Fajita French Fries ', 'French Fries', 'PigTail', '$2.31')
# (42488001, 'PigTail Frozen Broccoli ', 'Frozen Vegetables', 'PigTail', '$1.27')
# (42489001, 'PigTail Frozen Carrots ', 'Frozen Vegetables', 'PigTail', '$1.91')
# (42490001, 'PigTail Frozen Cauliflower ', 'Frozen Vegetables', 'PigTail', '$1.57')
# (42491001, 'PigTail Frozen Cheese Pizza ', 'Pizza', 'PigTail', '$2.64')
# (42492001, 'PigTail Frozen Chicken Breast ', 'Frozen Chicken', 'PigTail', '$1.51')
# (42493001, 'PigTail Frozen Chicken Thighs ', 'Frozen Chicken', 'PigTail', '$2.21')
# (42494001, 'PigTail Frozen Chicken Wings ', 'Frozen Chicken', 'PigTail', '$3.93')
# (42495001, 'PigTail Frozen Corn ', 'Frozen Vegetables', 'PigTail', '$3.70')
# (42496001, 'PigTail Frozen Mushroom Pizza ', 'Pizza', 'PigTail', '$1.21')
# (42497001, 'PigTail Frozen Peas ', 'Frozen Vegetables', 'PigTail', '$1.66')
# (42498001, 'PigTail Frozen Pepperoni Pizza ', 'Pizza', 'PigTail', '$1.68')
# (42499001, 'PigTail Frozen Sausage Pizza ', 'Pizza', 'PigTail', '$1.45')
# (42500001, 'PigTail Grape Popsicles ', 'Popsicles', 'PigTail', '$0.74')
# (42501001, 'PigTail Home Style French Fries ', 'French Fries', 'PigTail', '$0.81')
# (42502001, 'PigTail Ice Cream ', 'Ice Cream', 'PigTail', '$0.71')
# (42503001, 'PigTail Ice Cream Sandwich ', 'Ice Cream', 'PigTail', '$1.15')
# (42504001, 'PigTail Lemon Popsicles ', 'Popsicles', 'PigTail', '$1.28')
# (42505001, 'PigTail Lime Popsicles ', 'Popsicles', 'PigTail', '$1.32')
# (42506001, 'PigTail Low Fat French Fries ', 'French Fries', 'PigTail', '$3.95')
# (42507001, 'PigTail Orange Popsicles ', 'Popsicles', 'PigTail', '$1.22')
# (42508001, 'PigTail Turkey TV Dinner ', 'TV Dinner', 'PigTail', '$2.91')
# (42509001, 'Hamburgers Pure Beef', '', 'Philly Gourmet', '$9.99')
# (42510001, 'Hamburgers Pure Beef', '', 'Philly Gourmet', '$19.99')
# (42511001, 'Evaporated Milk Original', 'Baking Supplies', 'Pet', '$1.79')
# (42512001, 'Diet Soda', 'Soda', 'Pepsi', '$1.50')
# (42513001, 'Original Soda', 'Soda', 'Pepsi', '$1.50')
# (42514001, 'Bagels Everything', '', 'Pepperidge Farm', '$4.29')
# (42515001, 'Bagels Mini/Brown Sugar Cinnamon', '', 'Pepperidge Farm', '$4.29')
# (42516001, 'Bagels Mini/Cinnamon Raisin', '', 'Pepperidge Farm', '$4.29')
# (42517001, 'Bagels Mini/Plain', '', 'Pepperidge Farm', '$4.29')
# (42518001, 'Bagels Mini/Whole Wheat', '', 'Pepperidge Farm', '$4.29')
# (42519001, 'Bagels Pre-Sliced/Plain', '', 'Pepperidge Farm', '$4.29')
# (42520001, 'Bread Cinnamon Swirl', 'Bread', 'Pepperidge Farm', '$3.99')
# (42521001, 'Bread Swirl Brown Sugar Cinnamon', 'Bread', 'Pepperidge Farm', '$3.99')
# (42522001, 'Bread Swirl Raisin Cinnamon', 'Bread', 'Pepperidge Farm', '$3.99')
# (42523001, 'Bread White Original', 'Bread', 'Pepperidge Farm', '$3.49')
# (42524001, 'Bread White Sandwich', 'Bread', 'Pepperidge Farm', '$3.49')
# (42525001, 'Bread Whole Wheat Cinnamon Swirl', 'Bread', 'Pepperidge Farm', '$3.99')
# (42526001, 'Farmhouse Bread Hearty White', 'Bread', 'Pepperidge Farm', '$3.99')
# (42527001, 'Farmhouse Bread Oatmeal', 'Bread', 'Pepperidge Farm', '$3.99')
# (42528001, 'Farmhouse Bread Potato', 'Bread', 'Pepperidge Farm', '$3.99')
# (42529001, 'Farmhouse Bread Sourdough', 'Bread', 'Pepperidge Farm', '$3.99')
# (42530001, 'Goldfish Baby Cheddar', '', 'Pepperidge Farm', '$2.19')
# (42531001, 'Goldfish Blasted Burstin BBQ', '', 'Pepperidge Farm', '$2.19')
# (42532001, 'Goldfish Blasted Cheddar', '', 'Pepperidge Farm', '$5.49')
# (42533001, 'Goldfish Blasted Slammin Sour Cream & Onion', '', 'Pepperidge Farm', '$2.19')
# (42534001, 'Goldfish Blasted Xplosive Pizza', '', 'Pepperidge Farm', '$2.19')
# (42535001, 'Goldfish Blasted Xtra Cheddar', '', 'Pepperidge Farm', '$3.99')
# (42536001, 'Goldfish Blasted Xtra Cheddar', '', 'Pepperidge Farm', '$8.99')
# (42537001, 'Goldfish Blasted Xtra Cheddar', '', 'Pepperidge Farm', '$2.19')
# (42538001, 'Goldfish Cheddar', '', 'Pepperidge Farm', '$1.09')
# (42539001, 'Goldfish Cheddar', '', 'Pepperidge Farm', '$8.69')
# (42540001, 'Goldfish Cheddar', '', 'Pepperidge Farm', '$2.19')
# (42541001, 'Goldfish Cheddar Colors', '', 'Pepperidge Farm', '$2.19')
# (42542001, 'Goldfish Grahams Cookies And Creme', '', 'Pepperidge Farm', '$2.19')
# (42543001, 'Goldfish Grahams Smores', '', 'Pepperidge Farm', '$2.19')
# (42544001, 'Goldfish Grahams Vanilla Cupcake', '', 'Pepperidge Farm', '$2.19')
# (42545001, 'Goldfish Mix Extra Cheddar & Pretzel', '', 'Pepperidge Farm', '$8.99')
# (42546001, 'Goldfish Mix Extra Cheddar + Pretzel', '', 'Pepperidge Farm', '$2.19')
# (42547001, 'Goldfish Mix Honey Mustard + Pretzel', '', 'Pepperidge Farm', '$2.19')
# (42548001, 'Goldfish Organic Wheat Cheddar Lunch Packs', '', 'Pepperidge Farm', '$5.49')
# (42549001, 'Goldfish Parmesan', '', 'Pepperidge Farm', '$2.19')
# (42550001, 'Goldfish Pizza', '', 'Pepperidge Farm', '$2.19')
# (42551001, 'Goldfish Pretzel', '', 'Pepperidge Farm', '$2.19')
# (42552001, 'Goldfish Princess', '', 'Pepperidge Farm', '$1.09')
# (42553001, 'Goldfish Princess', '', 'Pepperidge Farm', '$2.19')
# (42554001, 'Goldfish Saltine', '', 'Pepperidge Farm', '$2.19')
# (42555001, 'Goldfish Sweet & Savory', '', 'Pepperidge Farm', '$8.69')
# (42556001, 'Goldfish Whole Grain Cheddar', '', 'Pepperidge Farm', '$2.19')
# (42557001, 'Goldfish Whole Grain Cheddar Colors', '', 'Pepperidge Farm', '$2.19')
# (42558001, 'Goldfish Whole Grain Cinnamon', '', 'Pepperidge Farm', '$2.19')
# (42559001, 'Goldfish Whole Grain Honey Grahams', '', 'Pepperidge Farm', '$2.19')
# (42560001, 'Goldfish Whole Grain Pretzel', '', 'Pepperidge Farm', '$2.19')
# (42561001, 'Goldfish Whole Grain Xtra Cheddar', '', 'Pepperidge Farm', '$2.19')
# (42562001, 'Italian Bread With Sesame Seeds', 'Bread', 'Pepperidge Farm', '$2.69')
# (42563001, 'Jewish Pumpernickel Dark Pump', 'Bread', 'Pepperidge Farm', '$3.79')
# (42564001, 'Jewish Rye & Pumpernickel Deli Swirl', 'Bread', 'Pepperidge Farm', '$3.79')
# (42565001, 'Jewish Rye Seeded', '', 'Pepperidge Farm', '$3.79')
# (42566001, 'Jewish Rye Seedless', 'Bread', 'Pepperidge Farm', '$3.79')
# (42567001, 'Light Style Bread 7 Grain', 'Bread', 'Pepperidge Farm', '$3.99')
# (42568001, 'Light Style Bread Soft Wheat', 'Bread', 'Pepperidge Farm', '$3.99')
# (42569001, 'Stuffing Corn Bread', 'Stuffing', 'Pepperidge Farm', '$2.99')
# (42570001, 'Swirl Bread Blueberry', 'Bread', 'Pepperidge Farm', '$3.99')
# (42571001, 'Swirl Bread Brown Sugar Cinnamon', 'Bread', 'Pepperidge Farm', '$3.99')
# (42572001, 'Swirl Bread Cinnamon', 'Bread', 'Pepperidge Farm', '$3.99')
# (42573001, 'Swirl Bread French Toast', 'Bread', 'Pepperidge Farm', '$3.99')
# (42574001, 'Swirl Bread Raisin Cinnamon', 'Bread', 'Pepperidge Farm', '$3.99')
# (42575001, 'Swirl Bread Strawberry', 'Bread', 'Pepperidge Farm', '$3.99')
# (42576001, 'Swirl Oatmeal Bread Apple & Cinnamon', 'Bread', 'Pepperidge Farm', '$4.29')
# (42577001, 'Swirl Oatmeal Bread Maple & Brown Sugar', 'Bread', 'Pepperidge Farm', '$4.29')
# (42578001, 'Texas Toast 5 Cheese', '', 'Pepperidge Farm', '$2.59')
# (42579001, 'Texas Toast Garlic', '', 'Pepperidge Farm', '$3.39')
# (42580001, 'Very Thin Bread 100% Whole Wheat', 'Bread', 'Pepperidge Farm', '$3.79')
# (42581001, 'Very Thin Bread White', 'Bread', 'Pepperidge Farm', '$3.79')
# (42582001, 'Whole Grain Bread 100% Wheat Bread', 'Bread', 'Pepperidge Farm', '$4.29')
# (42583001, 'Whole Grain Bread 15 Grain', 'Bread', 'Pepperidge Farm', '$4.29')
# (42584001, 'Whole Grain Bread Honey Wheat', 'Bread', 'Pepperidge Farm', '$4.29')
# (42585001, 'Anniversary Blend Coffee', 'Coffee/Creamer', 'Peets', '$10.99')
# (42586001, 'Cafe Domingo Coffee', 'Coffee/Creamer', 'Peets', '$10.99')
# (42587001, 'Cafe Solano Coffee', 'Coffee/Creamer', 'Peets', '$10.99')
# (42588001, 'Colombian Coffee', 'Coffee/Creamer', 'Peets', '$10.99')
# (42589001, 'French Roast Coffee', 'Coffee/Creamer', 'Peets', '$10.99')
# (42590001, 'House Blend Coffee', 'Coffee/Creamer', 'Peets', '$10.99')
# (42591001, 'House Blend Decaf Coffee', 'Coffee/Creamer', 'Peets', '$10.99')
# (42592001, 'Major Dickason Coffee', 'Coffee/Creamer', 'Peets', '$10.99')
# (42593001, 'Major Dickason Decaf Coffee', 'Coffee/Creamer', 'Peets', '$10.99')
# (42594001, 'Medium Brazil Monte Alegre Coffee', 'Coffee/Creamer', 'Peets', '$10.99')
# (42595001, 'Chopped Beef Dog Food', '', 'Pedigree', '$1.28')
# (42596001, 'Cough & Congestion Cherry', '', 'Pediacare', '$6.79')
# (42597001, 'Pasta Butter And Garlic', 'Pasta/Noodles', 'Pasta Roni', '$1.00')
# (42598001, 'Dutch Style Hot Cocoa Mix', '', 'Pantry Essentials', '$2.59')
# (42599001, 'Baby Dry Size 1', 'Diapers', 'Pampers', '$10.49')
# (42600001, 'Baby Dry Size 2', 'Diapers', 'Pampers', '$10.49')
# (42601001, 'Baby Dry Size 3', 'Diapers', 'Pampers', '$10.49')
# (42602001, 'Baby Dry Size 3', 'Diapers', 'Pampers', '$18.99')
# (42603001, 'Baby Dry Size 3', 'Diapers', 'Pampers', '$18.79')
# (42604001, 'Baby Dry Size 4', 'Diapers', 'Pampers', '$10.49')
# (42605001, 'Baby Dry Size 5', 'Diapers', 'Pampers', '$10.49')
# (42606001, 'Baby Dry Size 5', 'Diapers', 'Pampers', '$10.99')
# (42607001, 'Baby Dry Size 5', 'Diapers', 'Pampers', '$28.49')
# (42608001, 'Baby Dry Size 6', 'Diapers', 'Pampers', '$10.49')
# (42609001, 'Baby Dry Size 6', 'Diapers', 'Pampers', '$10.49')
# (42610001, 'Cruisers Size 3', 'Diapers', 'Pampers', '$10.99')
# (42611001, 'Cruisers Size 4', 'Diapers', 'Pampers', '$10.29')
# (42612001, 'Cruisers Size 4', 'Diapers', 'Pampers', '$10.99')
# (42613001, 'Cruisers Size 5', 'Diapers', 'Pampers', '$9.99')
# (42614001, 'Cruisers Size 5', 'Diapers', 'Pampers', '$10.99')
# (42615001, 'Cruisers Size 5', 'Diapers', 'Pampers', '$26.99')
# (42616001, 'Cruisers Size 5', 'Diapers', 'Pampers', '$26.99')
# (42617001, 'Cruisers Size 5', 'Diapers', 'Pampers', '$29.99')
# (42618001, 'Swaddlers Size 1', 'Diapers', 'Pampers', '$10.49')
# (42619001, 'Swaddlers Size 2', 'Diapers', 'Pampers', '$10.49')
# (42620001, 'Swaddlers Size Newborn', 'Diapers', 'Pampers', '$10.49')
# (42621001, 'Swaddlers Size Newborn', 'Diapers', 'Pampers', '$10.99')
# (42622001, 'Oxy Blue', '', 'Palmolive', '$2.79')
# (42623001, 'Oxi Clean Laundry Detergent', '', 'Oxi Clean', '$2.99')
# (42624001, 'Drink Mix Chocolate Malt', '', 'Ovaltine', '$5.29')
# (42625001, 'Drink Mix Chocolate Malt', '', 'Ovaltine', '$5.49')
# (42626001, 'Drink Mix Rich Chocolate', '', 'Ovaltine', '$4.99')
# (42627001, 'Hot Dogs Regular', '', 'Oscar Mayer', '$2.49')
# (42628001, 'Hot Dogs Turkey Smoked', '', 'Oscar Mayer', '$2.49')
# (42629001, 'Microwave Popcorn Butter', '', 'Orville Redenbachers', '$3.49')
# (42630001, 'Popcorn Garlic Butter & Sea Salt', '', 'Orville Redenbachers', '$3.19')
# (42631001, 'Blueberries In Light Syrup', '', 'Oregon', '$4.79')
# (42632001, 'French Fries Shoestring', '', 'Ore Ida', '$2.00')
# (42633001, 'Meatballs Angus Beef', '', 'Open Nature', '$7.69')
# (42634001, 'Chicken Patties', '', 'On Cor', '$3.49')
# (42635001, 'Juice Blueberry Pomegranate', '', 'Old Orchard', '$2.79')
# (42636001, 'Juice Peach Mango', '', 'Old Orchard', '$2.79')
# (42637001, 'Taco Seasoning Original', '', 'Old El Paso', '$0.83')
# (42638001, 'Craisins Original', '', 'Ocean Spray', '$2.49')
# (42639001, 'Cranberry Sauce Jellied', '', 'Ocean Spray', '$3.29')
# (42640001, 'Juice Cherry', '', 'Ocean Spray', '$3.89')
# (42641001, 'Juice Citrus Tangerine Orange Juice', '', 'Ocean Spray', '$3.99')
# (42642001, 'Juice Grape Cranberry', '', 'Ocean Spray', '$4.19')
# (42643001, 'Juice White Grapefruit', '', 'Ocean Spray', '$2.00')
# (42644001, 'Sparkling Juice Cranberry', '', 'Ocean Spray', '$4.19')
# (42645001, 'Coffee Aztec Blend Medium', 'Coffee/Creamer', 'O Organics', '$5.99')
# (42646001, 'Coffee Columbian Excelso', 'Coffee/Creamer', 'O Organics', '$5.99')
# (42647001, 'Coffee French Roast Dark', 'Coffee/Creamer', 'O Organics', '$5.99')
# (42648001, 'Coffee Guatemalan', 'Coffee/Creamer', 'O Organics', '$5.99')
# (42649001, 'Coffee Mexican Chiapas', 'Coffee/Creamer', 'O Organics', '$5.99')
# (42650001, 'Coffee Peruvian Chanchamayo', 'Coffee/Creamer', 'O Organics', '$5.99')
# (42651001, 'Honey Flake & Oat Clusters Cereal', 'Cereal', 'O Organics', '$3.29')
# (42652001, 'Honey Nut Os Cereal', 'Cereal', 'O Organics', '$3.29')
# (42653001, 'Multi Grain Squares Cereal', 'Cereal', 'O Organics', '$3.29')
# (42654001, 'Raisin Bran Cereal', 'Cereal', 'O Organics', '$3.29')
# (42655001, 'Spread Hazelnut', '', 'Nutella', '$6.99')
# (42656001, 'Coffee Breakfast Blend', 'Coffee/Creamer', 'New England', '$5.99')
# (42657001, 'Coffee Hazelnut Creme', 'Coffee/Creamer', 'New England', '$5.99')
# (42658001, 'Carnation Reduced Fat', '', 'Nestle', '$1.79')
# (42659001, 'Coffeemate French Vanilla', 'Coffee/Creamer', 'Nestle', '$3.29')
# (42660001, 'Hot Cocoa Mix Milk Chocolate', 'Soda/Juice/Drinks', 'Nestle', '$1.99')
# (42661001, 'Hot Cocoa Mix Mini Marshmallow', '', 'Nestle', '$1.99')
# (42662001, 'Milk Banana Strawberry', 'Soda/Juice/Drinks', 'Nestle', '$1.69')
# (42663001, 'Tea Instant', '', 'Nestea', '$4.39')
# (42664001, 'Drink Mix Chocolate', '', 'Nesquik', '$4.39')
# (42665001, 'Drink Mix Chocolate', '', 'Nesquik', '$6.59')
# (42666001, 'Drink Mix Chocolate', '', 'Nesquik', '$6.99')
# (42667001, 'Tasters Choice Coffee', 'Coffee/Creamer', 'Nescafe', '$7.00')
# (42668001, 'Bagels Cinnamon Raisin', '', 'Natures Own', '$3.29')
# (42669001, 'Bagels Plain', '', 'Natures Own', '$3.29')
# (42670001, 'Bagels Whole Wheat', '', 'Natures Own', '$3.29')
# (42671001, 'Bread Cinnamon Raisin Swirl', 'Bread', 'Natures Own', '$3.99')
# (42672001, 'Thin Bagels White', '', 'Natures Own', '$3.29')
# (42673001, 'Thin Bagels Whole Wheat', '', 'Natures Own', '$3.29')
# (42674001, 'Nationeel Avocado Dip ', 'Dips', 'Nationeel', '$2.41')
# (42675001, 'Nationeel Buttered Popcorn ', 'Popcorn', 'Nationeel', '$2.51')
# (42676001, 'Nationeel Cheese Dip ', 'Dips', 'Nationeel', '$2.22')
# (42677001, 'Nationeel Chocolate Chip Cookies ', 'Cookies', 'Nationeel', '$3.31')
# (42678001, 'Nationeel Fondue Mix ', 'Dips', 'Nationeel', '$2.22')
# (42679001, 'Nationeel Frosted Cookies ', 'Cookies', 'Nationeel', '$1.63')
# (42680001, 'Nationeel Fudge Brownies ', 'Cookies', 'Nationeel', '$1.71')
# (42681001, 'Nationeel Fudge Cookies ', 'Cookies', 'Nationeel', '$1.42')
# (42682001, 'Nationeel Graham Crackers ', 'Cookies', 'Nationeel', '$1.65')
# (42683001, 'Nationeel Lemon Cookies ', 'Cookies', 'Nationeel', '$2.26')
# (42684001, 'Nationeel Low Fat Cookies ', 'Cookies', 'Nationeel', '$0.66')
# (42685001, 'Nationeel Low Fat Popcorn ', 'Popcorn', 'Nationeel', '$3.88')
# (42686001, 'Nationeel No Salt Popcorn ', 'Popcorn', 'Nationeel', '$0.69')
# (42687001, 'Nationeel Salsa Dip ', 'Dips', 'Nationeel', '$1.60')
# (42688001, 'Nationeel Sugar Cookies ', 'Cookies', 'Nationeel', '$2.94')
# (42689001, 'Chips Ahoy Cookies Candy Blasts', '', 'Nabisco', '$2.79')
# (42690001, 'Chips Ahoy Cookies Chewy Chocolate Chip', '', 'Nabisco', '$2.79')
# (42691001, 'Chips Ahoy Cookies Chewy Chocolate Chip', '', 'Nabisco', '$3.89')
# (42692001, 'Chips Ahoy Cookies Chewy Chocolate Reeses', '', 'Nabisco', '$2.79')
# (42693001, 'Chips Ahoy Cookies Chewy Reeses Peanut Butter Cup', 'Snacks', 'Nabisco', '$2.79')
# (42694001, 'Chips Ahoy Cookies Chocolate Chip', '', 'Nabisco', '$6.99')
# (42695001, 'Chips Ahoy Cookies Chocolate Chip', '', 'Nabisco', '$3.89')
# (42696001, 'Chips Ahoy Cookies Chunky', '', 'Nabisco', '$2.79')
# (42697001, 'Chips Ahoy Cookies Double Chocolate Thins', '', 'Nabisco', '$2.79')
# (42698001, 'Chips Ahoy Cookies Oatmeal Thins', '', 'Nabisco', '$2.79')
# (42699001, 'Chips Ahoy Cookies Red Velvet', '', 'Nabisco', '$2.79')
# (42700001, 'Chips Ahoy Cookies Reduced Fat', '', 'Nabisco', '$2.79')
# (42701001, 'Chips Ahoy Cookies Smores', '', 'Nabisco', '$2.79')
# (42702001, 'Chips Ahoy Cookies Snak-Saks Original', '', 'Nabisco', '$2.99')
# (42703001, 'Chips Ahoy Cookies Soft Chunky Peanut Butter', 'Snacks', 'Nabisco', '$2.79')
# (42704001, 'Chips Ahoy Cookies Thins Cinnamon Sugar', '', 'Nabisco', '$2.79')
# (42705001, 'Chips Ahoy Cookies Thins Original', '', 'Nabisco', '$2.79')
# (42706001, 'Chips Ahoy Cookies White Fudge Chunky', '', 'Nabisco', '$2.79')
# (42707001, 'Chips Ahoy Original Chocolate Chip', '', 'Nabisco', '$2.79')
# (42708001, 'Wheat Thins Big Crackers Original', '', 'Nabisco', '$2.39')
# (42709001, 'Wheat Thins Cracked Pepper & Olive Oil', '', 'Nabisco', '$2.39')
# (42710001, 'Wheat Thins Hint Of Salt', '', 'Nabisco', '$2.39')
# (42711001, 'Wheat Thins Original', '', 'Nabisco', '$2.39')
# (42712001, 'Wheat Thins Ranch', '', 'Nabisco', '$2.39')
# (42713001, 'Wheat Thins Reduced Fat', '', 'Nabisco', '$2.39')
# (42714001, 'Wheat Thins Sundried Tomato & Basil', '', 'Nabisco', '$2.39')
# (42715001, 'Wheat Thins Toasted Chips Multigrain', '', 'Nabisco', '$3.99')
# (42716001, 'Wheat Thins Toasted Chips Veggie', '', 'Nabisco', '$3.99')
# (42717001, 'Wheat Thins Toasted Pita Garlic Herb', '', 'Nabisco', '$2.39')
# (42718001, 'Wheat Thins Toasted Pita Original', '', 'Nabisco', '$2.39')
# (42719001, 'Musial Malted Milk Balls ', 'Chocolate Candy', 'Musial', '$0.89')
# (42720001, 'Musial Mint Chocolate Bar ', 'Chocolate Candy', 'Musial', '$0.98')
# (42721001, 'Musial Mints ', 'Hard Candy', 'Musial', '$3.14')
# (42722001, 'Musial Semi-Sweet Chocolate Bar ', 'Chocolate Candy', 'Musial', '$2.81')
# (42723001, 'Musial Spicy Mints ', 'Hard Candy', 'Musial', '$2.92')
# (42724001, 'Musial Tasty Candy Bar ', 'Chocolate Candy', 'Musial', '$2.10')
# (42725001, 'Musial White Chocolate Bar ', 'Chocolate Candy', 'Musial', '$3.43')
# (42726001, 'Diaper Bag Dispenser', 'Diapers', 'Munchkin', '$4.29')
# (42727001, 'Diaper Bag Refills', 'Diapers', 'Munchkin', '$4.39')
# (42728001, 'Syrup Regular', '', 'Mrs. Buttersworths', '$3.49')
# (42729001, 'Juice Boxes Apple White Grape', '', 'Motts For Tots', '$2.99')
# (42730001, 'Applesauce Cinnamon', '', 'Motts', '$3.39')
# (42731001, 'Pain Reliever/Fever Reducer Original Berry', '', 'Motrin Infant', '$8.99')
# (42732001, 'Salt Kosher', '', 'Morton', '$2.89')
# (42733001, 'Sea Salt Coarse', '', 'Morton', '$2.69')
# (42734001, 'Sea Salt Fine', '', 'Morton', '$0.99')
# (42735001, 'Monarch Rice Medly ', 'Rice', 'Monarch', '$1.80')
# (42736001, 'Monarch Thai Rice ', 'Rice', 'Monarch', '$3.11')
# (42737001, 'Moms Beef Bologna ', 'Bologna', 'Moms', '$2.27')
# (42738001, 'Moms Chicken Hot Dogs ', 'Hot Dogs', 'Moms', '$1.49')
# ...
# (43946001, 'Big Time Frozen Pepperoni Pizza ', 'Pizza', 'Big Time', '$1.13')
# (43947001, 'Big Time Frozen Sausage Pizza ', 'Pizza', 'Big Time', '$0.80')
# (43948001, 'Big Time Grape Popsicles ', 'Popsicles', 'Big Time', '$0.51')
# (43949001, 'Big Time Home Style French Fries ', 'French Fries', 'Big Time', '$1.38')
# (43950001, 'Big Time Ice Cream ', 'Ice Cream', 'Big Time', '$2.77')
# (43951001, 'Big Time Ice Cream Sandwich ', 'Ice Cream', 'Big Time', '$2.91')
# (43952001, 'Big Time Lemon Popsicles ', 'Popsicles', 'Big Time', '$1.47')
# (43953001, 'Big Time Lime Popsicles ', 'Popsicles', 'Big Time', '$2.25')
# (43954001, 'Big Time Low Fat French Fries ', 'French Fries', 'Big Time', '$1.35')
# (43955001, 'Big Time Orange Popsicles ', 'Popsicles', 'Big Time', '$3.13')
# (43956001, 'Big Time Turkey TV Dinner ', 'TV Dinner', 'Big Time', '$3.21')
# (43957001, 'Citrus Drop Soda', 'Soda/Juice/Drinks', 'Big K', '$0.89')
# (43958001, 'Cola Regular', 'Soda/Juice/Drinks', 'Big K', '$2.00')
# (43959001, 'Big City Canned Mixed Fruit ', 'Canned Fruit', 'Big City', '$1.17')
# (43960001, 'Big City Canned Peaches ', 'Canned Fruit', 'Big City', '$0.76')
# (43961001, 'Fruit Snacks SpongeBob', 'Snacks', 'Betty Crocker', '$3.29')
# (43962001, 'Hamburger Helper Bacon Cheeseburger', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43963001, 'Hamburger Helper Beef Pasta', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43964001, 'Hamburger Helper Cheddar Cheese Melt', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43965001, 'Hamburger Helper Cheeseburger Macaroni', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43966001, 'Hamburger Helper Cheesy Enchilada', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43967001, 'Hamburger Helper Cheesy Italian Shells', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43968001, 'Hamburger Helper Chili Macaroni', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43969001, 'Hamburger Helper Crunchy Taco', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43970001, 'Hamburger Helper Deluxe Beef Stroganoff', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43971001, 'Hamburger Helper Deluxe Cheeseburger Macaroni', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43972001, 'Hamburger Helper Double Cheeseburger Macaroni', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43973001, 'Hamburger Helper Four Cheese Lasagna', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43974001, 'Hamburger Helper Lasagna', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43975001, 'Hamburger Helper Philly Cheesesteak', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43976001, 'Hamburger Helper Potatoes Stroganoff', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43977001, 'Hamburger Helper Salisbury', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43978001, 'Hamburger Helper Stroganoff', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43979001, 'Hamburger Helper Three Cheese', 'Pasta/Noodles', 'Betty Crocker', '$1.29')
# (43980001, 'Better Beef Soup ', 'Soup', 'Better', '$0.57')
# (43981001, 'Better Canned Beets ', 'Canned Vegetables', 'Better', '$0.60')
# (43982001, 'Better Canned Peas ', 'Canned Vegetables', 'Better', '$1.40')
# (43983001, 'Better Canned String Beans ', 'Canned Vegetables', 'Better', '$1.74')
# (43984001, 'Better Canned Tomatos ', 'Canned Vegetables', 'Better', '$1.32')
# (43985001, 'Better Canned Tuna in Oil ', 'Tuna', 'Better', '$1.50')
# (43986001, 'Better Canned Tuna in Water ', 'Tuna', 'Better', '$2.77')
# (43987001, 'Better Canned Yams ', 'Canned Vegetables', 'Better', '$2.83')
# (43988001, 'Better Chicken Noodle Soup ', 'Soup', 'Better', '$1.15')
# (43989001, 'Better Chicken Ramen Soup ', 'Soup', 'Better', '$0.63')
# (43990001, 'Better Chicken Soup ', 'Soup', 'Better', '$3.98')
# (43991001, 'Better Creamed Corn ', 'Canned Vegetables', 'Better', '$1.26')
# (43992001, 'Better Noodle Soup ', 'Soup', 'Better', '$0.78')
# (43993001, 'Better Regular Ramen Soup ', 'Soup', 'Better', '$3.74')
# (43994001, 'Better Rice Soup ', 'Soup', 'Better', '$1.23')
# (43995001, 'Better Turkey Noodle Soup ', 'Soup', 'Better', '$0.75')
# (43996001, 'Better Vegetable Soup ', 'Soup', 'Better', '$2.21')
# (43997001, 'Best Choice Avocado Dip ', 'Dips', 'Best Choice', '$2.46')
# (43998001, 'Best Choice Buttered Popcorn ', 'Popcorn', 'Best Choice', '$2.23')
# (43999001, 'Best Choice Cheese Dip ', 'Dips', 'Best Choice', '$3.55')
# (44000001, 'Best Choice Chocolate Chip Cookies ', 'Cookies', 'Best Choice', '$3.95')
# (44001001, 'Best Choice Fondue Mix ', 'Dips', 'Best Choice', '$1.81')
# (44002001, 'Best Choice Frosted Cookies ', 'Cookies', 'Best Choice', '$2.59')
# (44003001, 'Best Choice Fudge Brownies ', 'Cookies', 'Best Choice', '$1.73')
# (44004001, 'Best Choice Fudge Cookies ', 'Cookies', 'Best Choice', '$3.19')
# (44005001, 'Best Choice Graham Crackers ', 'Cookies', 'Best Choice', '$1.98')
# (44006001, 'Best Choice Lemon Cookies ', 'Cookies', 'Best Choice', '$0.76')
# (44007001, 'Best Choice Low Fat Cookies ', 'Cookies', 'Best Choice', '$0.68')
# (44008001, 'Best Choice Low Fat Popcorn ', 'Popcorn', 'Best Choice', '$2.65')
# (44009001, 'Best Choice No Salt Popcorn ', 'Popcorn', 'Best Choice', '$1.19')
# (44010001, 'Best Choice Salsa Dip ', 'Dips', 'Best Choice', '$2.63')
# (44011001, 'Best Choice Sugar Cookies ', 'Cookies', 'Best Choice', '$3.66')
# (44012001, 'Cereal Oatmeal', 'Cereal', 'Beech-Nut', '$2.29')
# (44013001, 'Cereal Rice', 'Cereal', 'Beech-Nut', '$2.29')
# (44014001, 'Fruities On The Go Peach, Apple & Banana', 'Baby Food', 'Beech-Nut', '$1.29')
# (44015001, 'Fruities On The Go Pear, Banana & Raspberry', 'Baby Food', 'Beech-Nut', '$1.29')
# (44016001, 'Fruities On The Go Pear, Mango & Squash', 'Baby Food', 'Beech-Nut', '$1.29')
# (44017001, 'Stage 1 Bananas', 'Baby Food', 'Beech-Nut', '$1.09')
# (44018001, 'Stage 1 Beef & Broth', 'Baby Food', 'Beech-Nut', '$1.09')
# (44019001, 'Stage 1 Butternut Squash', 'Baby Food', 'Beech-Nut', '$1.09')
# (44020001, 'Stage 1 Chicken & Broth', 'Baby Food', 'Beech-Nut', '$1.09')
# (44021001, 'Stage 1 Honey Crisp Apples', 'Baby Food', 'Beech-Nut', '$1.09')
# (44022001, 'Stage 1 Sweet Potatoes', 'Baby Food', 'Beech-Nut', '$1.09')
# (44023001, 'Stage 1 Turkey And Broth', 'Baby Food', 'Beech-Nut', '$1.09')
# (44024001, 'Stage 2 Apple & Pumpkin', 'Baby Food', 'Beech-Nut', '$1.09')
# (44025001, 'Stage 2 Apples & Bananas', 'Baby Food', 'Beech-Nut', '$0.79')
# (44026001, 'Stage 2 Applesauce', 'Baby Food', 'Beech-Nut', '$0.79')
# (44027001, 'Stage 2 Bananas & Strawberries', 'Baby Food', 'Beech-Nut', '$0.79')
# (44028001, 'Stage 2 Butternut Squash', 'Baby Food', 'Beech-Nut', '$0.79')
# (44029001, 'Stage 2 Chicken & Rice', 'Baby Food', 'Beech-Nut', '$0.79')
# (44030001, 'Stage 2 Chiquita-Bananas', 'Baby Food', 'Beech-Nut', '$0.79')
# (44031001, 'Stage 2 Country Garden Vegetables', 'Baby Food', 'Beech-Nut', '$0.79')
# (44032001, 'Stage 2 Just Apple & Blackberry', 'Baby Food', 'Beech-Nut', '$1.09')
# (44033001, 'Stage 2 Just Apple & Kiwi', 'Baby Food', 'Beech-Nut', '$1.09')
# (44034001, 'Stage 2 Just Apple & Strawberry', 'Baby Food', 'Beech-Nut', '$1.09')
# (44035001, 'Stage 2 Just Pear & Blueberry', 'Baby Food', 'Beech-Nut', '$1.09')
# (44036001, 'Stage 2 Mixed Vegetables', 'Baby Food', 'Beech-Nut', '$0.79')
# (44037001, 'Stage 2 Pears', 'Baby Food', 'Beech-Nut', '$0.79')
# (44038001, 'Stage 2 Tender Golden Sweet Carrots', 'Baby Food', 'Beech-Nut', '$0.79')
# (44039001, 'Stage 2 Tender Sweet Peas', 'Baby Food', 'Beech-Nut', '$0.79')
# (44040001, 'Stage 2 Tender Young Green Beans', 'Baby Food', 'Beech-Nut', '$0.79')
# (44041001, 'Stage 2 Yellow Cling Peaches', 'Baby Food', 'Beech-Nut', '$0.79')
# (44042001, 'Stage 3 Just Apple & Aronia Berry', 'Baby Food', 'Beech-Nut', '$1.09')
# (44043001, 'Stage 3 Mango, Carrot,Strawberry & Chia', 'Baby Food', 'Beech-Nut', '$1.09')
# (44044001, 'Yogurt Blends Pouch Strawberry', 'Baby Food', 'Beech-Nut', '$1.29')
# (44045001, 'Yogurt Blends Pouch Strawberry Banana', 'Baby Food', 'Beech-Nut', '$1.29')
# (44046001, 'Yogurt Blends Pouch Vanilla Apple', 'Baby Food', 'Beech-Nut', '$1.29')
# (44047001, 'BBB Best Brown Sugar ', 'Sugar', 'BBB Best', '$1.78')
# (44048001, 'BBB Best Canola Oil ', 'Cooking Oil', 'BBB Best', '$1.35')
# (44049001, 'BBB Best Chunky Peanut Butter ', 'Peanut Butter', 'BBB Best', '$1.97')
# (44050001, 'BBB Best Corn Oil ', 'Cooking Oil', 'BBB Best', '$1.54')
# (44051001, 'BBB Best Creamy Peanut Butter ', 'Peanut Butter', 'BBB Best', '$1.10')
# (44052001, 'BBB Best Extra Chunky Peanut Butter ', 'Peanut Butter', 'BBB Best', '$2.78')
# (44053001, 'BBB Best Oregano ', 'Spices', 'BBB Best', '$0.53')
# (44054001, 'BBB Best Pepper ', 'Spices', 'BBB Best', '$0.76')
# (44055001, 'BBB Best Salt ', 'Spices', 'BBB Best', '$0.63')
# (44056001, 'BBB Best Sesame Oil ', 'Cooking Oil', 'BBB Best', '$1.84')
# (44057001, 'BBB Best Vegetable Oil ', 'Cooking Oil', 'BBB Best', '$2.97')
# (44058001, 'BBB Best White Sugar ', 'Sugar', 'BBB Best', '$2.46')
# (44059001, 'Collezione Bucatini', 'Pasta/Noodles', 'Barilla', '$2.59')
# (44060001, 'Gluten Free Elbows', 'Pasta/Noodles', 'Barilla', '$2.59')
# (44061001, 'Gluten Free Penne', 'Pasta/Noodles', 'Barilla', '$2.59')
# (44062001, 'Gluten Free Spaghetti', 'Pasta/Noodles', 'Barilla', '$2.59')
# (44063001, 'Pasta Angel Hair', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44064001, 'Pasta Elbows', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44065001, 'Pasta Farfalle', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44066001, 'Pasta Fettuccine', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44067001, 'Pasta Fideo Cut Spaghetti', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44068001, 'Pasta Jumbo Shells', 'Pasta/Noodles', 'Barilla', '$2.29')
# (44069001, 'Pasta Linguine', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44070001, 'Pasta Mini Penne', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44071001, 'Pasta Mostaccioli', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44072001, 'Pasta Orzo', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44073001, 'Pasta Penne', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44074001, 'Pasta Rigatoni', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44075001, 'Pasta Rotini', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44076001, 'Pasta Spaghetti', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44077001, 'Pasta Thick Spaghetti', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44078001, 'Pasta Thin Spaghetti', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44079001, 'Pasta Tri-Color Rotini', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44080001, 'Pasta Veggie Rotini', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44081001, 'Pasta Wavy Lasagne', 'Pasta/Noodles', 'Barilla', '$2.29')
# (44082001, 'PLUS Multigrain Elbows', 'Pasta/Noodles', 'Barilla', '$1.99')
# (44083001, 'Pronto Elbows', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44084001, 'Pronto Penne', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44085001, 'Pronto Rotini', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44086001, 'Pronto Spaghetti', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44087001, 'Protein Plus Multigrain Angel Hair', 'Pasta/Noodles', 'Barilla', '$2.59')
# (44088001, 'Protein Plus Multigrain Penne', 'Pasta/Noodles', 'Barilla', '$2.59')
# (44089001, 'Protein Plus Multigrain Thin Spaghetti', 'Pasta/Noodles', 'Barilla', '$2.59')
# (44090001, 'Sauce Creamy Alfredo', 'Gravy/Sauce', 'Barilla', '$2.99')
# (44091001, 'Sauce Garlic Alfredo', 'Gravy/Sauce', 'Barilla', '$2.99')
# (44092001, 'Sauce Marinara', 'Gravy/Sauce', 'Barilla', '$2.99')
# (44093001, 'Sauce Meat', 'Gravy/Sauce', 'Barilla', '$2.99')
# (44094001, 'Sauce Roasted Garlic', 'Gravy/Sauce', 'Barilla', '$2.99')
# (44095001, 'Sauce Tomato & Basil', 'Gravy/Sauce', 'Barilla', '$2.99')
# (44096001, 'Sauce Traditional', 'Gravy/Sauce', 'Barilla', '$2.99')
# (44097001, 'White Fiber Shells', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44098001, 'White Fiber Spaghetti', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44099001, 'Whole Grain Lasagne', 'Pasta/Noodles', 'Barilla', '$2.29')
# (44100001, 'Whole Grain Linguine', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44101001, 'Whole Grain Penne', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44102001, 'Whole Grain Rotini', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44103001, 'Whole Grain Spaghetti', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44104001, 'Whole Grain Thin Spaghetti', 'Pasta/Noodles', 'Barilla', '$1.39')
# (44105001, 'Chicken Breast Stuffed Broccoli & Cheese', '', 'Barber', '$5.49')
# (44106001, 'Brown N Serve Sausage Maple Links', 'Frozen Food', 'Banquet', '$1.99')
# (44107001, 'Brown N Serve Sausage Original Links', 'Frozen Food', 'Banquet', '$1.99')
# (44108001, 'Brown N Serve Sausage Turkey', 'Frozen Food', 'Banquet', '$1.99')
# (44109001, 'Chicken Breast Strips', '', 'Banquet', '$4.39')
# (44110001, 'Chicken Patties', '', 'Banquet', '$4.39')
# (44111001, 'Chicken Patty', '', 'Banquet', '$4.39')
# (44112001, 'Atomic Malted Milk Balls ', 'Chocolate Candy', 'Atomic', '$1.78')
# (44113001, 'Atomic Mint Chocolate Bar ', 'Chocolate Candy', 'Atomic', '$0.90')
# (44114001, 'Atomic Mints ', 'Hard Candy', 'Atomic', '$2.16')
# (44115001, 'Atomic Semi-Sweet Chocolate Bar ', 'Chocolate Candy', 'Atomic', '$2.35')
# (44116001, 'Atomic Spicy Mints ', 'Hard Candy', 'Atomic', '$3.16')
# (44117001, 'Atomic Tasty Candy Bar ', 'Chocolate Candy', 'Atomic', '$0.66')
# (44118001, 'Atomic White Chocolate Bar ', 'Chocolate Candy', 'Atomic', '$1.25')
# (44119001, 'Scramble Bacon', 'Frozen Food', 'Atkins', '$3.99')
# (44120001, 'Scramble Farmhouse-Style Sausage', 'Frozen Food', 'Atkins', '$3.99')
# (44121001, 'Coconut Milk Lite', 'Drink', 'Asian Gourmet', '$2.29')
# (44122001, 'Sandwich Thins Honey Wheat', 'Bread', 'Arnold', '$3.49')
# (44123001, 'Sandwich Thins Multigrain', 'Bread', 'Arnold', '$3.49')
# (44124001, 'Sandwich Thins Potato Rolls', 'Bread', 'Arnold', '$3.49')
# (44125001, 'Sandwich Thins Whole Wheat', 'Bread', 'Arnold', '$3.49')
# (44126001, 'Fruitables Berry Berry Juice', '', 'Apple & Eve', '$3.29')
# (44127001, 'Applause Canned Mixed Fruit ', 'Canned Fruit', 'Applause', '$2.80')
# (44128001, 'Applause Canned Peaches ', 'Canned Fruit', 'Applause', '$2.34')
# (44129001, 'Berry Bunnies Cereal', 'Cereal', "Annie's", '$5.49')
# (44130001, 'Cocoa Bunnies Cereal', 'Cereal', "Annie's", '$5.49')
# (44131001, 'Frosted Oat Flakes Cereal', 'Cereal', "Annie's", '$5.49')
# (44132001, 'Amigo Lox ', 'Fresh Fish', 'Amigo', '$2.96')
# (44133001, 'American Beef Bologna ', 'Bologna', 'American', '$0.78')
# (44134001, 'American Chicken Hot Dogs ', 'Hot Dogs', 'American', '$2.52')
# (44135001, 'American Cole Slaw ', 'Deli Salads', 'American', '$0.89')
# (44136001, 'American Corned Beef ', 'Deli Meats', 'American', '$2.65')
# (44137001, 'American Foot-Long Hot Dogs ', 'Hot Dogs', 'American', '$2.14')
# (44138001, 'American Low Fat Bologna ', 'Bologna', 'American', '$2.87')
# (44139001, 'American Low Fat Cole Slaw ', 'Deli Salads', 'American', '$2.27')
# (44140001, 'American Pimento Loaf ', 'Bologna', 'American', '$2.76')
# (44141001, 'American Potato Salad ', 'Deli Salads', 'American', '$1.55')
# (44142001, 'American Roasted Chicken ', 'Fresh Chicken', 'American', '$2.97')
# (44143001, 'American Sliced Chicken ', 'Deli Meats', 'American', '$0.59')
# (44144001, 'American Sliced Ham ', 'Deli Meats', 'American', '$2.76')
# (44145001, 'American Sliced Turkey ', 'Deli Meats', 'American', '$3.17')
# (44146001, 'American Turkey Hot Dogs ', 'Hot Dogs', 'American', '$2.74')
# (44147001, 'Drink Mix Spiced Cider', 'Drink', 'Alpine', '$3.59')
# (44148001, 'Almond Milk Original', 'Drink', 'Almond Breeze', '$3.69')
# (44149001, 'Almond Milk Unsweetened', 'Drink', 'Almond Breeze', '$3.59')
# (44150001, 'Almond Milk Vanilla', 'Drink', 'Almond Breeze', '$3.69')
# (44151001, 'Snack Cakes Vanilla', 'Snacks', 'All But Gluten', '$6.59')
# (44152001, 'Laundry Detergent 2X Ultra Free Clear', 'Household', 'All', '$11.99')
# (44153001, 'Gourmet Griller Carmelized Onion', 'Frozen Food', 'Al Fresco', '$10.99')
# (44154001, 'Gourmet Griller Sweet Italian', 'Frozen Food', 'Al Fresco', '$10.99')
# (44155001, 'Meatballs Caramelized Onion', 'Frozen Food', 'Aidells', '$6.59')
# (44156001, 'Meatballs Pineapple Teriyaki', 'Frozen Food', 'Aidells', '$6.59')
# (44157001, 'Meatballs Sundried Tomato', 'Frozen Food', 'Aidells', '$6.59')
# (44158001, 'Popcorn Butter', 'Frozen Food', 'Act II', '$3.99')
# (44159001, 'Coconut Milk Unsweetened', 'Drink', 'A Taste Of Thai', '$3.59')
# (44160001, 'Iced Tea Mix Regular', 'Drink', '4C', '$6.49')
