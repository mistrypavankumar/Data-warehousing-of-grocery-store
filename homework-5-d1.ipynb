# %%
import sqlite3
import pandas as pd

# Define the store databases for Region A (Stores 1-4)

products_df = pd.read_csv("./Products1.txt", delimiter="|")

store_databases = {
    "Store 1": {
        "database_name": "store1.db",
        "transactions": {
            "table_name": "user_transactions",
            "column_names": {
                "id": "transaction_id",
                "date": "date",
                "customer_number": "customer_number",
                "sku": "sku",
                "sale_price": "sales_price",
                "items_left": "items_left",
                "cases_ordered": "cases_ordered"
            },
        },

    },
    "Store 2": {
        "database_name": "store2.db",
        "transactions":  {
            "table_name": "sales",
            "column_names": {
                "id": "",
                "date": "saleDate",
                "customer_number": "customerNum",
                "sku": "sku",
                "sales_price": "price",
                "items_left": "stockCount",
                "cases_ordered": "caseCount"
            },
        },
    },
    "Store 3": {
        "database_name": "store3.db",
        "transactions": {
            "table_name": "sales",
            "column_names": {
                "id": "",
                "date": "Date",
                "customer_number": "Customer #",
                "sku": "SKU",
                "sales_price": "Sale Price",
                "items_left": "ItemsLeft",
                "cases_ordered": "TotalCasesOrdered"
            },
        },
    },
    "Store 4": {
        "database_name": "store4.db",
        "transactions": {
            "table_name": "sales_transactions",
            "column_names": {
                "id": "",
                "date": "date",
                "customer_number": "customer_number",
                "sku": "product_sku",
                "sales_price": "SalesPrice",
                "items_left": "items_left",
                "cases_ordered": "cases_ordered"
            }
        },
    }
}

# %%
# Function to load December data from a store's database
def load_december_data(store):
    conn = sqlite3.connect(store['database_name'])

    table_name = store['transactions']['table_name']
    _date = store['transactions']['column_names']['date']

    # Load December transactions (filter for month = 12)
    december_transactions_query = """
        SELECT * 
        FROM """ + table_name + """ 
        WHERE """ +  _date + """ LIKE '%/12/%' OR """ + _date+ """ LIKE '%-12-%' OR """ + _date+ """ LIKE '%12%'
    """

    print(december_transactions_query)
    december_transactions_df = pd.read_sql_query(
        december_transactions_query, conn)

    conn.close()

    return december_transactions_df, products_df

# %%
# Function to get top-selling items for December
def get_december_top_selling_items(december_transactions_df, products_df,  top_n=25):
    # Merging transactions with products to get product names
    merged_df = pd.merge(december_transactions_df, products_df,
                         left_on="sku", right_on="SKU", how="left")

    # Group by sku and Product Name, then sum the quantities sold
    top_items = merged_df.groupby(
        ["sku", "Product Name"]).size().reset_index(name="Quantity Sold")

    # Sort by quantity sold in descending order
    top_items = top_items.sort_values(by="Quantity Sold", ascending=False)

    # Add a rank column (1 to N) based on quantity sold
    top_items["Rank"] = top_items["Quantity Sold"].rank(
        method="min", ascending=False).astype(int)

    # Get the top N items
    top_items = top_items.head(top_n)

    return top_items

# %%
def calculate_december_customer_count(december_transactions_df, col_name):
    return december_transactions_df[col_name].nunique()

# %%
def calculate_december_sales(december_transactions_df, col_name):
    return december_transactions_df[col_name].sum()

# %%
result = {
    "Store": [],
    "December Sales": [],
    "December Customer Count": [],
}

for store_name, db_path in store_databases.items():
    print(f"Processing {store_name}...")

    # Load December data
    december_transactions_df, products_df = load_december_data(db_path)

    transactions_col_name = december_transactions_df.columns
    products_col_name = products_df.columns	

    sales_price_format = [x for x in transactions_col_name if x in ['sale_price', 'sales_price', 'SalesPrice',
                                                                    "salesPrice", "salesprice", "Sale Price"]]
    customer_number_format = [x for x in transactions_col_name if x in ['customer_number', "Customer Number",
                                                                        "customer number", "Customer#", "Customer #"]]
    
    print(sales_price_format, customer_number_format)

    if sales_price_format:
        december_sales = calculate_december_sales(
            december_transactions_df, sales_price_format[0])
    else:
        print(f"Error: Sales price column not found in {store_name}. Skipping this store.")
        continue

    if customer_number_format:
        december_customer_count = calculate_december_customer_count(
            december_transactions_df, customer_number_format[0])
    else:
        print(f"Error: Customer number column not found in {store_name}. Skipping this store.")
        continue
    
    result["Store"].append(store_name)
    result["December Sales"].append(december_sales)
    result["December Customer Count"].append(december_customer_count)

    sales_price_format = []
    customer_number_format = []
# Out:
# Processing Store 1...
#
#         SELECT *
#         FROM user_transactions
#         WHERE date LIKE '%/12/%' OR date LIKE '%-12-%' OR date LIKE '%12%'
#
# ['sale_price'] ['customer_number']
# Processing Store 2...
#
#         SELECT *
#         FROM sales
#         WHERE saleDate LIKE '%/12/%' OR saleDate LIKE '%-12-%' OR saleDate LIKE '%12%'
#
# [] []
# Error: Sales price column not found in Store 2. Skipping this store.
# Processing Store 3...
#
#         SELECT *
#         FROM sales
#         WHERE Date LIKE '%/12/%' OR Date LIKE '%-12-%' OR Date LIKE '%12%'
#
# ['Sale Price'] ['Customer #']
# Processing Store 4...
#
#         SELECT *
#         FROM sales_transactions
#         WHERE date LIKE '%/12/%' OR date LIKE '%-12-%' OR date LIKE '%12%'
#
# ['salesPrice'] ['customer_number']

# %%
result = pd.DataFrame(result)
result
# Out:
#      Store  December Sales  December Customer Count
# 0  Store 1      4538694.32                     1085
# 1  Store 3       518304.19                       42
# 2  Store 4      5339914.35                     1126

# %%
# Combined total sales of december month
combined_total_sales = result['December Sales'].sum()
print(f"Combined total sales of december month: ${combined_total_sales:.2f}")

# combined totall customer count of december month
combined_total_customer_count = result['December Customer Count'].sum()
print("Combined total customer count of december month: ", combined_total_customer_count)
# Out:
# Combined total sales of december month: $10396912.86
# Combined total customer count of december month:  2253

# %%
# Dictionary to store top-selling items for all stores
all_top_items = {}

# Get the top 25 products from Store 1
print("Processing Store 1 to determine top 25 products...")

december_transactions_df_store1, products_df_store1 = load_december_data(
    store_databases["Store 1"])

top_25_products_store1 = get_december_top_selling_items(
    december_transactions_df_store1, products_df_store1)

top_25_products_store1
# Out:
# Processing Store 1 to determine top 25 products...
#
#         SELECT *
#         FROM user_transactions
#         WHERE date LIKE '%/12/%' OR date LIKE '%-12-%' OR date LIKE '%12%'
#            sku                      Product Name  Quantity Sold  Rank
# 275   42356001                        1.00% Milk           5018     1
# 276   42357001                        2.00% Milk           5018     1
# 274   42355001                        1.00% Milk           4998     3
# 278   42359001                   Whole Milk Milk           4978     4
# 279   42360001                   Whole Milk Milk           4931     5
# 277   42358001                        2.00% Milk           4887     6
# 233   42314001               Squeeze Jelly Grape           1391     7
# 230   42311001                         Jam Grape           1357     8
# 232   42313001                       Jelly Grape           1356     9
# 231   42312001                    Jam Strawberry           1354    10
# 2069  44155001       Meatballs Caramelized Onion            843    11
# 1410  43496001  Tostitos Tortilla Chips Original            838    12
# 644   42725001       Musial White Chocolate Bar             825    13
# 1159  43245001   Cookies Vanilla Creme Chocolate            822    14
# 779   42863001                     Bursts Cherry            819    15
# 1114  43200001   Gorilla Low Fat Cottage Cheese             819    15
# 405   42486001        PigTail Chicken TV Dinner             818    17
# 420   42501001  PigTail Home Style French Fries             817    18
# 1915  44001001           Best Choice Fondue Mix             817    18
# 289   42370001       Red Spade Chicken Hot Dogs             817    18
# 61    42142001            Tri-State Sweet Onion             816    21
# 1580  43666001                  Ebony Mushrooms             816    21
# 1436  43522001              Fort West Salsa Dip             814    23
# 782   42866001                         Kiwi Lox             813    24
# 2060  44146001         American Turkey Hot Dogs             813    24

# %%
# Extract the SKUs of the top 25 products from Store 1
top_25_skus = top_25_products_store1["sku"].tolist()
top_25_skus
# Out:
# [42356001,
#  42357001,
#  42355001,
#  42359001,
#  42360001,
#  42358001,
#  42314001,
#  42311001,
#  42313001,
#  42312001,
#  44155001,
#  43496001,
#  42725001,
#  43245001,
#  42863001,
#  43200001,
#  42486001,
#  42501001,
#  44001001,
#  42370001,
#  42142001,
#  43666001,
#  43522001,
#  42866001,
#  44146001]

# %%
# Using above store-1 skus, get sales data for all stores
for store_name, db_path in store_databases.items():
    print(f"Processing {store_name}...")

    # Load December data for each store
    december_transactions_df, products_df = load_december_data(db_path)

    transactions_col_names = december_transactions_df.columns
    products_col_names = products_df.columns


    trans_sku_format = [x for x in transactions_col_names if x in ["sku", "SKU"]]
    prod_sku_format = [x for x in products_col_names if x in ["sku", "SKU"]]

    print(trans_sku_format, prod_sku_format)

    # Ensure that the lists are not empty before accessing their elements
    if trans_sku_format and prod_sku_format:
        # Merge transactions with products to get product names
        merged_df = pd.merge(december_transactions_df, products_df,
                             left_on=trans_sku_format[0], right_on=prod_sku_format[0], how="left")
    else:
        print(f"Error: SKU column not found in {store_name}. Skipping this store.")
        continue

    # Filter for the top 25 SKUs from Store 1
    filtered_df = merged_df[merged_df[trans_sku_format[0]].isin(top_25_skus)]

    # Group by sku and Product Name, then sum the quantities sold
    top_items = filtered_df.groupby(
        [trans_sku_format[0], "Product Name"]).size().reset_index(name="Quantity Sold")

    # Sort by quantity sold in descending order
    top_items = top_items.sort_values(by="Quantity Sold", ascending=False)

    # Add a rank column (1 to 25) based on quantity sold
    top_items["Rank"] = top_items["Quantity Sold"].rank(
        method="min", ascending=False).astype(int)

    all_top_items[store_name] = top_items

    trans_sku_format = []
    prod_sku_format = []
# Out:
# Processing Store 1...
#
#         SELECT *
#         FROM user_transactions
#         WHERE date LIKE '%/12/%' OR date LIKE '%-12-%' OR date LIKE '%12%'
#
# ['sku'] ['SKU']
# Processing Store 2...
#
#         SELECT *
#         FROM sales
#         WHERE saleDate LIKE '%/12/%' OR saleDate LIKE '%-12-%' OR saleDate LIKE '%12%'
#
# ['sku'] ['SKU']
# Processing Store 3...
#
#         SELECT *
#         FROM sales
#         WHERE Date LIKE '%/12/%' OR Date LIKE '%-12-%' OR Date LIKE '%12%'
#
# ['SKU'] ['SKU']
# Processing Store 4...
#
#         SELECT *
#         FROM sales_transactions
#         WHERE date LIKE '%/12/%' OR date LIKE '%-12-%' OR date LIKE '%12%'
#
# ['sku'] ['SKU']

# %%
# Creating a single Dataframe
combined_top_items = pd.DataFrame()

# Iterate through each store's top-selling items
for store_name, top_items in all_top_items.items():
    # Standardize column names to lowercase for consistency
    top_items.columns = top_items.columns.str.lower()
    top_items = top_items.rename(columns={
        "quantity sold": f"{store_name} Quantity Sold",
        "rank": f"{store_name} Rank"
    })

    # Merge with the combined DataFrame
    if combined_top_items.empty:
        combined_top_items = top_items[[
            "sku", "product name", f"{store_name} Quantity Sold", f"{store_name} Rank"]]
    else:
        combined_top_items = pd.merge(
            combined_top_items,
            top_items[["sku", f"{store_name} Quantity Sold",
                       f"{store_name} Rank"]],
            on="sku",
            how="outer"
        ).sort_values(by="Store 1 Rank")

# %%
combined_top_items.head()
# Out:
#          sku     product name  Store 1 Quantity Sold  Store 1 Rank  \
# 6   42356001       1.00% Milk                   5018             1
# 7   42357001       2.00% Milk                   5018             1
# 5   42355001       1.00% Milk                   4998             3
# 9   42359001  Whole Milk Milk                   4978             4
# 10  42360001  Whole Milk Milk                   4931             5
#
#     Store 2 Quantity Sold  Store 2 Rank  Store 3 Quantity Sold  Store 3 Rank  \
# 6                     NaN           NaN                     61             1
# 7                     NaN           NaN                     61             1
# 5                     NaN           NaN                     61             1
# 9                     NaN           NaN                     61             1
# 10                    NaN           NaN                     61             1
#
#     Store 4 Quantity Sold  Store 4 Rank
# 6                    5285             5
# 7                    5291             4
# 5                    5213             6
# 9                    5297             3
# 10                   5332             2

# %%
# Fill NaN values with 0 for Quantity Sold and "N/A" for Rank
combined_top_items = combined_top_items.fillna({
    "Store 1 Quantity Sold": 0,
    "Store 1 Rank": "N/A",
    "Store 2 Quantity Sold": 0,
    "Store 2 Rank": "N/A",
    "Store 3 Quantity Sold": 0,
    "Store 3 Rank": "N/A",
    "Store 4 Quantity Sold": 0,
    "Store 4 Rank": "N/A"
})

combined_top_items = combined_top_items.sort_values(by="Store 1 Rank")

print("\nBest Selling Items Combined for December in Region A (Stores 1-4):")
combined_top_items = combined_top_items.reset_index(drop=True)
combined_top_items
# Out:
# Best Selling Items Combined for December in Region A (Stores 1-4):
#          sku                      product name  Store 1 Quantity Sold  \
# 0   42356001                        1.00% Milk                   5018
# 1   42357001                        2.00% Milk                   5018
# 2   42355001                        1.00% Milk                   4998
# 3   42359001                   Whole Milk Milk                   4978
# 4   42360001                   Whole Milk Milk                   4931
# 5   42358001                        2.00% Milk                   4887
# 6   42314001               Squeeze Jelly Grape                   1391
# 7   42311001                         Jam Grape                   1357
# 8   42313001                       Jelly Grape                   1356
# 9   42312001                    Jam Strawberry                   1354
# 10  44155001       Meatballs Caramelized Onion                    843
# 11  43496001  Tostitos Tortilla Chips Original                    838
# 12  42725001       Musial White Chocolate Bar                     825
# 13  43245001   Cookies Vanilla Creme Chocolate                    822
# 14  43200001   Gorilla Low Fat Cottage Cheese                     819
# 15  42863001                     Bursts Cherry                    819
# 16  42486001        PigTail Chicken TV Dinner                     818
# 17  44001001           Best Choice Fondue Mix                     817
# 18  42370001       Red Spade Chicken Hot Dogs                     817
# 19  42501001  PigTail Home Style French Fries                     817
# 20  42142001            Tri-State Sweet Onion                     816
# 21  43666001                  Ebony Mushrooms                     816
# 22  43522001              Fort West Salsa Dip                     814
# 23  42866001                         Kiwi Lox                     813
# 24  44146001         American Turkey Hot Dogs                     813
#
#     Store 1 Rank  Store 2 Quantity Sold Store 2 Rank  Store 3 Quantity Sold  \
# 0              1                    0.0          N/A                     61
# 1              1                    0.0          N/A                     61
# 2              3                    0.0          N/A                     61
# 3              4                    0.0          N/A                     61
# 4              5                    0.0          N/A                     61
# 5              6                    0.0          N/A                     61
# 6              7                    0.0          N/A                     61
# 7              8                    0.0          N/A                     61
# 8              9                    0.0          N/A                     61
# 9             10                    0.0          N/A                     61
# 10            11                    0.0          N/A                     61
# 11            12                    0.0          N/A                     61
# 12            13                    0.0          N/A                     61
# 13            14                    0.0          N/A                     61
# 14            15                    0.0          N/A                     61
# 15            15                    0.0          N/A                     61
# 16            17                    0.0          N/A                     61
# 17            18                    0.0          N/A                     61
# 18            18                    0.0          N/A                     61
# 19            18                    0.0          N/A                     61
# 20            21                    0.0          N/A                     61
# 21            21                    0.0          N/A                     61
# 22            23                    0.0          N/A                     61
# 23            24                    0.0          N/A                     61
# 24            24                    0.0          N/A                     61
#
#     Store 3 Rank  Store 4 Quantity Sold  Store 4 Rank
# 0              1                   5285             5
# 1              1                   5291             4
# 2              1                   5213             6
# 3              1                   5297             3
# 4              1                   5332             2
# 5              1                   5392             1
# 6              1                   1485             8
# 7              1                   1433            10
# 8              1                   1441             9
# 9              1                   1500             7
# 10             1                    912            18
# 11             1                    892            24
# 12             1                    901            21
# 13             1                    909            20
# 14             1                    874            25
# 15             1                    914            17
# 16             1                    912            18
# 17             1                    942            12
# 18             1                    900            23
# 19             1                    917            15
# 20             1                    901            21
# 21             1                    973            11
# 22             1                    915            16
# 23             1                    930            13
# 24             1                    922            14

# %%
combined_cal = pd.DataFrame({
    "combined_total_sales": combined_total_sales,
    "combined_total_customer_count": combined_total_customer_count,
}, index=[1])

combined_cal
# Out:
#    combined_total_sales  combined_total_customer_count
# 1           10396912.86                           2253

# %%
# Save the result DataFrame
result.to_csv("Final-deliverable-1.csv", index=False, header=True)

combined_cal.to_csv("Final-deliverable-1.csv", index=False, mode='a', header=True)

# Append the combined_top_items DataFrame to the same file
combined_top_items.to_csv("Final-deliverable-1.csv", index=False, mode='a', header=True)

# %% [markdown]
# ### Deliverable 2a

# %%
import pandas as pd

# Existing products table
products = pd.read_csv('Products1.txt', delimiter="|")
product_class = pd.read_csv(
    'product_class.csv')

# %%
products.head()
# Out:
#   Manufacturer           Product Name   Size        itemType       SKU  \
# 0    Zatarains     Jambalaya Rice Mix  12 oz   Rice/Rice Mix  42081001
# 1    Zatarains     Jambalaya Rice Mix   8 oz   Rice/Rice Mix  42082001
# 2      Yucatan      Guacamole Regular   8 oz             NaN  42083001
# 3        Yuban  Coffee Original Blend  12 oz  Coffee/Creamer  42084001
# 4      Yoplait    GoGurt Variety Pack   8 ct          Yogurt  42085001
#
#   BasePrice
# 0     $2.49
# 1     $1.79
# 2     $3.99
# 3     $3.99
# 4     $2.99

# %%
product_class.head(99)
# Out:
#     product_class_id product_subcategory  product_category product_department  \
# 0                  1                Nuts         Specialty            Produce
# 1                  2           Shellfish           Seafood            Seafood
# 2                  3        Canned Fruit             Fruit    Canned Products
# 3                  4              Spices      Baking Goods       Baking Goods
# 4                  5               Pasta     Starchy Foods      Starchy Foods
# ..               ...                 ...               ...                ...
# 94                95           Anchovies  Canned Anchovies       Canned Foods
# 95                96               Clams      Canned Clams       Canned Foods
# 96                97             Oysters    Canned Oysters       Canned Foods
# 97                98            Sardines   Canned Sardines       Canned Foods
# 98                99         Fresh Fruit             Fruit            Produce
#
#    product_family
# 0            Food
# 1            Food
# 2            Food
# 3            Food
# 4            Food
# ..            ...
# 94           Food
# 95           Food
# 96           Food
# 97           Food
# 98           Food
#
# [99 rows x 5 columns]

# %%
[products.shape, product_class.shape]
# Out:
# [(2075, 6), (114, 5)]

# %%
product_class[product_class['product_class_id'] == 99]
# Out:
#     product_class_id product_subcategory product_category product_department  \
# 98                99         Fresh Fruit            Fruit            Produce
#
#    product_family
# 98           Food

# %% [markdown]
# #### Total Null itemType

# %%
total_null_items = len(products[products['itemType'].isnull()])
total_null_items
# Out:
# 294

# %%
subcategory_mapping = {
    'Frito Lay': 'Chips',
    'Whole Milk': 'Dairy',
    'Potato Chips': 'Chips',
    'Sliced Bread': 'Sliced Bread',
    'Yogurt': 'Yogurt',
    'Cheese': 'Cheese',
    'Fresh Vegetables': 'Fresh Vegetables',
    'Chips': 'Chips',
    'Soda': 'Soda',
    'Juice': 'Juice',
    'Cereal': 'Cereal',
    'Pasta': 'Pasta',
    'Coffee': 'Coffee',
    'Ice Cream': 'Ice Cream',
    'Cookies': 'Cookies',
    'Pretzels': 'Pretzels',
    'Popcorn': 'Popcorn',
    'Crackers': 'Crackers',
    'Dips': 'Dips',
    'Donuts': 'Donuts'
}


def map_subcategory(product_name):
    for keyword, subcategory in subcategory_mapping.items():
        if keyword in product_name:
            return subcategory
    return None

# %%
products['Subcategory'] = products['Product Name'].apply(map_subcategory)

# %%
products.sample(10)
# Out:
#        Manufacturer                    Product Name     Size  \
# 1917    Best Choice     Best Choice Fudge Brownies      6.23
# 1514     Entenmanns               Cake Lemon Crunch    26 oz
# 1554        Edwards                    Pie Key Lime    36 oz
# 1142         Golden    Golden Frozen Chicken Wings      13.3
# 1300  General Mills                 Cheerios Cereal    36 oz
# 109       Tell Tale       Tell Tale Canned Peanuts      6.86
# 1955      Beech-Nut    Stage 2 Yellow Cling Peaches     4 oz
# 1669           Coke                     Sprite Soda  67.6 oz
# 376        Pleasant  Pleasant Canned Tuna in Water       3.4
# 949         Huggies      Snug & Dry - Disney Size 5    24 ct
#
#                           itemType       SKU BasePrice Subcategory
# 1917                       Cookies  44003001     $1.73        None
# 1514  Baked Goods Other than Bread  43600001     $7.59        None
# 1554                           NaN  43640001     $7.99        None
# 1142                Frozen Chicken  43228001     $3.48        None
# 1300                        Cereal  43386001     $6.59      Cereal
# 109                           Nuts  42190001     $3.40        None
# 1955                     Baby Food  44041001     $0.79        None
# 1669                          Soda  43755001     $1.50        Soda
# 376                           Tuna  42457001     $2.96        None
# 949                        Diapers  43033001    $10.99        None

# %%
uncategorized_products = products[products['Subcategory'].isnull()]
uncategorized_products.count()
# Out:
# Manufacturer    1484
# Product Name    1484
# Size            1484
# itemType        1255
# SKU             1484
# BasePrice       1484
# Subcategory        0
# dtype: int64

# %%
subcategories = list(product_class['product_subcategory'])

for subcategory in subcategories:
    products.loc[products['Product Name'].str.contains(
        subcategory, case=False) & products['Subcategory'].isnull(), 'Subcategory'] = subcategory

# %%
# Filter products where 'itemType' is null and select the 'Product Name' column
products[products['Product Name'].isin(products[products['itemType'].isnull()]['Product Name'].unique())]
# Out:
#       Manufacturer                              Product Name      Size  \
# 2          Yucatan                         Guacamole Regular      8 oz
# 6     White Castle         Cheeseburger Heat & Serve Sliders  29.28 oz
# 8           Welchs                Farmers Pick Concord Grape     46 oz
# 19     Turkey Hill                            Iced Tea Lemon    128 oz
# 88          Thomas                          Bagels Blueberry     22 oz
# ...            ...                                       ...       ...
# 2019        Barber  Chicken Breast Stuffed Broccoli & Cheese    2.5 oz
# 2023       Banquet                     Chicken Breast Strips     24 oz
# 2024       Banquet                           Chicken Patties     27 oz
# 2025       Banquet                             Chicken Patty     27 oz
# 2040   Apple & Eve              Fruitables Berry Berry Juice      8 ct
#
#                           itemType       SKU BasePrice Subcategory
# 2                              NaN  42083001     $3.99        None
# 6                              NaN  42087001    $11.59      Cheese
# 8                              NaN  42089001     $3.59        None
# 19                             NaN  42100001     $2.99        None
# 88    Baked Goods Other than Bread  42169001     $3.00      Bagels
# ...                            ...       ...       ...         ...
# 2019                           NaN  44105001     $5.49      Cheese
# 2023                           NaN  44109001     $4.39        None
# 2024                           NaN  44110001     $4.39        None
# 2025                           NaN  44111001     $4.39        None
# 2040                           NaN  44126001     $3.29       Juice
#
# [303 rows x 7 columns]

# %%
remaining_uncategorized = products[products['Subcategory'].isnull()]
print(len(remaining_uncategorized))
# Out:
# 998

# %%
if len(remaining_uncategorized) > 0:
    print("\nSuggesting new subcategories for remaining uncategorized products:")
    for product_name in remaining_uncategorized['Product Name'].unique():
        print(
            f"Product: {product_name} → Suggested Subcategory: [New Subcategory]")
# Out:
# Suggesting new subcategories for remaining uncategorized products:
# Product: Guacamole Regular → Suggested Subcategory: [New Subcategory]
# Product: GoGurt Variety Pack → Suggested Subcategory: [New Subcategory]
# Product: Italian Dressing → Suggested Subcategory: [New Subcategory]
# Product: Choice Cuts Poultry → Suggested Subcategory: [New Subcategory]
# Product: Farmers Pick Concord Grape → Suggested Subcategory: [New Subcategory]
# Product: Splash Berry Blend → Suggested Subcategory: [New Subcategory]
# Product: Splash Mango Peach → Suggested Subcategory: [New Subcategory]
# Product: V-Fusion Berry → Suggested Subcategory: [New Subcategory]
# Product: V-Fusion Pomegranate Blueberry → Suggested Subcategory: [New Subcategory]
# Product: V-Fusion Refreshers Peach Strawberry → Suggested Subcategory: [New Subcategory]
# Product: Iced Tea Lemon → Suggested Subcategory: [New Subcategory]
# Product: Trop50 Calcium → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Almonds  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Asparagus  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Baby Onion  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Beets  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Broccoli  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Cantelope  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Cauliflower  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Corn on the Cob  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Dried Mushrooms  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Elephant Garlic  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Fancy Plums  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Fresh Lima Beans  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Fuji Apples  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Garlic  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Golden Delcious Apples  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Green Pepper  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Honey Dew  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Lemons  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Lettuce  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Limes  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Macintosh Apples  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Mandarin Oranges  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Mushrooms  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State New Potatos  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Onions  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Oranges  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Peaches  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Plums  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Potatos  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Prepared Salad  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Red Delcious Apples  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Red Pepper  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Shitake Mushrooms  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Squash  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Summer Squash  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Sweet Onion  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Sweet Peas  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Tangerines  → Suggested Subcategory: [New Subcategory]
# Product: Tri-State Tomatos  → Suggested Subcategory: [New Subcategory]
# Product: Toucan Canned Mixed Fruit  → Suggested Subcategory: [New Subcategory]
# Product: Toucan Canned Peaches  → Suggested Subcategory: [New Subcategory]
# Product: Tip Top Lox  → Suggested Subcategory: [New Subcategory]
# Product: Thresher Mints  → Suggested Subcategory: [New Subcategory]
# Product: Thresher Spicy Mints  → Suggested Subcategory: [New Subcategory]
# Product: Thresher Tasty Candy Bar  → Suggested Subcategory: [New Subcategory]
# Product: Bagel Thins 100% Whole Wheat → Suggested Subcategory: [New Subcategory]
# Product: Bagel Thins Cinnamon Raisin → Suggested Subcategory: [New Subcategory]
# Product: Bagel Thins Everything → Suggested Subcategory: [New Subcategory]
# Product: Bagel Thins Plain → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Almonds  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Asparagus  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Baby Onion  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Beets  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Broccoli  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Cantelope  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Cauliflower  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Corn on the Cob  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Dried Mushrooms  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Elephant Garlic  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Fancy Plums  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Fresh Lima Beans  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Fuji Apples  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Garlic  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Golden Delcious Apples  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Green Pepper  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Honey Dew  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Lemons  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Lettuce  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Limes  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Macintosh Apples  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Mandarin Oranges  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Mushrooms  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale New Potatos  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Onions  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Oranges  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Peaches  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Plums  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Potatos  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Prepared Salad  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Red Delcious Apples  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Red Pepper  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Shitake Mushrooms  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Squash  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Summer Squash  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Sweet Onion  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Sweet Peas  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Tangerines  → Suggested Subcategory: [New Subcategory]
# Product: Tell Tale Tomatos  → Suggested Subcategory: [New Subcategory]
# Product: Cake Dreamies Creme Kakes → Suggested Subcategory: [New Subcategory]
# Product: Cake Koffee Kake Cream Filled → Suggested Subcategory: [New Subcategory]
# Product: Cupcakes Buttercream → Suggested Subcategory: [New Subcategory]
# Product: Cupcakes Krimpet Butterscotch → Suggested Subcategory: [New Subcategory]
# Product: Cupcakes Lemon → Suggested Subcategory: [New Subcategory]
# Product: Pie Apple → Suggested Subcategory: [New Subcategory]
# Product: Pie Cherry → Suggested Subcategory: [New Subcategory]
# Product: Pie Lemon → Suggested Subcategory: [New Subcategory]
# Product: Pie Peach → Suggested Subcategory: [New Subcategory]
# Product: Hot Cocoa Mix Marshmallows → Suggested Subcategory: [New Subcategory]
# Product: Swell Canned Mixed Fruit  → Suggested Subcategory: [New Subcategory]
# Product: Swell Canned Peaches  → Suggested Subcategory: [New Subcategory]
# Product: Super Canola Oil  → Suggested Subcategory: [New Subcategory]
# Product: Super Corn Oil  → Suggested Subcategory: [New Subcategory]
# Product: Super Oregano  → Suggested Subcategory: [New Subcategory]
# Product: Super Pepper  → Suggested Subcategory: [New Subcategory]
# Product: Super Salt  → Suggested Subcategory: [New Subcategory]
# Product: Super Sesame Oil  → Suggested Subcategory: [New Subcategory]
# Product: Super Vegetable Oil  → Suggested Subcategory: [New Subcategory]
# Product: Sunset Counter Cleaner  → Suggested Subcategory: [New Subcategory]
# Product: Sunset Glass Cleaner  → Suggested Subcategory: [New Subcategory]
# Product: Sunset Room Freshener  → Suggested Subcategory: [New Subcategory]
# Product: Sunset Toilet Bowl Cleaner  → Suggested Subcategory: [New Subcategory]
# Product: Sunny Delight Original → Suggested Subcategory: [New Subcategory]
# Product: Orange Citrus Punch Smooth → Suggested Subcategory: [New Subcategory]
# Product: Orange Citrus Punch Tangy Original → Suggested Subcategory: [New Subcategory]
# Product: Bread Raisin → Suggested Subcategory: [New Subcategory]
# Product: Giant Bread → Suggested Subcategory: [New Subcategory]
# Product: BBQ Sauce Original → Suggested Subcategory: [New Subcategory]
# Product: Bread Honey Wheat → Suggested Subcategory: [New Subcategory]
# Product: Stuffing Mix Pork → Suggested Subcategory: [New Subcategory]
# Product: Sandwich Steaks Thin Sliced → Suggested Subcategory: [New Subcategory]
# Product: Hot Cocoa Mix Salted Caramel → Suggested Subcategory: [New Subcategory]
# Product: Hot Cocoa Mix Vanilla Brulee → Suggested Subcategory: [New Subcategory]
# Product: Vinegar Balsamic → Suggested Subcategory: [New Subcategory]
# Product: Sparkling Spring Water Pomegranate Berry → Suggested Subcategory: [New Subcategory]
# Product: Baby Lotion Original → Suggested Subcategory: [New Subcategory]
# Product: Hair Moist Creme → Suggested Subcategory: [New Subcategory]
# Product: Hair Moisturizer Detangling → Suggested Subcategory: [New Subcategory]
# Product: Singles To Go Diet Green Tea → Suggested Subcategory: [New Subcategory]
# Product: Singles To Go Diet Lemon → Suggested Subcategory: [New Subcategory]
# Product: All Purpose Cleaner Bleach 5-in-1 → Suggested Subcategory: [New Subcategory]
# Product: Shower Automatic Refill Liquid Shower Cleaner → Suggested Subcategory: [New Subcategory]
# Product: Bread Amazin Raisin → Suggested Subcategory: [New Subcategory]
# Product: Tastings Medium Asiago → Suggested Subcategory: [New Subcategory]
# Product: Tastings Parmentino → Suggested Subcategory: [New Subcategory]
# Product: Flatbread Chicken Melts → Suggested Subcategory: [New Subcategory]
# Product: Bread Texas Toast → Suggested Subcategory: [New Subcategory]
# Product: Red Wing Counter Cleaner  → Suggested Subcategory: [New Subcategory]
# Product: Red Wing Glass Cleaner  → Suggested Subcategory: [New Subcategory]
# Product: Red Wing Room Freshener  → Suggested Subcategory: [New Subcategory]
# Product: Red Wing Toilet Bowl Cleaner  → Suggested Subcategory: [New Subcategory]
# Product: Red Spade Cole Slaw  → Suggested Subcategory: [New Subcategory]
# Product: Red Spade Corned Beef  → Suggested Subcategory: [New Subcategory]
# Product: Red Spade Low Fat Cole Slaw  → Suggested Subcategory: [New Subcategory]
# Product: Red Spade Pimento Loaf  → Suggested Subcategory: [New Subcategory]
# Product: Red Spade Potato Salad  → Suggested Subcategory: [New Subcategory]
# Product: Red Spade Roasted Chicken  → Suggested Subcategory: [New Subcategory]
# Product: Red Spade Sliced Chicken  → Suggested Subcategory: [New Subcategory]
# Product: Red Spade Sliced Ham  → Suggested Subcategory: [New Subcategory]
# Product: Red Spade Sliced Turkey  → Suggested Subcategory: [New Subcategory]
# Product: Stone Wheat Thins Original → Suggested Subcategory: [New Subcategory]
# Product: Apple Nut Harvest Real Medley Bars → Suggested Subcategory: [New Subcategory]
# Product: Cherry Pistachio Real Medley Bars → Suggested Subcategory: [New Subcategory]
# Product: Peach Almond Real Medley Bars → Suggested Subcategory: [New Subcategory]
# Product: Sausage Pork → Suggested Subcategory: [New Subcategory]
# Product: Lettuce Head → Suggested Subcategory: [New Subcategory]
# Product: Turnip Greens Vegetables → Suggested Subcategory: [New Subcategory]
# Product: Bacon Potato Crisps → Suggested Subcategory: [New Subcategory]
# Product: BBQ Grab & Go → Suggested Subcategory: [New Subcategory]
# Product: BBQ Potato Crisps → Suggested Subcategory: [New Subcategory]
# Product: Buffalo Ranch Potato Crisps → Suggested Subcategory: [New Subcategory]
# Product: Honey Butter Stix → Suggested Subcategory: [New Subcategory]
# Product: Honey Mustard Potato Crisps → Suggested Subcategory: [New Subcategory]
# Product: Jalapeno Potato Crisps → Suggested Subcategory: [New Subcategory]
# Product: Lightly Salted Potato Crisps → Suggested Subcategory: [New Subcategory]
# Product: Loaded Baked Potato Potato Crisps → Suggested Subcategory: [New Subcategory]
# Product: Loud Fiery Chili Lime Corn Crisps → Suggested Subcategory: [New Subcategory]
# Product: Loud Salsa Fiesta Corn Crisps → Suggested Subcategory: [New Subcategory]
# Product: Loud Spicy Queso Corn Crisps → Suggested Subcategory: [New Subcategory]
# Product: Loud Super Cheesy Italian Grain & Vegetable Crisps → Suggested Subcategory: [New Subcategory]
# Product: Memphis BBQ Potato Crisps → Suggested Subcategory: [New Subcategory]
# Product: Mixed Flavors Snack Stacks → Suggested Subcategory: [New Subcategory]
# Product: Original Grab & Go → Suggested Subcategory: [New Subcategory]
# Product: Original Potato Crisps → Suggested Subcategory: [New Subcategory]
# Product: Ranch Potato Crisps → Suggested Subcategory: [New Subcategory]
# Product: Reduced Fat Potato Crisps → Suggested Subcategory: [New Subcategory]
# Product: Salt & Vinegar Potato Crisps → Suggested Subcategory: [New Subcategory]
# Product: Screamin Dill Pickle Potato Crisps → Suggested Subcategory: [New Subcategory]
# Product: Variety Pack Grab & Go → Suggested Subcategory: [New Subcategory]
# Product: Zero Fruit Punch → Suggested Subcategory: [New Subcategory]
# Product: Zero Grape → Suggested Subcategory: [New Subcategory]
# Product: Zero Mixed Berry → Suggested Subcategory: [New Subcategory]
# Product: Zero Orange → Suggested Subcategory: [New Subcategory]
# Product: Pleasant Canned Beets  → Suggested Subcategory: [New Subcategory]
# Product: Pleasant Canned Peas  → Suggested Subcategory: [New Subcategory]
# Product: Pleasant Canned String Beans  → Suggested Subcategory: [New Subcategory]
# Product: Pleasant Canned Tomatos  → Suggested Subcategory: [New Subcategory]
# Product: Pleasant Canned Yams  → Suggested Subcategory: [New Subcategory]
# Product: Pleasant Creamed Corn  → Suggested Subcategory: [New Subcategory]
# Product: Plato Canola Oil  → Suggested Subcategory: [New Subcategory]
# Product: Plato Corn Oil  → Suggested Subcategory: [New Subcategory]
# Product: Plato Oregano  → Suggested Subcategory: [New Subcategory]
# Product: Plato Pepper  → Suggested Subcategory: [New Subcategory]
# Product: Plato Salt  → Suggested Subcategory: [New Subcategory]
# Product: Plato Sesame Oil  → Suggested Subcategory: [New Subcategory]
# Product: Plato Vegetable Oil  → Suggested Subcategory: [New Subcategory]
# Product: PigTail Frozen Broccoli  → Suggested Subcategory: [New Subcategory]
# Product: PigTail Frozen Carrots  → Suggested Subcategory: [New Subcategory]
# Product: PigTail Frozen Cauliflower  → Suggested Subcategory: [New Subcategory]
# Product: PigTail Frozen Corn  → Suggested Subcategory: [New Subcategory]
# Product: PigTail Frozen Peas  → Suggested Subcategory: [New Subcategory]
# Product: Bread Cinnamon Swirl → Suggested Subcategory: [New Subcategory]
# Product: Bread Swirl Raisin Cinnamon → Suggested Subcategory: [New Subcategory]
# Product: Bread White Original → Suggested Subcategory: [New Subcategory]
# Product: Bread White Sandwich → Suggested Subcategory: [New Subcategory]
# Product: Bread Whole Wheat Cinnamon Swirl → Suggested Subcategory: [New Subcategory]
# Product: Farmhouse Bread Hearty White → Suggested Subcategory: [New Subcategory]
# Product: Farmhouse Bread Oatmeal → Suggested Subcategory: [New Subcategory]
# Product: Farmhouse Bread Potato → Suggested Subcategory: [New Subcategory]
# Product: Farmhouse Bread Sourdough → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Baby Cheddar → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Blasted Burstin BBQ → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Blasted Cheddar → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Blasted Xtra Cheddar → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Cheddar → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Cheddar Colors → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Grahams Smores → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Grahams Vanilla Cupcake → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Mix Extra Cheddar & Pretzel → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Mix Extra Cheddar + Pretzel → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Mix Honey Mustard + Pretzel → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Organic Wheat Cheddar Lunch Packs → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Parmesan → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Pretzel → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Princess → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Saltine → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Sweet & Savory → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Whole Grain Cheddar → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Whole Grain Cheddar Colors → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Whole Grain Cinnamon → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Whole Grain Honey Grahams → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Whole Grain Pretzel → Suggested Subcategory: [New Subcategory]
# Product: Goldfish Whole Grain Xtra Cheddar → Suggested Subcategory: [New Subcategory]
# Product: Italian Bread With Sesame Seeds → Suggested Subcategory: [New Subcategory]
# Product: Jewish Pumpernickel Dark Pump → Suggested Subcategory: [New Subcategory]
# Product: Jewish Rye & Pumpernickel Deli Swirl → Suggested Subcategory: [New Subcategory]
# Product: Jewish Rye Seeded → Suggested Subcategory: [New Subcategory]
# Product: Jewish Rye Seedless → Suggested Subcategory: [New Subcategory]
# Product: Light Style Bread 7 Grain → Suggested Subcategory: [New Subcategory]
# Product: Light Style Bread Soft Wheat → Suggested Subcategory: [New Subcategory]
# Product: Stuffing Corn Bread → Suggested Subcategory: [New Subcategory]
# Product: Swirl Bread Blueberry → Suggested Subcategory: [New Subcategory]
# Product: Swirl Bread Cinnamon → Suggested Subcategory: [New Subcategory]
# Product: Swirl Bread French Toast → Suggested Subcategory: [New Subcategory]
# Product: Swirl Bread Raisin Cinnamon → Suggested Subcategory: [New Subcategory]
# Product: Swirl Bread Strawberry → Suggested Subcategory: [New Subcategory]
# Product: Swirl Oatmeal Bread Apple & Cinnamon → Suggested Subcategory: [New Subcategory]
# Product: Texas Toast Garlic → Suggested Subcategory: [New Subcategory]
# Product: Very Thin Bread 100% Whole Wheat → Suggested Subcategory: [New Subcategory]
# Product: Very Thin Bread White → Suggested Subcategory: [New Subcategory]
# Product: Whole Grain Bread 100% Wheat Bread → Suggested Subcategory: [New Subcategory]
# Product: Whole Grain Bread 15 Grain → Suggested Subcategory: [New Subcategory]
# Product: Whole Grain Bread Honey Wheat → Suggested Subcategory: [New Subcategory]
# Product: Chopped Beef Dog Food → Suggested Subcategory: [New Subcategory]
# Product: Cough & Congestion Cherry → Suggested Subcategory: [New Subcategory]
# Product: Dutch Style Hot Cocoa Mix → Suggested Subcategory: [New Subcategory]
# Product: Baby Dry Size 1 → Suggested Subcategory: [New Subcategory]
# Product: Baby Dry Size 2 → Suggested Subcategory: [New Subcategory]
# Product: Baby Dry Size 3 → Suggested Subcategory: [New Subcategory]
# Product: Baby Dry Size 4 → Suggested Subcategory: [New Subcategory]
# Product: Baby Dry Size 5 → Suggested Subcategory: [New Subcategory]
# Product: Baby Dry Size 6 → Suggested Subcategory: [New Subcategory]
# Product: Cruisers Size 3 → Suggested Subcategory: [New Subcategory]
# Product: Cruisers Size 4 → Suggested Subcategory: [New Subcategory]
# Product: Cruisers Size 5 → Suggested Subcategory: [New Subcategory]
# Product: Swaddlers Size 1 → Suggested Subcategory: [New Subcategory]
# Product: Swaddlers Size 2 → Suggested Subcategory: [New Subcategory]
# Product: Swaddlers Size Newborn → Suggested Subcategory: [New Subcategory]
# Product: Oxy Blue → Suggested Subcategory: [New Subcategory]
# Product: Oxi Clean Laundry Detergent → Suggested Subcategory: [New Subcategory]
# Product: Blueberries In Light Syrup → Suggested Subcategory: [New Subcategory]
# Product: Meatballs Angus Beef → Suggested Subcategory: [New Subcategory]
# Product: Chicken Patties → Suggested Subcategory: [New Subcategory]
# Product: Taco Seasoning Original → Suggested Subcategory: [New Subcategory]
# Product: Craisins Original → Suggested Subcategory: [New Subcategory]
# Product: Cranberry Sauce Jellied → Suggested Subcategory: [New Subcategory]
# Product: Spread Hazelnut → Suggested Subcategory: [New Subcategory]
# Product: Carnation Reduced Fat → Suggested Subcategory: [New Subcategory]
# Product: Hot Cocoa Mix Mini Marshmallow → Suggested Subcategory: [New Subcategory]
# Product: Tea Instant → Suggested Subcategory: [New Subcategory]
# Product: Bread Cinnamon Raisin Swirl → Suggested Subcategory: [New Subcategory]
# Product: Nationeel Avocado Dip  → Suggested Subcategory: [New Subcategory]
# Product: Nationeel Fondue Mix  → Suggested Subcategory: [New Subcategory]
# Product: Nationeel Fudge Brownies  → Suggested Subcategory: [New Subcategory]
# Product: Nationeel Salsa Dip  → Suggested Subcategory: [New Subcategory]
# Product: Wheat Thins Cracked Pepper & Olive Oil → Suggested Subcategory: [New Subcategory]
# Product: Wheat Thins Hint Of Salt → Suggested Subcategory: [New Subcategory]
# Product: Wheat Thins Original → Suggested Subcategory: [New Subcategory]
# Product: Wheat Thins Ranch → Suggested Subcategory: [New Subcategory]
# Product: Wheat Thins Reduced Fat → Suggested Subcategory: [New Subcategory]
# Product: Wheat Thins Sundried Tomato & Basil → Suggested Subcategory: [New Subcategory]
# Product: Wheat Thins Toasted Pita Garlic Herb → Suggested Subcategory: [New Subcategory]
# Product: Wheat Thins Toasted Pita Original → Suggested Subcategory: [New Subcategory]
# Product: Musial Mints  → Suggested Subcategory: [New Subcategory]
# Product: Musial Spicy Mints  → Suggested Subcategory: [New Subcategory]
# Product: Musial Tasty Candy Bar  → Suggested Subcategory: [New Subcategory]
# Product: Diaper Bag Dispenser → Suggested Subcategory: [New Subcategory]
# Product: Diaper Bag Refills → Suggested Subcategory: [New Subcategory]
# Product: Syrup Regular → Suggested Subcategory: [New Subcategory]
# Product: Applesauce Cinnamon → Suggested Subcategory: [New Subcategory]
# Product: Pain Reliever/Fever Reducer Original Berry → Suggested Subcategory: [New Subcategory]
# Product: Salt Kosher → Suggested Subcategory: [New Subcategory]
# Product: Sea Salt Coarse → Suggested Subcategory: [New Subcategory]
# Product: Sea Salt Fine → Suggested Subcategory: [New Subcategory]
# Product: Moms Cole Slaw  → Suggested Subcategory: [New Subcategory]
# Product: Moms Corned Beef  → Suggested Subcategory: [New Subcategory]
# Product: Moms Low Fat Cole Slaw  → Suggested Subcategory: [New Subcategory]
# Product: Moms Pimento Loaf  → Suggested Subcategory: [New Subcategory]
# Product: Moms Potato Salad  → Suggested Subcategory: [New Subcategory]
# Product: Moms Roasted Chicken  → Suggested Subcategory: [New Subcategory]
# Product: Moms Sliced Chicken  → Suggested Subcategory: [New Subcategory]
# Product: Moms Sliced Ham  → Suggested Subcategory: [New Subcategory]
# Product: Moms Sliced Turkey  → Suggested Subcategory: [New Subcategory]
# Product: Coolers Fruit Punch → Suggested Subcategory: [New Subcategory]
# Product: Fruit Drink Peach → Suggested Subcategory: [New Subcategory]
# Product: Vanilla, Butter & Nut Exctract → Suggested Subcategory: [New Subcategory]
# Product: Potato Bread Cinnamon Raisin Swirl → Suggested Subcategory: [New Subcategory]
# Product: With Ultra Leakguards Size 3 → Suggested Subcategory: [New Subcategory]
# Product: With Ultra Leakguards Size 4 → Suggested Subcategory: [New Subcategory]
# Product: With Ultra Leakguards Size 5 → Suggested Subcategory: [New Subcategory]
# Product: Gas Relief Drops Natural Berry → Suggested Subcategory: [New Subcategory]
# Product: Spray & Drops Saline → Suggested Subcategory: [New Subcategory]
# Product: Bars Marshmallow Treat → Suggested Subcategory: [New Subcategory]
# Product: Bars Nutty → Suggested Subcategory: [New Subcategory]
# Product: Brownies Cosmic → Suggested Subcategory: [New Subcategory]
# Product: Brownies Fudge → Suggested Subcategory: [New Subcategory]
# Product: Buns Honey → Suggested Subcategory: [New Subcategory]
# Product: Cake Cloud Cakes → Suggested Subcategory: [New Subcategory]
# Product: Cake Swiss Rolls → Suggested Subcategory: [New Subcategory]
# Product: Cake Zebra Cakes → Suggested Subcategory: [New Subcategory]
# Product: Spin Wheels Pecan → Suggested Subcategory: [New Subcategory]
# Product: Tea Bags Black Tea & Honey Berry Lemonade Decaf → Suggested Subcategory: [New Subcategory]
# Product: Tea Bags Green Tea & Honey Coconut Passionfruit → Suggested Subcategory: [New Subcategory]
# Product: Tea Bags Green Tea & Honey Dragonfruit Peach → Suggested Subcategory: [New Subcategory]
# Product: Tea Stix Tea & Honey Lemon → Suggested Subcategory: [New Subcategory]
# Product: Lean Cusine Frozen → Suggested Subcategory: [New Subcategory]
# Product: Landslide Canola Oil  → Suggested Subcategory: [New Subcategory]
# Product: Landslide Corn Oil  → Suggested Subcategory: [New Subcategory]
# Product: Landslide Oregano  → Suggested Subcategory: [New Subcategory]
# Product: Landslide Pepper  → Suggested Subcategory: [New Subcategory]
# Product: Landslide Salt  → Suggested Subcategory: [New Subcategory]
# Product: Landslide Sesame Oil  → Suggested Subcategory: [New Subcategory]
# Product: Landslide Vegetable Oil  → Suggested Subcategory: [New Subcategory]
# Product: Lake Cole Slaw  → Suggested Subcategory: [New Subcategory]
# Product: Lake Corned Beef  → Suggested Subcategory: [New Subcategory]
# Product: Lake Low Fat Cole Slaw  → Suggested Subcategory: [New Subcategory]
# Product: Lake Pimento Loaf  → Suggested Subcategory: [New Subcategory]
# Product: Lake Potato Salad  → Suggested Subcategory: [New Subcategory]
# Product: Lake Roasted Chicken  → Suggested Subcategory: [New Subcategory]
# Product: Lake Sliced Chicken  → Suggested Subcategory: [New Subcategory]
# Product: Lake Sliced Ham  → Suggested Subcategory: [New Subcategory]
# Product: Lake Sliced Turkey  → Suggested Subcategory: [New Subcategory]
# Product: Bread Crumbs Italian Style → Suggested Subcategory: [New Subcategory]
# Product: Garlic Bread Classic → Suggested Subcategory: [New Subcategory]
# Product: Twisted Bread Sticks Garlic → Suggested Subcategory: [New Subcategory]
# Product: Twisted Bread Sticks Mozzarella → Suggested Subcategory: [New Subcategory]
# Product: Cool Whip Regular → Suggested Subcategory: [New Subcategory]
# Product: Salad Dressing Italian → Suggested Subcategory: [New Subcategory]
# Product: Salad Dressing Ranch → Suggested Subcategory: [New Subcategory]
# Product: Salad Dressing Thousand Island → Suggested Subcategory: [New Subcategory]
# Product: Salad Dressing Zesty Italian → Suggested Subcategory: [New Subcategory]
# Product: Bursts Cherry → Suggested Subcategory: [New Subcategory]
# Product: Oven Cravers Cordon Bleu → Suggested Subcategory: [New Subcategory]
# Product: Kiwi Lox  → Suggested Subcategory: [New Subcategory]
# Product: Cooking Stock Chicken → Suggested Subcategory: [New Subcategory]
# Product: Flour All Purpose → Suggested Subcategory: [New Subcategory]
# Product: Salad Dressing French → Suggested Subcategory: [New Subcategory]
# Product: Eggo French Toaster Sticks Cinnamon → Suggested Subcategory: [New Subcategory]
# Product: Nutri Grain Blueberry Bliss Harvest Fruit & Oat Bars → Suggested Subcategory: [New Subcategory]
# Product: Nutri Grain Fruit Crunch Apple Cobbler Granola Bars → Suggested Subcategory: [New Subcategory]
# Product: Nutri Grain Fruit Crunch Strawberry Parfait Granola Bars → Suggested Subcategory: [New Subcategory]
# Product: Nutri Grain Toffee Crunch Bar → Suggested Subcategory: [New Subcategory]
# Product: Nutri-Grain Harvest Strawberry Fruit & Oat Bars → Suggested Subcategory: [New Subcategory]
# Product: Special K Berry Pastry Crisps → Suggested Subcategory: [New Subcategory]
# Product: Special K Blueberry Pastry Crisps → Suggested Subcategory: [New Subcategory]
# Product: Special K Indulgent Moments Dreamy Coconut Snack Bites → Suggested Subcategory: [New Subcategory]
# Product: Special K Moments Caramel Pretzel Bliss Snack Bites → Suggested Subcategory: [New Subcategory]
# Product: Special K Strawberry Pastry Crisps → Suggested Subcategory: [New Subcategory]
# Product: Just Right Canned Beets  → Suggested Subcategory: [New Subcategory]
# Product: Just Right Canned Peas  → Suggested Subcategory: [New Subcategory]
# Product: Just Right Canned String Beans  → Suggested Subcategory: [New Subcategory]
# Product: Just Right Canned Tomatos  → Suggested Subcategory: [New Subcategory]
# Product: Just Right Canned Yams  → Suggested Subcategory: [New Subcategory]
# Product: Just Right Creamed Corn  → Suggested Subcategory: [New Subcategory]
# Product: Nectar Guava → Suggested Subcategory: [New Subcategory]
# Product: Baby Oil Original → Suggested Subcategory: [New Subcategory]
# Product: Baby Powder Original → Suggested Subcategory: [New Subcategory]
# Product: Cake Mix Yellow → Suggested Subcategory: [New Subcategory]
# Product: Mix Baking → Suggested Subcategory: [New Subcategory]
# Product: Muffin Mix Blueberry → Suggested Subcategory: [New Subcategory]
# Product: Muffin Mix Corn → Suggested Subcategory: [New Subcategory]
# Product: Muffin Mix Raspberry → Suggested Subcategory: [New Subcategory]
# Product: Muffin Mix Vegetarian Corn → Suggested Subcategory: [New Subcategory]
# Product: Imagine Frozen Broccoli  → Suggested Subcategory: [New Subcategory]
# Product: Imagine Frozen Carrots  → Suggested Subcategory: [New Subcategory]
# Product: Imagine Frozen Cauliflower  → Suggested Subcategory: [New Subcategory]
# Product: Imagine Frozen Corn  → Suggested Subcategory: [New Subcategory]
# Product: Imagine Frozen Peas  → Suggested Subcategory: [New Subcategory]
# Product: Good Nights Jumbo - Boy → Suggested Subcategory: [New Subcategory]
# Product: Good Nights Large - Boy → Suggested Subcategory: [New Subcategory]
# Product: Little Movers - Disney Size 3 → Suggested Subcategory: [New Subcategory]
# Product: Little Movers - Disney Size 4 → Suggested Subcategory: [New Subcategory]
# Product: Little Movers - Disney Size 5 → Suggested Subcategory: [New Subcategory]
# Product: Little Movers - Disney Size 6 → Suggested Subcategory: [New Subcategory]
# Product: Little Movers Slip On Size 3 → Suggested Subcategory: [New Subcategory]
# Product: Little Movers Slip On Size 4 → Suggested Subcategory: [New Subcategory]
# Product: Little Movers Slip On Size 5 → Suggested Subcategory: [New Subcategory]
# Product: Little Snugglers Size 2 → Suggested Subcategory: [New Subcategory]
# Product: Little Snugglers Size Newborn → Suggested Subcategory: [New Subcategory]
# Product: Little Swimmers Size Large → Suggested Subcategory: [New Subcategory]
# Product: Little Swimmers Size Medium → Suggested Subcategory: [New Subcategory]
# Product: Little Swimmers Size Small → Suggested Subcategory: [New Subcategory]
# Product: Pull-ups 4T-5T/Girls → Suggested Subcategory: [New Subcategory]
# Product: Snug & Dry - Disney Size 2 → Suggested Subcategory: [New Subcategory]
# Product: Snug & Dry - Disney Size 3 → Suggested Subcategory: [New Subcategory]
# Product: Snug & Dry - Disney Size 4 → Suggested Subcategory: [New Subcategory]
# Product: Snug & Dry - Disney Size 5 → Suggested Subcategory: [New Subcategory]
# Product: Snug & Dry - Disney Size 6 → Suggested Subcategory: [New Subcategory]
# Product: Snug & Dry Size 1 → Suggested Subcategory: [New Subcategory]
# Product: Snug & Dry Size 3 → Suggested Subcategory: [New Subcategory]
# Product: Snug & Dry Size 4 → Suggested Subcategory: [New Subcategory]
# Product: Snug & Dry Size 6 → Suggested Subcategory: [New Subcategory]
# Product: Cake Ding Dongs → Suggested Subcategory: [New Subcategory]
# Product: Cake Ho Hos → Suggested Subcategory: [New Subcategory]
# Product: Cake Twinkies → Suggested Subcategory: [New Subcategory]
# Product: Horatio Avocado Dip  → Suggested Subcategory: [New Subcategory]
# Product: Horatio Fondue Mix  → Suggested Subcategory: [New Subcategory]
# Product: Horatio Fudge Brownies  → Suggested Subcategory: [New Subcategory]
# Product: Horatio Salsa Dip  → Suggested Subcategory: [New Subcategory]
# Product: High Top Almonds  → Suggested Subcategory: [New Subcategory]
# Product: High Top Asparagus  → Suggested Subcategory: [New Subcategory]
# Product: High Top Baby Onion  → Suggested Subcategory: [New Subcategory]
# Product: High Top Beets  → Suggested Subcategory: [New Subcategory]
# Product: High Top Broccoli  → Suggested Subcategory: [New Subcategory]
# Product: High Top Cantelope  → Suggested Subcategory: [New Subcategory]
# Product: High Top Cauliflower  → Suggested Subcategory: [New Subcategory]
# Product: High Top Corn on the Cob  → Suggested Subcategory: [New Subcategory]
# Product: High Top Dried Mushrooms  → Suggested Subcategory: [New Subcategory]
# Product: High Top Elephant Garlic  → Suggested Subcategory: [New Subcategory]
# Product: High Top Fancy Plums  → Suggested Subcategory: [New Subcategory]
# Product: High Top Fresh Lima Beans  → Suggested Subcategory: [New Subcategory]
# Product: High Top Fuji Apples  → Suggested Subcategory: [New Subcategory]
# Product: High Top Garlic  → Suggested Subcategory: [New Subcategory]
# Product: High Top Golden Delcious Apples  → Suggested Subcategory: [New Subcategory]
# Product: High Top Green Pepper  → Suggested Subcategory: [New Subcategory]
# Product: High Top Honey Dew  → Suggested Subcategory: [New Subcategory]
# Product: High Top Lemons  → Suggested Subcategory: [New Subcategory]
# Product: High Top Lettuce  → Suggested Subcategory: [New Subcategory]
# Product: High Top Limes  → Suggested Subcategory: [New Subcategory]
# Product: High Top Macintosh Apples  → Suggested Subcategory: [New Subcategory]
# Product: High Top Mandarin Oranges  → Suggested Subcategory: [New Subcategory]
# Product: High Top Mushrooms  → Suggested Subcategory: [New Subcategory]
# Product: High Top New Potatos  → Suggested Subcategory: [New Subcategory]
# Product: High Top Onions  → Suggested Subcategory: [New Subcategory]
# Product: High Top Oranges  → Suggested Subcategory: [New Subcategory]
# Product: High Top Peaches  → Suggested Subcategory: [New Subcategory]
# Product: High Top Plums  → Suggested Subcategory: [New Subcategory]
# Product: High Top Potatos  → Suggested Subcategory: [New Subcategory]
# Product: High Top Prepared Salad  → Suggested Subcategory: [New Subcategory]
# Product: High Top Red Delcious Apples  → Suggested Subcategory: [New Subcategory]
# Product: High Top Red Pepper  → Suggested Subcategory: [New Subcategory]
# Product: High Top Shitake Mushrooms  → Suggested Subcategory: [New Subcategory]
# Product: High Top Squash  → Suggested Subcategory: [New Subcategory]
# Product: High Top Summer Squash  → Suggested Subcategory: [New Subcategory]
# Product: High Top Sweet Onion  → Suggested Subcategory: [New Subcategory]
# Product: High Top Sweet Peas  → Suggested Subcategory: [New Subcategory]
# Product: High Top Tangerines  → Suggested Subcategory: [New Subcategory]
# Product: High Top Tomatos  → Suggested Subcategory: [New Subcategory]
# Product: High Quality Counter Cleaner  → Suggested Subcategory: [New Subcategory]
# Product: High Quality Glass Cleaner  → Suggested Subcategory: [New Subcategory]
# Product: High Quality Room Freshener  → Suggested Subcategory: [New Subcategory]
# Product: High Quality Toilet Bowl Cleaner  → Suggested Subcategory: [New Subcategory]
# Product: Syrup Strawberry → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Almonds  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Asparagus  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Baby Onion  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Beets  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Broccoli  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Cantelope  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Cauliflower  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Corn on the Cob  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Dried Mushrooms  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Elephant Garlic  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Fancy Plums  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Fresh Lima Beans  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Fuji Apples  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Garlic  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Golden Delcious Apples  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Green Pepper  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Honey Dew  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Lemons  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Lettuce  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Limes  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Macintosh Apples  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Mandarin Oranges  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Mushrooms  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos New Potatos  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Onions  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Oranges  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Peaches  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Plums  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Potatos  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Prepared Salad  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Red Delcious Apples  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Red Pepper  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Shitake Mushrooms  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Squash  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Summer Squash  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Sweet Onion  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Sweet Peas  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Tangerines  → Suggested Subcategory: [New Subcategory]
# Product: Hermanos Tomatos  → Suggested Subcategory: [New Subcategory]
# Product: Salsa Mild → Suggested Subcategory: [New Subcategory]
# Product: Ketchup Original → Suggested Subcategory: [New Subcategory]
# Product: Aloha Morning Mixed Berry → Suggested Subcategory: [New Subcategory]
# Product: Aloha Morning Orange Citrus → Suggested Subcategory: [New Subcategory]
# Product: Gulf Coast Mints  → Suggested Subcategory: [New Subcategory]
# Product: Gulf Coast Spicy Mints  → Suggested Subcategory: [New Subcategory]
# Product: Gulf Coast Tasty Candy Bar  → Suggested Subcategory: [New Subcategory]
# Product: Green Ribbon Canned Mixed Fruit  → Suggested Subcategory: [New Subcategory]
# Product: Green Ribbon Canned Peaches  → Suggested Subcategory: [New Subcategory]
# Product: Flavor Straws Strawberry Magic → Suggested Subcategory: [New Subcategory]
# Product: Boys L/XL → Suggested Subcategory: [New Subcategory]
# Product: Boys S/M → Suggested Subcategory: [New Subcategory]
# Product: Girl L & XL → Suggested Subcategory: [New Subcategory]
# Product: Girls 2T-3T → Suggested Subcategory: [New Subcategory]
# Product: Girls L/XL → Suggested Subcategory: [New Subcategory]
# Product: Girls S/M → Suggested Subcategory: [New Subcategory]
# Product: Tru-Fit Refills L/XL → Suggested Subcategory: [New Subcategory]
# Product: Tru-Fit Starter Kit L/XL - Boy → Suggested Subcategory: [New Subcategory]
# Product: Tru-Fit Starter Kit L/XL - Girl → Suggested Subcategory: [New Subcategory]
# Product: Golden Frozen Broccoli  → Suggested Subcategory: [New Subcategory]
# Product: Golden Frozen Carrots  → Suggested Subcategory: [New Subcategory]
# Product: Golden Frozen Cauliflower  → Suggested Subcategory: [New Subcategory]
# Product: Golden Frozen Corn  → Suggested Subcategory: [New Subcategory]
# Product: Golden Frozen Peas  → Suggested Subcategory: [New Subcategory]
# Product: Vitamin Water Tropical Citrus → Suggested Subcategory: [New Subcategory]
# Product: Bitty Bites Blueberry → Suggested Subcategory: [New Subcategory]
# Product: Bitty Bites Strawberry → Suggested Subcategory: [New Subcategory]
# Product: Fruit & Veggie Melts Truly Tropical Blend → Suggested Subcategory: [New Subcategory]
# Product: Grabbers Apple & Sweet Potato → Suggested Subcategory: [New Subcategory]
# Product: Grabbers Pear & Squash → Suggested Subcategory: [New Subcategory]
# Product: Grabbers Strawberry Banana → Suggested Subcategory: [New Subcategory]
# Product: Lil Biscuits Vanilla Wafers → Suggested Subcategory: [New Subcategory]
# Product: Lil Crunchies Cinnamon Maple → Suggested Subcategory: [New Subcategory]
# Product: Lil Crunchies Mild Cheddar → Suggested Subcategory: [New Subcategory]
# Product: Lil Crunchies Veggie Dip → Suggested Subcategory: [New Subcategory]
# Product: Lil Entrees Mashed Potatoes & Gravy → Suggested Subcategory: [New Subcategory]
# Product: Lil Entrees Meatloaf & Mashed Potatoes → Suggested Subcategory: [New Subcategory]
# Product: Lil Meals Spaghetti Rings & Meat Sauce → Suggested Subcategory: [New Subcategory]
# Product: Lil Sticks Chicken Sticks → Suggested Subcategory: [New Subcategory]
# Product: Lil Sticks Meat Sticks → Suggested Subcategory: [New Subcategory]
# Product: Puffs Apple Cinnamon → Suggested Subcategory: [New Subcategory]
# Product: Puffs Blueberry → Suggested Subcategory: [New Subcategory]
# Product: Puffs Peach → Suggested Subcategory: [New Subcategory]
# Product: Puffs Strawberry Apple → Suggested Subcategory: [New Subcategory]
# Product: Formula Soy Concentrate → Suggested Subcategory: [New Subcategory]
# Product: 1st Foods Applesauce → Suggested Subcategory: [New Subcategory]
# Product: 1st Foods Carrots → Suggested Subcategory: [New Subcategory]
# Product: 1st Foods Peaches → Suggested Subcategory: [New Subcategory]
# Product: 1st Foods Peas → Suggested Subcategory: [New Subcategory]
# Product: 1st Foods Prunes → Suggested Subcategory: [New Subcategory]
# Product: 1st Foods Squash → Suggested Subcategory: [New Subcategory]
# Product: 1st Foods Sweet Potatoes → Suggested Subcategory: [New Subcategory]
# Product: Organic Pouch Apple Blackberry → Suggested Subcategory: [New Subcategory]
# Product: Organic Pouch Apples & Summer Peachs → Suggested Subcategory: [New Subcategory]
# Product: Organic Pouch Banana Mango → Suggested Subcategory: [New Subcategory]
# Product: Organic Pouch Banana Squash → Suggested Subcategory: [New Subcategory]
# Product: Organic Pouch Pear Peach Strawberry → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Apple Banana Strawberry → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Apple Blueberry → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Apple Strawberry Banana → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Apples → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Apples & Cherries → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Applesauce → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Apricots W/ Mixed Fruit → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Banana & Orange Medley → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Banana & Plum Grape → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Beef & Gravy → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Blended Fruits With Oatmeal → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Carrots → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Chicken & Gravy → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Chicken Noodle → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Green Beans → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Hawaiian Delight → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Mixed Vegetables → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Organic Harvest Vegetables With Mixed Grains → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Peaches → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Pear & Cinnamon With Oatmeal → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Pears → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Pears & Pineapple → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Peas → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Prunes With Apples → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Squash → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Sweet Potato & Turkey With Whole Grains → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Sweet Potatoes → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Sweet Potatoes With Corn → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Vegetable Beef → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Vegetable Chicken → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Apple Banana Peach → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Apple Mango Kiwi → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Apples & Cinnamon With Oatmeal → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Banana Strawberry → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Broccoli & Carrots → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Chicken Noodle → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Fruit Medley Dessert → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Lasagna → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Mixed Vegetables & Chicken → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Oatmeal Apple Cinnamon → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Pears → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Spaghetti With Beef → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Sweet Potatoes → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Vegetables & Beef → Suggested Subcategory: [New Subcategory]
# Product: Fiber One Blueberry Streusel Bar → Suggested Subcategory: [New Subcategory]
# Product: Fiber One Strawberry Streusel Bar → Suggested Subcategory: [New Subcategory]
# Product: G2 Lime → Suggested Subcategory: [New Subcategory]
# Product: Gatorade Sports Drink → Suggested Subcategory: [New Subcategory]
# Product: Sports Drink Strawberry Lemonade → Suggested Subcategory: [New Subcategory]
# Product: Doritos & Cheetos Mix 2Go → Suggested Subcategory: [New Subcategory]
# Product: Doritos Cool Ranch → Suggested Subcategory: [New Subcategory]
# Product: Doritos Jacked Ranch Dipped Hot Wings → Suggested Subcategory: [New Subcategory]
# Product: Doritos Mix Taco Explosion → Suggested Subcategory: [New Subcategory]
# ...
# Product: Ebony Golden Delcious Apples  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Green Pepper  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Honey Dew  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Lemons  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Lettuce  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Limes  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Macintosh Apples  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Mandarin Oranges  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Mushrooms  → Suggested Subcategory: [New Subcategory]
# Product: Ebony New Potatos  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Onions  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Oranges  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Peaches  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Plums  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Potatos  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Prepared Salad  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Red Delcious Apples  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Red Pepper  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Shitake Mushrooms  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Squash  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Summer Squash  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Sweet Onion  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Sweet Peas  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Tangerines  → Suggested Subcategory: [New Subcategory]
# Product: Ebony Tomatos  → Suggested Subcategory: [New Subcategory]
# Product: Dual City Lox  → Suggested Subcategory: [New Subcategory]
# Product: Devil Dogs Cake → Suggested Subcategory: [New Subcategory]
# Product: Ring Dings Cake → Suggested Subcategory: [New Subcategory]
# Product: Yodels Cake → Suggested Subcategory: [New Subcategory]
# Product: Hearty Meals Beef Stew → Suggested Subcategory: [New Subcategory]
# Product: Denny Counter Cleaner  → Suggested Subcategory: [New Subcategory]
# Product: Denny Glass Cleaner  → Suggested Subcategory: [New Subcategory]
# Product: Denny Room Freshener  → Suggested Subcategory: [New Subcategory]
# Product: Denny Toilet Bowl Cleaner  → Suggested Subcategory: [New Subcategory]
# Product: Diced Mango Fruit Cup → Suggested Subcategory: [New Subcategory]
# Product: Fruit Burst Squeezers Mixed Berry → Suggested Subcategory: [New Subcategory]
# Product: Cutting Edge Cole Slaw  → Suggested Subcategory: [New Subcategory]
# Product: Cutting Edge Corned Beef  → Suggested Subcategory: [New Subcategory]
# Product: Cutting Edge Low Fat Cole Slaw  → Suggested Subcategory: [New Subcategory]
# Product: Cutting Edge Pimento Loaf  → Suggested Subcategory: [New Subcategory]
# Product: Cutting Edge Potato Salad  → Suggested Subcategory: [New Subcategory]
# Product: Cutting Edge Roasted Chicken  → Suggested Subcategory: [New Subcategory]
# Product: Cutting Edge Sliced Chicken  → Suggested Subcategory: [New Subcategory]
# Product: Cutting Edge Sliced Ham  → Suggested Subcategory: [New Subcategory]
# Product: Cutting Edge Sliced Turkey  → Suggested Subcategory: [New Subcategory]
# Product: Curlew Lox  → Suggested Subcategory: [New Subcategory]
# Product: 3D White Arctic Fresh → Suggested Subcategory: [New Subcategory]
# Product: Lemonade Yellow → Suggested Subcategory: [New Subcategory]
# Product: Spread Original → Suggested Subcategory: [New Subcategory]
# Product: Cormorant Counter Cleaner  → Suggested Subcategory: [New Subcategory]
# Product: Cormorant Glass Cleaner  → Suggested Subcategory: [New Subcategory]
# Product: Cormorant Room Freshener  → Suggested Subcategory: [New Subcategory]
# Product: Cormorant Toilet Bowl Cleaner  → Suggested Subcategory: [New Subcategory]
# Product: Rotel Diced Tomatoes& Green Chilies → Suggested Subcategory: [New Subcategory]
# Product: FF & LS Broth Chicken → Suggested Subcategory: [New Subcategory]
# Product: Disinfecting Wipes Lemon Fresh → Suggested Subcategory: [New Subcategory]
# Product: Ultra Liquid Bleach Mountain Fresh → Suggested Subcategory: [New Subcategory]
# Product: Alfredo Sauce Sun-Dried Tomato → Suggested Subcategory: [New Subcategory]
# Product: Choice Mints  → Suggested Subcategory: [New Subcategory]
# Product: Choice Spicy Mints  → Suggested Subcategory: [New Subcategory]
# Product: Choice Tasty Candy Bar  → Suggested Subcategory: [New Subcategory]
# Product: Beefaroni Whole Grain → Suggested Subcategory: [New Subcategory]
# Product: Mini Bites Dinos & Meatballs → Suggested Subcategory: [New Subcategory]
# Product: Ravioli Beef → Suggested Subcategory: [New Subcategory]
# Product: CDR Canola Oil  → Suggested Subcategory: [New Subcategory]
# Product: CDR Corn Oil  → Suggested Subcategory: [New Subcategory]
# Product: CDR Oregano  → Suggested Subcategory: [New Subcategory]
# Product: CDR Pepper  → Suggested Subcategory: [New Subcategory]
# Product: CDR Salt  → Suggested Subcategory: [New Subcategory]
# Product: CDR Sesame Oil  → Suggested Subcategory: [New Subcategory]
# Product: CDR Vegetable Oil  → Suggested Subcategory: [New Subcategory]
# Product: Carrington Frozen Broccoli  → Suggested Subcategory: [New Subcategory]
# Product: Carrington Frozen Carrots  → Suggested Subcategory: [New Subcategory]
# Product: Carrington Frozen Cauliflower  → Suggested Subcategory: [New Subcategory]
# Product: Carrington Frozen Corn  → Suggested Subcategory: [New Subcategory]
# Product: Carrington Frozen Peas  → Suggested Subcategory: [New Subcategory]
# Product: Coastal Cooler Strawberry Banana → Suggested Subcategory: [New Subcategory]
# Product: SuperV Apple → Suggested Subcategory: [New Subcategory]
# Product: Dog Treats Beef → Suggested Subcategory: [New Subcategory]
# Product: Chicken Noodle Low Sodium → Suggested Subcategory: [New Subcategory]
# Product: Gravy Turkey → Suggested Subcategory: [New Subcategory]
# Product: Spaghetti O's Plus Calcium → Suggested Subcategory: [New Subcategory]
# Product: Country Style Baked Beans → Suggested Subcategory: [New Subcategory]
# Product: Homestyle Baked Beans → Suggested Subcategory: [New Subcategory]
# Product: Honey Baked Beans → Suggested Subcategory: [New Subcategory]
# Product: Maple Cured Bacon Baked Baked Beans → Suggested Subcategory: [New Subcategory]
# Product: Maple Cured Bacon Baked Beans → Suggested Subcategory: [New Subcategory]
# Product: Original Baked Beans → Suggested Subcategory: [New Subcategory]
# Product: Vegetarian Baked Beans → Suggested Subcategory: [New Subcategory]
# Product: Certified Angus Beef Burger → Suggested Subcategory: [New Subcategory]
# Product: Bravo Canned Beets  → Suggested Subcategory: [New Subcategory]
# Product: Bravo Canned Peas  → Suggested Subcategory: [New Subcategory]
# Product: Bravo Canned String Beans  → Suggested Subcategory: [New Subcategory]
# Product: Bravo Canned Tomatos  → Suggested Subcategory: [New Subcategory]
# Product: Bravo Canned Yams  → Suggested Subcategory: [New Subcategory]
# Product: Bravo Creamed Corn  → Suggested Subcategory: [New Subcategory]
# Product: Blue Label Canned Beets  → Suggested Subcategory: [New Subcategory]
# Product: Blue Label Canned Peas  → Suggested Subcategory: [New Subcategory]
# Product: Blue Label Canned String Beans  → Suggested Subcategory: [New Subcategory]
# Product: Blue Label Canned Tomatos  → Suggested Subcategory: [New Subcategory]
# Product: Blue Label Canned Yams  → Suggested Subcategory: [New Subcategory]
# Product: Blue Label Creamed Corn  → Suggested Subcategory: [New Subcategory]
# Product: Big Time Frozen Broccoli  → Suggested Subcategory: [New Subcategory]
# Product: Big Time Frozen Carrots  → Suggested Subcategory: [New Subcategory]
# Product: Big Time Frozen Cauliflower  → Suggested Subcategory: [New Subcategory]
# Product: Big Time Frozen Corn  → Suggested Subcategory: [New Subcategory]
# Product: Big Time Frozen Peas  → Suggested Subcategory: [New Subcategory]
# Product: Cola Regular → Suggested Subcategory: [New Subcategory]
# Product: Big City Canned Mixed Fruit  → Suggested Subcategory: [New Subcategory]
# Product: Big City Canned Peaches  → Suggested Subcategory: [New Subcategory]
# Product: Fruit Snacks SpongeBob → Suggested Subcategory: [New Subcategory]
# Product: Better Canned Beets  → Suggested Subcategory: [New Subcategory]
# Product: Better Canned Peas  → Suggested Subcategory: [New Subcategory]
# Product: Better Canned String Beans  → Suggested Subcategory: [New Subcategory]
# Product: Better Canned Tomatos  → Suggested Subcategory: [New Subcategory]
# Product: Better Canned Yams  → Suggested Subcategory: [New Subcategory]
# Product: Better Creamed Corn  → Suggested Subcategory: [New Subcategory]
# Product: Best Choice Avocado Dip  → Suggested Subcategory: [New Subcategory]
# Product: Best Choice Fondue Mix  → Suggested Subcategory: [New Subcategory]
# Product: Best Choice Fudge Brownies  → Suggested Subcategory: [New Subcategory]
# Product: Best Choice Salsa Dip  → Suggested Subcategory: [New Subcategory]
# Product: Fruities On The Go Peach, Apple & Banana → Suggested Subcategory: [New Subcategory]
# Product: Fruities On The Go Pear, Banana & Raspberry → Suggested Subcategory: [New Subcategory]
# Product: Fruities On The Go Pear, Mango & Squash → Suggested Subcategory: [New Subcategory]
# Product: Stage 1 Beef & Broth → Suggested Subcategory: [New Subcategory]
# Product: Stage 1 Butternut Squash → Suggested Subcategory: [New Subcategory]
# Product: Stage 1 Chicken & Broth → Suggested Subcategory: [New Subcategory]
# Product: Stage 1 Honey Crisp Apples → Suggested Subcategory: [New Subcategory]
# Product: Stage 1 Sweet Potatoes → Suggested Subcategory: [New Subcategory]
# Product: Stage 1 Turkey And Broth → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Apple & Pumpkin → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Butternut Squash → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Country Garden Vegetables → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Just Apple & Blackberry → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Just Apple & Kiwi → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Just Apple & Strawberry → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Just Pear & Blueberry → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Tender Golden Sweet Carrots → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Tender Sweet Peas → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Tender Young Green Beans → Suggested Subcategory: [New Subcategory]
# Product: Stage 2 Yellow Cling Peaches → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Just Apple & Aronia Berry → Suggested Subcategory: [New Subcategory]
# Product: Stage 3 Mango, Carrot,Strawberry & Chia → Suggested Subcategory: [New Subcategory]
# Product: BBB Best Canola Oil  → Suggested Subcategory: [New Subcategory]
# Product: BBB Best Corn Oil  → Suggested Subcategory: [New Subcategory]
# Product: BBB Best Oregano  → Suggested Subcategory: [New Subcategory]
# Product: BBB Best Pepper  → Suggested Subcategory: [New Subcategory]
# Product: BBB Best Salt  → Suggested Subcategory: [New Subcategory]
# Product: BBB Best Sesame Oil  → Suggested Subcategory: [New Subcategory]
# Product: BBB Best Vegetable Oil  → Suggested Subcategory: [New Subcategory]
# Product: Collezione Bucatini → Suggested Subcategory: [New Subcategory]
# Product: Gluten Free Elbows → Suggested Subcategory: [New Subcategory]
# Product: Gluten Free Penne → Suggested Subcategory: [New Subcategory]
# Product: Gluten Free Spaghetti → Suggested Subcategory: [New Subcategory]
# Product: PLUS Multigrain Elbows → Suggested Subcategory: [New Subcategory]
# Product: Pronto Elbows → Suggested Subcategory: [New Subcategory]
# Product: Pronto Penne → Suggested Subcategory: [New Subcategory]
# Product: Pronto Rotini → Suggested Subcategory: [New Subcategory]
# Product: Pronto Spaghetti → Suggested Subcategory: [New Subcategory]
# Product: Protein Plus Multigrain Angel Hair → Suggested Subcategory: [New Subcategory]
# Product: Protein Plus Multigrain Penne → Suggested Subcategory: [New Subcategory]
# Product: Protein Plus Multigrain Thin Spaghetti → Suggested Subcategory: [New Subcategory]
# Product: Sauce Creamy Alfredo → Suggested Subcategory: [New Subcategory]
# Product: Sauce Garlic Alfredo → Suggested Subcategory: [New Subcategory]
# Product: Sauce Marinara → Suggested Subcategory: [New Subcategory]
# Product: Sauce Meat → Suggested Subcategory: [New Subcategory]
# Product: Sauce Roasted Garlic → Suggested Subcategory: [New Subcategory]
# Product: Sauce Tomato & Basil → Suggested Subcategory: [New Subcategory]
# Product: Sauce Traditional → Suggested Subcategory: [New Subcategory]
# Product: White Fiber Shells → Suggested Subcategory: [New Subcategory]
# Product: White Fiber Spaghetti → Suggested Subcategory: [New Subcategory]
# Product: Whole Grain Lasagne → Suggested Subcategory: [New Subcategory]
# Product: Whole Grain Linguine → Suggested Subcategory: [New Subcategory]
# Product: Whole Grain Penne → Suggested Subcategory: [New Subcategory]
# Product: Whole Grain Rotini → Suggested Subcategory: [New Subcategory]
# Product: Whole Grain Spaghetti → Suggested Subcategory: [New Subcategory]
# Product: Whole Grain Thin Spaghetti → Suggested Subcategory: [New Subcategory]
# Product: Brown N Serve Sausage Maple Links → Suggested Subcategory: [New Subcategory]
# Product: Brown N Serve Sausage Original Links → Suggested Subcategory: [New Subcategory]
# Product: Brown N Serve Sausage Turkey → Suggested Subcategory: [New Subcategory]
# Product: Chicken Breast Strips → Suggested Subcategory: [New Subcategory]
# Product: Chicken Patty → Suggested Subcategory: [New Subcategory]
# Product: Atomic Mints  → Suggested Subcategory: [New Subcategory]
# Product: Atomic Spicy Mints  → Suggested Subcategory: [New Subcategory]
# Product: Atomic Tasty Candy Bar  → Suggested Subcategory: [New Subcategory]
# Product: Scramble Bacon → Suggested Subcategory: [New Subcategory]
# Product: Scramble Farmhouse-Style Sausage → Suggested Subcategory: [New Subcategory]
# Product: Sandwich Thins Honey Wheat → Suggested Subcategory: [New Subcategory]
# Product: Sandwich Thins Multigrain → Suggested Subcategory: [New Subcategory]
# Product: Sandwich Thins Potato Rolls → Suggested Subcategory: [New Subcategory]
# Product: Sandwich Thins Whole Wheat → Suggested Subcategory: [New Subcategory]
# Product: Applause Canned Mixed Fruit  → Suggested Subcategory: [New Subcategory]
# Product: Applause Canned Peaches  → Suggested Subcategory: [New Subcategory]
# Product: Amigo Lox  → Suggested Subcategory: [New Subcategory]
# Product: American Cole Slaw  → Suggested Subcategory: [New Subcategory]
# Product: American Corned Beef  → Suggested Subcategory: [New Subcategory]
# Product: American Low Fat Cole Slaw  → Suggested Subcategory: [New Subcategory]
# Product: American Pimento Loaf  → Suggested Subcategory: [New Subcategory]
# Product: American Potato Salad  → Suggested Subcategory: [New Subcategory]
# Product: American Roasted Chicken  → Suggested Subcategory: [New Subcategory]
# Product: American Sliced Chicken  → Suggested Subcategory: [New Subcategory]
# Product: American Sliced Ham  → Suggested Subcategory: [New Subcategory]
# Product: American Sliced Turkey  → Suggested Subcategory: [New Subcategory]
# Product: Drink Mix Spiced Cider → Suggested Subcategory: [New Subcategory]
# Product: Snack Cakes Vanilla → Suggested Subcategory: [New Subcategory]
# Product: Laundry Detergent 2X Ultra Free Clear → Suggested Subcategory: [New Subcategory]
# Product: Gourmet Griller Carmelized Onion → Suggested Subcategory: [New Subcategory]
# Product: Gourmet Griller Sweet Italian → Suggested Subcategory: [New Subcategory]
# Product: Meatballs Caramelized Onion → Suggested Subcategory: [New Subcategory]
# Product: Meatballs Pineapple Teriyaki → Suggested Subcategory: [New Subcategory]
# Product: Meatballs Sundried Tomato → Suggested Subcategory: [New Subcategory]
# Product: Iced Tea Mix Regular → Suggested Subcategory: [New Subcategory]

# %%
new_products_columns = [
    'Product Key', 'SKU', 'Product Name', 'Product Class ID', 'Subcategory',
    'Category', 'Department', 'Product Family', 'Size', '#Per Case',
    'Brand Name', 'Manufacturer', 'Supplier'
]

new_products = products[['SKU', 'Product Name', 'Subcategory']].copy()

# %%
# Unique product keys
new_products['Product Key'] = range(
    1, len(new_products) + 1)


# Ensure the product_subcategory column in product_class has unique values
product_class_unique = product_class.drop_duplicates(
    subset='product_subcategory')

new_products['Product Class ID'] = new_products['Subcategory'].map(
    product_class_unique.set_index('product_subcategory')['product_class_id'])
new_products['Category'] = new_products['Subcategory'].map(
    product_class_unique.set_index('product_subcategory')['product_category'])
new_products['Department'] = new_products['Subcategory'].map(
    product_class_unique.set_index('product_subcategory')['product_department'])
new_products['Product Family'] = new_products['Subcategory'].map(
    product_class_unique.set_index('product_subcategory')['product_family'])
new_products['Size'] = 'Standard'  # Default size
new_products['#Per Case'] = 12  # Default #Per Case
new_products['Brand Name'] = 'Generic'  # Default brand name
new_products['Manufacturer'] = 'Rowan Warehouse'  # Default manufacturer
new_products['Supplier'] = new_products['Product Name'].apply(
    lambda x: 'Rowan Dairy' if 'Milk' in x else 'Rowan Warehouse')

# %%
# Reorder columns to match the required format
new_products = new_products[new_products_columns]
new_products.head()
# Out:
#    Product Key       SKU           Product Name  Product Class ID Subcategory  \
# 0            1  42081001     Jambalaya Rice Mix              57.0        Rice
# 1            2  42082001     Jambalaya Rice Mix              57.0        Rice
# 2            3  42083001      Guacamole Regular               NaN        None
# 3            4  42084001  Coffee Original Blend               7.0      Coffee
# 4            5  42085001    GoGurt Variety Pack               NaN        None
#
#         Category     Department Product Family      Size  #Per Case  \
# 0  Starchy Foods  Starchy Foods           Food  Standard         12
# 1  Starchy Foods  Starchy Foods           Food  Standard         12
# 2            NaN            NaN            NaN  Standard         12
# 3      Dry Goods   Baking Goods          Drink  Standard         12
# 4            NaN            NaN            NaN  Standard         12
#
#   Brand Name     Manufacturer         Supplier
# 0    Generic  Rowan Warehouse  Rowan Warehouse
# 1    Generic  Rowan Warehouse  Rowan Warehouse
# 2    Generic  Rowan Warehouse  Rowan Warehouse
# 3    Generic  Rowan Warehouse  Rowan Warehouse
# 4    Generic  Rowan Warehouse  Rowan Warehouse

# %%
new_products.to_csv('new_products.csv', index=False)
print("\nNew Products Table saved as 'new_products.csv'.")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 new_products.to_csv('new_products.csv', index=False)
#       2 print("\nNew Products Table saved as 'new_products.csv'.")
#
# File c:\Users\pavan\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\pavan\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\pavan\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\pavan\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\pavan\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'new_products.csv'
